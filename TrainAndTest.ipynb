# %% [markdown]
# ### Setup & Functions

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
tf.config.run_functions_eagerly(True)
tf.data.experimental.enable_debug_mode()
import cv2
import matplotlib.pyplot as plt
import random
from keras.backend import clear_session
from keras.backend import get_session
import time
from datetime import timedelta 
os.chdir("..\\asset") # change working directory

# %%
emotionList = ('Neutral', 'Happy', 'Sad', 'Surprise', 'Fear', 'Disgust', 'Anger', 'Contempt')
TRAINANNOTATIONPATH = "train_set\\annotations\\"
TRAINIMAGEPATH = "train_set\\images\\"
TESTANNOTATIONPATH = "val_set\\annotations\\"
TESTIMAGEPATH = "val_set\\images\\"

def LoadAllImageNames(filePath, limit = 0, catLimit = []):
  """Load the images names and label in tuple format (label, image name)

  Args:
      filePath (str): directory of image folder
      limit (int, optional): max number of image to load. Defaults to 0.
      catLimit (list<int>, optional): array of image count limit for each class. Defaults to []*8.

  Returns:
      list<str>: shuffled list of image names
  """
  limitCounter = [0,0,0,0,0,0,0,0]
  dataSet = []
  loadCounter = 0
  for file in os.scandir(filePath):
    if (limit > 0 and loadCounter > limit):
      break
  
    name = file.name[:-4] # file name w/o file extension
    data = np.load("{}{}_exp.npy".format(TRAINANNOTATIONPATH if filePath == TRAINIMAGEPATH else TESTANNOTATIONPATH, name)) # 
    label = int(data.item(0))

    if len(catLimit) > 0 and limitCounter[label] >= catLimit[label]:
        continue
    limitCounter[label] += 1
    loadCounter += 1

    dataSet.append((label, file.name))
    if (loadCounter%10000==0):
      print("Files loaded:{}".format(loadCounter))
  
  print("Total images loaded: ", loadCounter)
  print("Images Loaded: ", limitCounter)
  random.shuffle(dataSet)
  return dataSet

# Load the pixels of a picture to numpy.ndarray format. false for test set, true for training set
# Return image in RGB format
def LoadImage(imagePath, imageName, normalize = True):
  """Load image using numpy

  Args:
      imagePath (str): image path 
      imageName (str): image name
      normalize (bool, optional): To normalize image or not. Defaults to True.

  Returns:
      numpy array: x,y,3 array
  """
  # print("{}{}{}".format(os.getcwd(), "\\"+imagePath, imageName))
  image_array = cv2.imread("{}{}{}".format(os.getcwd(), "\\"+imagePath, imageName))
  image_array = cv2.cvtColor(image_array, cv2.COLOR_BGR2RGB)
  if normalize:
    image_array = image_array/255
    
  return image_array

# Extract the daata from 0 to amount from list and return it
def CropData(list, amount):
  if (len(list) < amount):
    amount = len(list)
  croppedList = list[:amount]
  del list[:amount]
  return croppedList

def LoadImages(imagePath, list):
  label = []
  data = []
  count = 0
  for entries in list:
    try:
      image = LoadImage(imagePath, entries[1])
      data.append(image) 
      label.append(entries[0]) 
    except: 
      print("Failed to load training image: ", entries[1])
  npLabel = np.array(label) 
  npData = np.array(data) 
  return npLabel, npData 

def InitializeModel():
  pretrained_model = tf.keras.applications.MobileNetV3Large(input_shape=(224,224,3)) # Initializing model with mobile net V3 pretrained model

  # Initializing the input and output from the model, removing last layer
  base_input = pretrained_model.layers[0].input
  base_output = pretrained_model.layers[-2].output

  # Adding 3 more layers to output side
  final_output = layers.Dense(128)(base_output) # Adding new layers, to the output side
  final_output = layers.Activation('relu')(final_output) # activating layer
  final_output = layers.Dense(64)(final_output)
  final_output = layers.Activation('relu')(final_output) # activating layer
  final_output = layers.Dense(8, activation = 'softmax')(final_output) # 8 cuz there are 8 image classifications

  new_model = keras.Model(inputs = base_input, outputs = final_output)
  # new_model.summary()
  return new_model

def ConvertToGray(image):
  image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
  image = cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)
  return image

def ScaleImage(image, width):
  ratio = image.shape[1]/width
  image = cv2.resize(image, (width, int(image.shape[0]/ratio)))
  return image

def DetectFace(image):
  face_roi = np.ndarray(1)
  faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
  grayImage = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
  faces = faceCascade.detectMultiScale(grayImage, 1.3, 5)
  for x,y,w,h in faces:
    roi_gray = grayImage[y:y+h, x:x+w]
    roi_color = image[y:y+h, x:x+w]
    cv2.rectangle(image, (x,y), (x+w, y+h), (255,0,0), 2)
    facess = faceCascade.detectMultiScale(roi_gray)
    if (len(facess) == 0):
      print("Face not detected")
    else:
      for (ex,ey,ew,eh) in facess:
        face_roi = roi_color[ey:ey+eh, ex:ex+ew]
  return face_roi

def ConvertToInput(image):
  input = ScaleImage(image, 224)
  input = np.expand_dims(input, axis = 0) ## to add fourth dimension to fit model input
  input = input/255
  return input

def GetResult(model, input):
  Predictions = model.predict(input)
  print(Predictions)
  result = np.argmax(Predictions)
  return emotionList[result]

def printDataSetLabels(dataSet):
    counterList = list(range(8))
    for label, name in dataSet:
        counterList[label] += 1
    print(counterList)
    
# Reset Keras Session
def reset_keras():
    sess = get_session()
    clear_session()
    sess.close()
    sess = get_session()

    # try:
    #     del classifier # this is from global space - change this as you need
    # except:
    #     pass

    # use the same config as you used to create the session
    tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.9, visible_device_list="0")
    
def TestModel(model, testSetData):
  # test model
  lostSum = 0
  accuracySum = 0
  count = 0
  while(len(testSetData) != 0):
    # training data
    try:
      croppedList = CropData(testSetData, 100)
      label, data = LoadImages(TESTIMAGEPATH, croppedList)
      result = model.evaluate(data, label, batch_size = 1)
      lostSum += result[0]
      accuracySum += result[1]
    except:
      print("Failed to train data")

    count += 1
    reset_keras()
  
  return lostSum/count, accuracySum/count

class TimeHistory(keras.callbacks.Callback):
  def on_train_begin(self, logs={}):
    self.times = []

  def on_epoch_begin(self, batch, logs={}):
    self.epoch_time_start = time.time()

  def on_epoch_end(self, batch, logs={}):
    self.times.append(time.time() - self.epoch_time_start)

  def AverageTime(self):
    sum = 0
    for time in self.times:
      sum += time
    return sum/len(self.times)

# %% [markdown]
# ### Data Processing

# %%
mainTrainSet = LoadAllImageNames(TRAINIMAGEPATH, catLimit=[3000]*8)
mainTestSet = LoadAllImageNames(TESTIMAGEPATH)
# Out:
# Files loaded:10000
# Files loaded:20000
# Total images loaded:  24000
# Images Loaded:  [3000, 3000, 3000, 3000, 3000, 3000, 3000, 3000]
# Total images loaded:  3999
# Images Loaded:  [500, 500, 500, 500, 500, 500, 500, 499]

# %% [markdown]
# ### Model prepping
# Change the pretrained model and layers here

# %%
def SingleLayerTrainAndTest(modelName, batchSize, firstLayerSize):
  """Train and test a model. This function's input should be customized to accept different parameters, function body should be customized to these parameters to train models of variety of paramters.

  Args:
      modelName (str): name of model
  """
  pretrained_model = tf.keras.applications.MobileNetV3Large(input_shape=(224,224,3)) # Initializing model with mobile net V3 pretrained model

  # Initializing the input and output from the model, removing last layer
  base_input = pretrained_model.layers[0].input
  base_output = pretrained_model.layers[-2].output

  #-------------------------------------------------
  # Customizing layers
  #-------------------------------------------------
  # Adding 3 more layers to output side
  final_output = layers.Dense(firstLayerSize)(base_output) # Adding new layers, to the output side
  final_output = layers.Activation('relu')(final_output) # activating layer
  final_output = layers.Dense(8, activation = 'softmax')(final_output) # 8 cuz there are 8 image classifications

  model = keras.Model(inputs = base_input, outputs = final_output)
  model.compile(loss = "sparse_categorical_crossentropy", optimizer = "adam", metrics=["accuracy"])

  # ------------------ Training Model ------------------
  time_callback = TimeHistory()
  dataSet = mainTrainSet.copy()

  # Initializing model fit params
  # batchSize = 4
  imgPerIter = batchSize*16

  count = 0
  while(len(dataSet) != 0):
    croppedList = []
    try:
      print("loading image") # Crop and load images in
      croppedList = CropData(dataSet, imgPerIter)
      label, data = LoadImages(TRAINIMAGEPATH, croppedList)
      
      # Training model
      model.fit(data, label, epochs = 11, batch_size = batchSize, callbacks = [time_callback])
      print(time_callback.AverageTime())
    except RuntimeError as e:
      print(e)
    
    # Saving weights
    model.save_weights('{}.h5'.format(modelName))
    
    # Print summary of current iteration
    count = count + len(croppedList)
    timeLeft = len(dataSet)/imgPerIter * time_callback.AverageTime()
    print("trained image count: ", count)
    print("Images Left: ", len(dataSet))
    print("Estimated completion time: ", str(timedelta(seconds=timeLeft)))
    
    reset_keras()
  print("---------------- {} Training Completed ------------------".format(modelName))

  # ---------------- Testing Model -----------------
  # initialise image names and label
  testSetData = mainTrainSet.copy()

  # test model
  loss, accuracy = TestModel(model, mainTrainSet.copy())
  
  # Saving test informations
  modelSummary = '''
  model name: {}
  average lost: {}
  average accuracy: {}
            '''.format(modelName, loss, accuracy)
      
  print("==========FINISH TESTING===========\n{}".format(modelSummary))
  
  file = open("training_summaries.txt", "a")
  file.write(modelSummary + "\n\n")

# %%
batchSizes = [4, 8, 16, 32, 48]
firstLayerSizes = [64, 128, 256, 384, 516, 772]

for batchSize in batchSizes:
    for firstLayerSize in firstLayerSizes:
        modelName = "bs{}_fls{}.h".format(batchSize, firstLayerSize)
        SingleLayerTrainAndTest(modelName, batchSize, firstLayerSize)
# Out:
# loading image
# Epoch 1/11
# 16/16 [==============================] - 8s 161ms/step - loss: 3.0773 - accuracy: 0.0938
# Epoch 2/11
# 16/16 [==============================] - 3s 161ms/step - loss: 2.0931 - accuracy: 0.3438
# Epoch 3/11
# 16/16 [==============================] - 3s 159ms/step - loss: 1.6338 - accuracy: 0.4375
# Epoch 4/11
# 16/16 [==============================] - 2s 155ms/step - loss: 1.0764 - accuracy: 0.6719
# Epoch 5/11
# 16/16 [==============================] - 3s 158ms/step - loss: 1.3966 - accuracy: 0.5781
# Epoch 6/11
# 16/16 [==============================] - 3s 156ms/step - loss: 1.0875 - accuracy: 0.7031
# Epoch 7/11
# 16/16 [==============================] - 3s 158ms/step - loss: 1.4901 - accuracy: 0.7500
# Epoch 8/11
# 16/16 [==============================] - 2s 154ms/step - loss: 1.7880 - accuracy: 0.5938
# Epoch 9/11
# 16/16 [==============================] - 2s 153ms/step - loss: 1.4479 - accuracy: 0.5469
# Epoch 10/11
# 16/16 [==============================] - 3s 164ms/step - loss: 1.2463 - accuracy: 0.6094
# Epoch 11/11
# 16/16 [==============================] - 3s 157ms/step - loss: 0.9741 - accuracy: 0.7969
# 3.0366162170063364
# trained image count:  64
# Images Left:  23936
# Estimated completion time:  0:18:55.694465
# loading image
# Epoch 1/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.4886 - accuracy: 0.1250
# Epoch 2/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.1233 - accuracy: 0.1406
# Epoch 3/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0607 - accuracy: 0.1562
# Epoch 4/11
# 16/16 [==============================] - 2s 154ms/step - loss: 1.9744 - accuracy: 0.2188
# Epoch 5/11
# 16/16 [==============================] - 3s 158ms/step - loss: 1.9636 - accuracy: 0.2812
# Epoch 6/11
# 16/16 [==============================] - 3s 158ms/step - loss: 1.8791 - accuracy: 0.2812
# Epoch 7/11
# 16/16 [==============================] - 3s 158ms/step - loss: 1.8596 - accuracy: 0.2188
# Epoch 8/11
# 16/16 [==============================] - 3s 156ms/step - loss: 1.8128 - accuracy: 0.2812
# Epoch 9/11
# 16/16 [==============================] - 3s 159ms/step - loss: 1.7859 - accuracy: 0.3125
# Epoch 10/11
# 16/16 [==============================] - 3s 156ms/step - loss: 1.7750 - accuracy: 0.4375
# Epoch 11/11
# 16/16 [==============================] - 3s 160ms/step - loss: 1.7663 - accuracy: 0.3125
# 2.5264963886954566
# trained image count:  128
# Images Left:  23872
# Estimated completion time:  0:15:42.383153
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.2080 - accuracy: 0.1406
# Epoch 2/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.1218 - accuracy: 0.1719
# Epoch 3/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0518 - accuracy: 0.1875
# Epoch 4/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0688 - accuracy: 0.1719
# Epoch 5/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0487 - accuracy: 0.1719
# Epoch 6/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.1122 - accuracy: 0.1719
# Epoch 7/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0711 - accuracy: 0.1719
# Epoch 8/11
# 16/16 [==============================] - 3s 156ms/step - loss: 2.0637 - accuracy: 0.1719
# Epoch 9/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0629 - accuracy: 0.1719
# Epoch 10/11
# 16/16 [==============================] - 3s 156ms/step - loss: 2.0615 - accuracy: 0.1719
# Epoch 11/11
# 16/16 [==============================] - 3s 166ms/step - loss: 2.0602 - accuracy: 0.1719
# 2.53475022315979
# trained image count:  192
# Images Left:  23808
# Estimated completion time:  0:15:42.927083
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0740 - accuracy: 0.1875
# Epoch 2/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0735 - accuracy: 0.1875
# Epoch 3/11
# 16/16 [==============================] - 3s 156ms/step - loss: 2.0728 - accuracy: 0.1875
# Epoch 4/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0722 - accuracy: 0.1875
# Epoch 5/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0715 - accuracy: 0.1875
# Epoch 6/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0710 - accuracy: 0.1875
# Epoch 7/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0703 - accuracy: 0.1875
# Epoch 8/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0697 - accuracy: 0.1875
# Epoch 9/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0693 - accuracy: 0.1875
# Epoch 10/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0686 - accuracy: 0.1875
# Epoch 11/11
# 16/16 [==============================] - 3s 166ms/step - loss: 2.0681 - accuracy: 0.1875
# 2.5222891677509653
# trained image count:  256
# Images Left:  23744
# Estimated completion time:  0:15:35.769281
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 156ms/step - loss: 2.0914 - accuracy: 0.0625
# Epoch 2/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0905 - accuracy: 0.0625
# Epoch 3/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.0891 - accuracy: 0.0625
# Epoch 4/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0878 - accuracy: 0.0625
# Epoch 5/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0863 - accuracy: 0.0625
# Epoch 6/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0852 - accuracy: 0.0625
# Epoch 7/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0838 - accuracy: 0.0625
# Epoch 8/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0825 - accuracy: 0.0625
# Epoch 9/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0811 - accuracy: 0.0625
# Epoch 10/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0803 - accuracy: 0.0625
# Epoch 11/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0790 - accuracy: 0.0625
# 2.5113576542247427
# trained image count:  320
# Images Left:  23680
# Estimated completion time:  0:15:29.202332
# loading image
# Epoch 1/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0845 - accuracy: 0.0625
# Epoch 2/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0814 - accuracy: 0.1875
# Epoch 3/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.0782 - accuracy: 0.2188
# Epoch 4/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0747 - accuracy: 0.2188
# Epoch 5/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0714 - accuracy: 0.2188
# Epoch 6/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0682 - accuracy: 0.2188
# Epoch 7/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0653 - accuracy: 0.2188
# Epoch 8/11
# 16/16 [==============================] - 3s 165ms/step - loss: 2.0620 - accuracy: 0.2188
# Epoch 9/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.0594 - accuracy: 0.2188
# Epoch 10/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0565 - accuracy: 0.2188
# Epoch 11/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0536 - accuracy: 0.2188
# 2.5232471986250444
# trained image count:  384
# Images Left:  23616
# Estimated completion time:  0:15:31.078216
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0663 - accuracy: 0.1875
# Epoch 2/11
# 16/16 [==============================] - 3s 156ms/step - loss: 2.0659 - accuracy: 0.1875
# Epoch 3/11
# 16/16 [==============================] - 3s 156ms/step - loss: 2.0655 - accuracy: 0.1875
# Epoch 4/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0652 - accuracy: 0.1875
# Epoch 5/11
# 16/16 [==============================] - 3s 161ms/step - loss: 2.0650 - accuracy: 0.1875
# Epoch 6/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0643 - accuracy: 0.1875
# Epoch 7/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0642 - accuracy: 0.1875
# Epoch 8/11
# 16/16 [==============================] - 3s 166ms/step - loss: 2.0638 - accuracy: 0.1875
# Epoch 9/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0634 - accuracy: 0.1875
# Epoch 10/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0631 - accuracy: 0.1875
# Epoch 11/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0628 - accuracy: 0.1875
# 2.5381705544211646
# trained image count:  448
# Images Left:  23552
# Estimated completion time:  0:15:34.046764
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.
11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0886 - accuracy: 0.0938
# Epoch 5/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0871 - accuracy: 0.0938
# Epoch 6/11
# 16/16 [==============================] - 3s 156ms/step - loss: 2.0857 - accuracy: 0.0938
# Epoch 7/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0844 - accuracy: 0.0938
# Epoch 8/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0830 - accuracy: 0.0938
# Epoch 9/11
# 16/16 [==============================] - 3s 156ms/step - loss: 2.0819 - accuracy: 0.0938
# Epoch 10/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0805 - accuracy: 0.0938
# Epoch 11/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0793 - accuracy: 0.0938
# 2.4978646365079014
# trained image count:  704
# Images Left:  23296
# Estimated completion time:  0:15:09.222728
# loading image
# Epoch 1/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0851 - accuracy: 0.0781
# Epoch 2/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0847 - accuracy: 0.0781
# Epoch 3/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.0838 - accuracy: 0.0781
# Epoch 4/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0829 - accuracy: 0.0781
# Epoch 5/11
# 16/16 [==============================] - 3s 161ms/step - loss: 2.0824 - accuracy: 0.0781
# Epoch 6/11
# 16/16 [==============================] - 3s 165ms/step - loss: 2.0815 - accuracy: 0.0781
# Epoch 7/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0808 - accuracy: 0.1250
# Epoch 8/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0802 - accuracy: 0.1250
# Epoch 9/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0794 - accuracy: 0.1250
# Epoch 10/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0787 - accuracy: 0.1250
# Epoch 11/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0781 - accuracy: 0.1094
# 2.516740928996693
# trained image count:  768
# Images Left:  23232
# Estimated completion time:  0:15:13.576957
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 155ms/step - loss: 2.0798 - accuracy: 0.0938
# Epoch 2/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0791 - accuracy: 0.1562
# Epoch 3/11
# 16/16 [==============================] - 3s 156ms/step - loss: 2.0780 - accuracy: 0.1562
# Epoch 4/11
# 16/16 [==============================] - 3s 167ms/step - loss: 2.0771 - accuracy: 0.1562
# Epoch 5/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0759 - accuracy: 0.1562
# Epoch 6/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0750 - accuracy: 0.1562
# Epoch 7/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0741 - accuracy: 0.1562
# Epoch 8/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0733 - accuracy: 0.2031
# Epoch 9/11
# 16/16 [==============================] - 2s 157ms/step - loss: 2.0723 - accuracy: 0.2031
# Epoch 10/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0714 - accuracy: 0.2031
# Epoch 11/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0706 - accuracy: 0.2031
# 2.52159985628995
# trained image count:  832
# Images Left:  23168
# Estimated completion time:  0:15:12.819148
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0820 - accuracy: 0.1250
# Epoch 2/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0815 - accuracy: 0.1250
# Epoch 3/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.0810 - accuracy: 0.1250
# Epoch 4/11
# 16/16 [==============================] - 3s 161ms/step - loss: 2.0800 - accuracy: 0.1250
# Epoch 5/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0792 - accuracy: 0.1250
# Epoch 6/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.0785 - accuracy: 0.1250
# Epoch 7/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0778 - accuracy: 0.1250
# Epoch 8/11
# 16/16 [==============================] - 3s 156ms/step - loss: 2.0771 - accuracy: 0.1250
# Epoch 9/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.0764 - accuracy: 0.1250
# Epoch 10/11
# 16/16 [==============================] - 3s 156ms/step - loss: 2.0758 - accuracy: 0.1250
# Epoch 11/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0750 - accuracy: 0.1250
# 2.5253616029565986
# trained image count:  896
# Images Left:  23104
# Estimated completion time:  0:15:11.655539
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0810 - accuracy: 0.1719
# Epoch 2/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0801 - accuracy: 0.1719
# Epoch 3/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0788 - accuracy: 0.1719
# Epoch 4/11
# 16/16 [==============================] - 3s 167ms/step - loss: 2.0776 - accuracy: 0.1719
# Epoch 5/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0765 - accuracy: 0.1719
# Epoch 6/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0753 - accuracy: 0.1719
# Epoch 7/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0740 - accuracy: 0.1719
# Epoch 8/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0731 - accuracy: 0.1719
# Epoch 9/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0718 - accuracy: 0.1719
# Epoch 10/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0708 - accuracy: 0.1719
# Epoch 11/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0700 - accuracy: 0.1719
# 2.5295834324576636
# trained image count:  960
# Images Left:  23040
# Estimated completion time:  0:15:10.650036
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 161ms/step - loss: 2.0757 - accuracy: 0.1875
# Epoch 2/11
# 16/16 [==============================] - 3s 156ms/step - loss: 2.0748 - accuracy: 0.1875
# Epoch 3/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0735 - accuracy: 0.1875
# Epoch 4/11
# 16/16 [==============================] - 3s 171ms/step - loss: 2.0723 - accuracy: 0.1875
# Epoch 5/11
# 16/16 [==============================] - 3s 155ms/step - loss: 2.0713 - accuracy: 0.1875
# Epoch 6/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0700 - accuracy: 0.1875
# Epoch 7/11
# 16/16 [==============================] - 3s 161ms/step - loss: 2.0692 - accuracy: 0.1875
# Epoch 8/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0679 - accuracy: 0.1875
# Epoch 9/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0671 - accuracy: 0.1875
# Epoch 10/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.0661 - accuracy: 0.1875
# Epoch 11/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0649 - accuracy: 0.1875
# 2.5441536469893022
# trained image count:  1024
# Images Left:  22976
# Estimated completion time:  0:15:13.351159
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0649 - accuracy: 0.1875
# Epoch 2/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0628 - accuracy: 0.1875
# Epoch 3/11
# 16/16 [==============================] - 3s 165ms/step - loss: 2.0606 - accuracy: 0.1875
# Epoch 4/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0580 - accuracy: 0.1875
# Epoch 5/11
# 16/16 [==============================] - 3s 172ms/step - loss: 2.0554 - accuracy: 0.1875
# Epoch 6/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0529 - accuracy: 0.1875
# Epoch 7/11
# 16/16 [==============================] - 3s 163ms/step - loss: 2.0509 - accuracy: 0.1875
# Epoch 8/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0485 - accuracy: 0.1875
# Epoch 9/11
# 16/16 [==============================] - 3s 162ms/step - loss: 2.0463 - accuracy: 0.1875
# Epoch 10/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0440 - accuracy: 0.1875
# Epoch 11/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0421 - accuracy: 0.1875
# 2.584779002449729
# trained image count:  1088
# Images Left:  22912
# Estimated completion time:  0:15:25.350883
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 161ms/step - loss: 2.0808 - accuracy: 0.1250
# Epoch 2/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0799 - accuracy: 0.1250
# Epoch 3/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0788 - accuracy: 0.1250
# Epoch 4/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0778 - accuracy: 0.1250
# Epoch 5/11
# 16/16 [==============================] - 3s 169ms/step - loss: 2.0766 - accuracy: 0.1250
# Epoch 6/11
# 16/16 [==============================] - 3s 163ms/step - loss: 2.0756 - accuracy: 0.1250
# Epoch 7/11
# 16/16 [==============================] - 3s 162ms/step - loss: 2.0744 - accuracy: 0.1250
# Epoch 8/11
# 16/16 [==============================] - 3s 161ms/step - loss: 2.0734 - accuracy: 0.1250
# Epoch 9/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0724 - accuracy: 0.1250
# Epoch 10/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0716 - accuracy: 0.1250
# Epoch 11/11
# 16/16 [==============================] - 3s 156ms/step - loss: 2.0706 - accuracy: 0.1250
# 2.5655868486924605
# trained image count:  1152
# Images Left:  22848
# Estimated completion time:  0:15:15.914505
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0873 - accuracy: 0.1250
# Epoch 2/11
# 16/16 [==============================] - 3s 156ms/step - loss: 2.0870 - accuracy: 0.1250
# Epoch 3/11
# 16/16 [==============================] - 3s 161ms/step - loss: 2.0864 - accuracy: 0.1250
# Epoch 4/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0860 - accuracy: 0.1250
# Epoch 5/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0856 - accuracy: 0.1250
# Epoch 6/11
# 16/16 [==============================] - 3s 172ms/step - loss: 2.0853 - accuracy: 0.1250
# Epoch 7/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0849 - accuracy: 0.1250
# Epoch 8/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0845 - accuracy: 0.1250
# Epoch 9/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0842 - accuracy: 0.1250
# Epoch 10/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0837 - accuracy: 0.1250
# Epoch 11/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.0835 - accuracy: 0.1250
# 2.550166455182162
# trained image count:  1216
# Images Left:  22784
# Estimated completion time:  0:15:07.859258
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 161ms/step - loss: 2.0957 - accuracy: 0.1406
# Epoch 2/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0944 - accuracy: 0.1406
# Epoch 3/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.0927 - accuracy: 0.1406
# Epoch 4/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0914 - accuracy: 0.1406
# Epoch 5/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.0900 - accuracy: 0.1406
# Epoch 6/11
# 16/16 [==============================] - 3s 166ms/step - loss: 2.0886 - accuracy: 0.1406
# Epoch 7/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0874 - accuracy: 0.1406
# Epoch 8/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0859 - accuracy: 0.1406
# Epoch 9/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0847 - accuracy: 0.1406
# Epoch 10/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0834 - accuracy: 0.1406
# Epoch 11/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0823 - accuracy: 0.1406
# 2.513201193376021
# trained image count:  1280
# Images Left:  22720
# Estimated completion time:  0:14:52.186424
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0839 - accuracy: 0.1406
# Epoch 2/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0831 - accuracy: 0.1406
# Epoch 3/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0822 - accuracy: 0.1406
# Epoch 4/11
# 16/16 [==============================] - 3s 156ms/step - loss: 2.0812 - accuracy: 0.1406
# Epoch 5/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0803 - accuracy: 0.1406
# Epoch 6/11
# 16/16 [==============================] - 3s 165ms/step - loss: 2.0796 - accuracy: 0.1406
# Epoch 7/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0785 - accuracy: 0.1406
# Epoch 8/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0779 - accuracy: 0.1406
# Epoch 9/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0769 - accuracy: 0.1406
# Epoch 10/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0762 - accuracy: 0.1406
# Epoch 11/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0752 - accuracy: 0.1406
# 2.5199180299585517
# trained image count:  1344
# Images Left:  22656
# Estimated completion time:  0:14:52.050983
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0832 - accuracy: 0.0938
# Epoch 2/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0819 - accuracy: 0.0938
# Epoch 3/11
# 16/16 [==============================] - 3s 156ms/step - loss: 2.0785 - accuracy: 0.0938
# Epoch 4/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0757 - accuracy: 0.0938
# Epoch 5/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0731 - accuracy: 0.0938
# Epoch 6/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0701 - accuracy: 0.0938
# Epoch 7/11
# 16/16 [==============================] - 3s 169ms/step - loss: 2.0677 - accuracy: 0.0938
# Epoch 8/11
# 16/16 [==============================] - 3s 156ms/step - loss: 2.0651 - accuracy: 0.0938
# Epoch 9/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0624 - accuracy: 0.0938
# Epoch 10/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0601 - accuracy: 0.0938
# Epoch 11/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0577 - accuracy: 0.2031
# 2.5467874136838047
# trained image count:  1408
# Images Left:  22592
# Estimated completion time:  0:14:59.015957
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0845 - accuracy: 0.1094
# Epoch 2/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.0831 - accuracy: 0.1094
# Epoch 3/11
# 16/16 [==============================] - 3s 156ms/step - loss: 2.0811 - accuracy: 0.1094
# Epoch 4/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0790 - accuracy: 0.1094
# Epoch 5/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0772 - accuracy: 0.1094
# Epoch 6/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0750 - accuracy: 0.1094
# Epoch 7/11
# 16/16 [==============================] - 3s 164ms/step - loss: 2.0731 - accuracy: 0.1094
# Epoch 8/11
# 16/16 [==============================] - 3s 161ms/step - loss: 2.0717 - accuracy: 0.1094
# Epoch 9/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.0696 - accuracy: 0.1094
# Epoch 10/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0678 - accuracy: 0.1875
# Epoch 11/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0665 - accuracy: 0.2188
# 2.517783836884932
# trained image count:  1472
# Images Left:  22528
# Estimated completion time:  0:14:46.259911
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0732 - accuracy: 0.0625
# Epoch 2/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0723 - accuracy: 0.0625
# Epoch 3/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0716 - accuracy: 0.0938
# Epoch 4/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0705 - accuracy: 0.1719
# Epoch 5/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0694 - accuracy: 0.1719
# Epoch 6/11
# 16/16 [==============================] - 3s 162ms/step - loss: 2.0685 - accuracy: 0.1719
# Epoch 7/11
# 16/16 [==============================] - 3s 167ms/step - loss: 2.0675 - accuracy: 0.1719
# Epoch 8/11
# 16/16 [==============================] - 3s 156ms/step - loss: 2.0666 - accuracy: 0.1719
# Epoch 9/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.0658 - accuracy: 0.1719
# Epoch 10/11
# 16/16 [==============================] - 3s 163ms/step - loss: 2.0649 - accuracy: 0.1719
# Epoch 11/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.
11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0796 - accuracy: 0.1719
# 2.506437366658991
# trained image count:  1728
# Images Left:  22272
# Estimated completion time:  0:14:32.240204
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 166ms/step - loss: 2.0617 - accuracy: 0.2188
# Epoch 2/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0602 - accuracy: 0.2188
# Epoch 3/11
# 16/16 [==============================] - 3s 161ms/step - loss: 2.0585 - accuracy: 0.2188
# Epoch 4/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0561 - accuracy: 0.2188
# Epoch 5/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0545 - accuracy: 0.2188
# Epoch 6/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0522 - accuracy: 0.2188
# Epoch 7/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0507 - accuracy: 0.2188
# Epoch 8/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0484 - accuracy: 0.2188
# Epoch 9/11
# 16/16 [==============================] - 3s 166ms/step - loss: 2.0466 - accuracy: 0.2188
# Epoch 10/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0448 - accuracy: 0.2188
# Epoch 11/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0431 - accuracy: 0.2188
# 2.546217203140259
# trained image count:  1792
# Images Left:  22208
# Estimated completion time:  0:14:43.537369
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 161ms/step - loss: 2.0713 - accuracy: 0.2031
# Epoch 2/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0706 - accuracy: 0.2031
# Epoch 3/11
# 16/16 [==============================] - 3s 161ms/step - loss: 2.0699 - accuracy: 0.2031
# Epoch 4/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0693 - accuracy: 0.2031
# Epoch 5/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0686 - accuracy: 0.2031
# Epoch 6/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0677 - accuracy: 0.2031
# Epoch 7/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0672 - accuracy: 0.2031
# Epoch 8/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0663 - accuracy: 0.2031
# Epoch 9/11
# 16/16 [==============================] - 3s 163ms/step - loss: 2.0658 - accuracy: 0.2031
# Epoch 10/11
# 16/16 [==============================] - 3s 161ms/step - loss: 2.0650 - accuracy: 0.2031
# Epoch 11/11
# 16/16 [==============================] - 3s 156ms/step - loss: 2.0645 - accuracy: 0.2031
# 2.5526452498002485
# trained image count:  1856
# Images Left:  22144
# Estimated completion time:  0:14:43.215256
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 162ms/step - loss: 2.0670 - accuracy: 0.1562
# Epoch 2/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0660 - accuracy: 0.1562
# Epoch 3/11
# 16/16 [==============================] - 3s 162ms/step - loss: 2.0647 - accuracy: 0.1562
# Epoch 4/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0636 - accuracy: 0.1562
# Epoch 5/11
# 16/16 [==============================] - 3s 162ms/step - loss: 2.0626 - accuracy: 0.1562
# Epoch 6/11
# 16/16 [==============================] - 3s 162ms/step - loss: 2.0610 - accuracy: 0.1562
# Epoch 7/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0600 - accuracy: 0.1562
# Epoch 8/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0586 - accuracy: 0.1562
# Epoch 9/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0576 - accuracy: 0.1562
# Epoch 10/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0566 - accuracy: 0.1562
# Epoch 11/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0557 - accuracy: 0.1562
# 2.5576626387509434
# trained image count:  1920
# Images Left:  22080
# Estimated completion time:  0:14:42.393610
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 162ms/step - loss: 2.1094 - accuracy: 0.0469
# Epoch 2/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.1080 - accuracy: 0.0469
# Epoch 3/11
# 16/16 [==============================] - 3s 161ms/step - loss: 2.1062 - accuracy: 0.0469
# Epoch 4/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.1044 - accuracy: 0.0469
# Epoch 5/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.1024 - accuracy: 0.0469
# Epoch 6/11
# 16/16 [==============================] - 3s 166ms/step - loss: 2.1007 - accuracy: 0.0469
# Epoch 7/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0986 - accuracy: 0.0469
# Epoch 8/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0969 - accuracy: 0.0469
# Epoch 9/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0950 - accuracy: 0.0469
# Epoch 10/11
# 16/16 [==============================] - 3s 161ms/step - loss: 2.0934 - accuracy: 0.0469
# Epoch 11/11
# 16/16 [==============================] - 3s 156ms/step - loss: 2.0918 - accuracy: 0.0469
# 2.557616515593095
# trained image count:  1984
# Images Left:  22016
# Estimated completion time:  0:14:39.820081
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0806 - accuracy: 0.0938
# Epoch 2/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0792 - accuracy: 0.0938
# Epoch 3/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0784 - accuracy: 0.0938
# Epoch 4/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0769 - accuracy: 0.0938
# Epoch 5/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0758 - accuracy: 0.0938
# Epoch 6/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0745 - accuracy: 0.0938
# Epoch 7/11
# 16/16 [==============================] - 3s 168ms/step - loss: 2.0734 - accuracy: 0.0938
# Epoch 8/11
# 16/16 [==============================] - 3s 162ms/step - loss: 2.0725 - accuracy: 0.0938
# Epoch 9/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0715 - accuracy: 0.0938
# Epoch 10/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0701 - accuracy: 0.0938
# Epoch 11/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0690 - accuracy: 0.1406
# 2.5435538508675317
# trained image count:  2048
# Images Left:  21952
# Estimated completion time:  0:14:32.438971
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 162ms/step - loss: 2.1139 - accuracy: 0.1094
# Epoch 2/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.1119 - accuracy: 0.1094
# Epoch 3/11
# 16/16 [==============================] - 3s 162ms/step - loss: 2.1100 - accuracy: 0.1094
# Epoch 4/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.1083 - accuracy: 0.1094
# Epoch 5/11
# 16/16 [==============================] - 3s 156ms/step - loss: 2.1060 - accuracy: 0.1094
# Epoch 6/11
# 16/16 [==============================] - 3s 161ms/step - loss: 2.1046 - accuracy: 0.1094
# Epoch 7/11
# 16/16 [==============================] - 3s 164ms/step - loss: 2.1025 - accuracy: 0.1094
# Epoch 8/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.1009 - accuracy: 0.1094
# Epoch 9/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0993 - accuracy: 0.1094
# Epoch 10/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.0977 - accuracy: 0.1094
# Epoch 11/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0960 - accuracy: 0.1094
# 2.546328999779441
# trained image count:  2112
# Images Left:  21888
# Estimated completion time:  0:14:30.844518
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0795 - accuracy: 0.1094
# Epoch 2/11
# 16/16 [==============================] - 3s 161ms/step - loss: 2.0789 - accuracy: 0.1094
# Epoch 3/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0778 - accuracy: 0.1094
# Epoch 4/11
# 16/16 [==============================] - 3s 162ms/step - loss: 2.0769 - accuracy: 0.1094
# Epoch 5/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0758 - accuracy: 0.1094
# Epoch 6/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0751 - accuracy: 0.1094
# Epoch 7/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0738 - accuracy: 0.1094
# Epoch 8/11
# 16/16 [==============================] - 3s 163ms/step - loss: 2.0729 - accuracy: 0.1719
# Epoch 9/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0718 - accuracy: 0.1719
# Epoch 10/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0713 - accuracy: 0.1719
# Epoch 11/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0702 - accuracy: 0.1719
# 2.5318065990101206
# trained image count:  2176
# Images Left:  21824
# Estimated completion time:  0:14:23.346050
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0940 - accuracy: 0.0781
# Epoch 2/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0930 - accuracy: 0.0781
# Epoch 3/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0916 - accuracy: 0.0938
# Epoch 4/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0900 - accuracy: 0.1562
# Epoch 5/11
# 16/16 [==============================] - 3s 161ms/step - loss: 2.0886 - accuracy: 0.1562
# Epoch 6/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0874 - accuracy: 0.1562
# Epoch 7/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0860 - accuracy: 0.1562
# Epoch 8/11
# 16/16 [==============================] - 3s 167ms/step - loss: 2.0846 - accuracy: 0.1562
# Epoch 9/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0834 - accuracy: 0.1562
# Epoch 10/11
# 16/16 [==============================] - 3s 156ms/step - loss: 2.0821 - accuracy: 0.1562
# Epoch 11/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0810 - accuracy: 0.1562
# 2.53523267399181
# trained image count:  2240
# Images Left:  21760
# Estimated completion time:  0:14:21.979109
# loading image
# Epoch 1/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0720 - accuracy: 0.1562
# Epoch 2/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0710 - accuracy: 0.1562
# Epoch 3/11
# 16/16 [==============================] - 3s 161ms/step - loss: 2.0700 - accuracy: 0.1562
# Epoch 4/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.0684 - accuracy: 0.1562
# Epoch 5/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0673 - accuracy: 0.1562
# Epoch 6/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0657 - accuracy: 0.1562
# Epoch 7/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0647 - accuracy: 0.1562
# Epoch 8/11
# 16/16 [==============================] - 3s 167ms/step - loss: 2.0635 - accuracy: 0.1562
# Epoch 9/11
# 16/16 [==============================] - 3s 156ms/step - loss: 2.0621 - accuracy: 0.1562
# Epoch 10/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0610 - accuracy: 0.1562
# Epoch 11/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.0599 - accuracy: 0.1562
# 2.529900160702792
# trained image count:  2304
# Images Left:  21696
# Estimated completion time:  0:14:17.636154
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0810 - accuracy: 0.1250
# Epoch 2/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0773 - accuracy: 0.1250
# Epoch 3/11
# 16/16 [==============================] - 3s 161ms/step - loss: 2.0722 - accuracy: 0.1250
# Epoch 4/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0683 - accuracy: 0.1719
# Epoch 5/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0633 - accuracy: 0.2969
# Epoch 6/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0588 - accuracy: 0.2969
# Epoch 7/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0544 - accuracy: 0.2969
# Epoch 8/11
# 16/16 [==============================] - 3s 161ms/step - loss: 2.0506 - accuracy: 0.2969
# Epoch 9/11
# 16/16 [==============================] - 3s 165ms/step - loss: 2.0461 - accuracy: 0.2969
# Epoch 10/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0425 - accuracy: 0.2969
# Epoch 11/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0385 - accuracy: 0.2969
# 2.5429892323233863
# trained image count:  2368
# Images Left:  21632
# Estimated completion time:  0:14:19.530361
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 161ms/step - loss: 2.0913 - accuracy: 0.1094
# Epoch 2/11
# 16/16 [==============================] - 3s 162ms/step - loss: 2.0905 - accuracy: 0.1094
# Epoch 3/11
# 16/16 [==============================] - 3s 161ms/step - loss: 2.0891 - accuracy: 0.1094
# Epoch 4/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.0879 - accuracy: 0.1094
# Epoch 5/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0864 - accuracy: 0.1094
# Epoch 6/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0849 - accuracy: 0.1094
# Epoch 7/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0838 - accuracy: 0.1094
# Epoch 8/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0826 - accuracy: 0.1094
# Epoch 9/11
# 16/16 [==============================] - 3s 161ms/step - loss: 2.0813 - accuracy: 0.1094
# Epoch 10/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0800 - accuracy: 0.1094
# Epoch 11/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.0787 - accuracy: 0.1094
# 2.548785599795255
# trained image count:  2432
# Images Left:  21568
# Estimated completion time:  0:14:18.940747
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0846 - accuracy: 0.1094
# Epoch 2/11
# 16/16 [==============================] - 3s 156ms/step - loss: 2.0832 - accuracy: 0.1094
# Epoch 3/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0817 - accuracy: 0.1094
# Epoch 4/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0804 - accuracy: 0.1094
# Epoch 5/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0789 - accuracy: 0.1094
# Epoch 6/11
# 16/16 [==============================] - 3s 163ms/step - loss: 2.0774 - accuracy: 0.1094
# Epoch 7/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0760 - accuracy: 0.1094
# Epoch 8/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0749 - accuracy: 0.1094
# Epoch 9/11
# 16/16 [==============================] - 3s 165ms/step - loss: 2.0736 - accuracy: 0.1094
# Epoch 10/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0725 - accuracy: 0.1094
# Epoch 11/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0711 - accuracy: 0.1094
# 2.545267256823453
# trained image count:  2496
# Images Left:  21504
# Estimated completion time:  0:14:15.209798
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0942 - accuracy: 0.1094
# Epoch 2/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0929 - accuracy: 0.1094
# Epoch 3/11
# ...
# Epoch 7/11
# 16/16 [==============================] - 3s 164ms/step - loss: 2.0723 - accuracy: 0.1562
# Epoch 8/11
# 16/16 [==============================] - 3s 162ms/step - loss: 2.0714 - accuracy: 0.1562
# Epoch 9/11
# 16/16 [==============================] - 3s 163ms/step - loss: 2.0709 - accuracy: 0.1562
# Epoch 10/11
# 16/16 [==============================] - 3s 167ms/step - loss: 2.0703 - accuracy: 0.1562
# Epoch 11/11
# 16/16 [==============================] - 3s 161ms/step - loss: 2.0699 - accuracy: 0.1562
# 2.6260367090051826
# trained image count:  10432
# Images Left:  13568
# Estimated completion time:  0:09:16.719782
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 167ms/step - loss: 2.0818 - accuracy: 0.0625
# Epoch 2/11
# 16/16 [==============================] - 3s 166ms/step - loss: 2.0806 - accuracy: 0.0625
# Epoch 3/11
# 16/16 [==============================] - 3s 163ms/step - loss: 2.0786 - accuracy: 0.0625
# Epoch 4/11
# 16/16 [==============================] - 3s 166ms/step - loss: 2.0771 - accuracy: 0.0625
# Epoch 5/11
# 16/16 [==============================] - 3s 164ms/step - loss: 2.0751 - accuracy: 0.1562
# Epoch 6/11
# 16/16 [==============================] - 3s 171ms/step - loss: 2.0734 - accuracy: 0.1562
# Epoch 7/11
# 16/16 [==============================] - 3s 165ms/step - loss: 2.0718 - accuracy: 0.1562
# Epoch 8/11
# 16/16 [==============================] - 3s 163ms/step - loss: 2.0703 - accuracy: 0.1562
# Epoch 9/11
# 16/16 [==============================] - 3s 164ms/step - loss: 2.0685 - accuracy: 0.1562
# Epoch 10/11
# 16/16 [==============================] - 3s 163ms/step - loss: 2.0670 - accuracy: 0.1562
# Epoch 11/11
# 16/16 [==============================] - 3s 162ms/step - loss: 2.0654 - accuracy: 0.1562
# 2.6434793038801714
# trained image count:  10496
# Images Left:  13504
# Estimated completion time:  0:09:17.774133
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s
11
# 16/16 [==============================] - 3s 161ms/step - loss: 2.0839 - accuracy: 0.1094
# 2.642286625775424
# trained image count:  10688
# Images Left:  13312
# Estimated completion time:  0:09:09.595618
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 168ms/step - loss: 2.0647 - accuracy: 0.2031
# Epoch 2/11
# 16/16 [==============================] - 3s 163ms/step - loss: 2.0624 - accuracy: 0.2031
# Epoch 3/11
# 16/16 [==============================] - 3s 167ms/step - loss: 2.0605 - accuracy: 0.2031
# Epoch 4/11
# 16/16 [==============================] - 3s 161ms/step - loss: 2.0579 - accuracy: 0.2031
# Epoch 5/11
# 16/16 [==============================] - 3s 162ms/step - loss: 2.0557 - accuracy: 0.2031
# Epoch 6/11
# 16/16 [==============================] - 3s 165ms/step - loss: 2.0535 - accuracy: 0.2031
# Epoch 7/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0511 - accuracy: 0.2031
# Epoch 8/11
# 16/16 [==============================] - 3s 173ms/step - loss: 2.0490 - accuracy: 0.2031
# Epoch 9/11
# 16/16 [==============================] - 3s 165ms/step - loss: 2.0469 - accuracy: 0.2031
# Epoch 10/11
# 16/16 [==============================] - 3s 162ms/step - loss: 2.0449 - accuracy: 0.2031
# Epoch 11/11
# 16/16 [==============================] - 3s 165ms/step - loss: 2.0426 - accuracy: 0.2031
# 2.6363786567341196
# trained image count:  10752
# Images Left:  13248
# Estimated completion time:  0:09:05.730382
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 166ms/step - loss: 2.1040 - accuracy: 0.0781
# Epoch 2/11
# 16/16 [==============================] - 3s 166ms/step - loss: 2.1027 - accuracy: 0.0781
# Epoch 3/11
# 16/16 [==============================] - 3s 161ms/step - loss: 2.1014 - accuracy: 0.0781
# Epoch 4/11
# 16/16 [==============================] - 3s 166ms/step - loss: 2.0998 - accuracy: 0.0625
# Epoch 5/11
# 16/16 [==============================] - 3s 165ms/step - loss: 2.0983 - accuracy: 0.1250
# Epoch 6/11
# 16/16 [==============================] - 3s 164ms/step - loss: 2.0971 - accuracy: 0.1250
# Epoch 7/11
# 16/16 [==============================] - 3s 164ms/step - loss: 2.0952 - accuracy: 0.1250
# Epoch 8/11
# 16/16 [==============================] - 3s 172ms/step - loss: 2.0939 - accuracy: 0.1250
# Epoch 9/11
# 16/16 [==============================] - 3s 164ms/step - loss: 2.0926 - accuracy: 0.1250
# Epoch 10/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0913 - accuracy: 0.1250
# Epoch 11/11
# 16/16 [==============================] - 3s 164ms/step - loss: 2.0901 - accuracy: 0.1250
# 2.6394973668185147
# trained image count:  10816
# Images Left:  13184
# Estimated completion time:  0:09:03.736458
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 164ms/step - loss: 2.0723 - accuracy: 0.1562
# Epoch 2/11
# 16/16 [==============================] - 3s 162ms/step - loss: 2.0721 - accuracy: 0.1562
# Epoch 3/11
# 16/16 [==============================] - 3s 166ms/step - loss: 2.0719 - accuracy: 0.1562
# Epoch 4/11
# 16/16 [==============================] - 3s 164ms/step - loss: 2.0716 - accuracy: 0.1562
# Epoch 5/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0711 - accuracy: 0.1562
# Epoch 6/11
# 16/16 [==============================] - 3s 162ms/step - loss: 2.0710 - accuracy: 0.1562
# Epoch 7/11
# 16/16 [==============================] - 3s 167ms/step - loss: 2.0706 - accuracy: 0.1562
# Epoch 8/11
# 16/16 [==============================] - 3s 164ms/step - loss: 2.0705 - accuracy: 0.1562
# Epoch 9/11
# 16/16 [==============================] - 3s 165ms/step - loss: 2.0702 - accuracy: 0.1562
# Epoch 10/11
# 16/16 [==============================] - 3s 162ms/step - loss: 2.0701 - accuracy: 0.1562
# Epoch 11/11
# 16/16 [==============================] - 3s 163ms/step - loss: 2.0697 - accuracy: 0.1562
# 2.617664423855868
# trained image count:  10880
# Images Left:  13120
# Estimated completion time:  0:08:56.621207
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 163ms/step - loss: 2.0704 - accuracy: 0.1406
# Epoch 2/11
# 16/16 [==============================] - 3s 165ms/step - loss: 2.0697 - accuracy: 0.1406
# Epoch 3/11
# 16/16 [==============================] - 3s 165ms/step - loss: 2.0688 - accuracy: 0.1406
# Epoch 4/11
# 16/16 [==============================] - 3s 164ms/step - loss: 2.0680 - accuracy: 0.1406
# Epoch 5/11
# 16/16 [==============================] - 3s 168ms/step - loss: 2.0672 - accuracy: 0.1406
# Epoch 6/11
# 16/16 [==============================] - 3s 164ms/step - loss: 2.0664 - accuracy: 0.1406
# Epoch 7/11
# 16/16 [==============================] - 3s 164ms/step - loss: 2.0655 - accuracy: 0.1406
# Epoch 8/11
# 16/16 [==============================] - 3s 164ms/step - loss: 2.0646 - accuracy: 0.1406
# Epoch 9/11
# 16/16 [==============================] - 3s 170ms/step - loss: 2.0641 - accuracy: 0.1406
# Epoch 10/11
# 16/16 [==============================] - 3s 166ms/step - loss: 2.0632 - accuracy: 0.1406
# Epoch 11/11
# 16/16 [==============================] - 3s 161ms/step - loss: 2.0625 - accuracy: 0.1406
# 2.636073350906372
# trained image count:  10944
# Images Left:  13056
# Estimated completion time:  0:08:57.758964
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 161ms/step - loss: 2.0886 - accuracy: 0.0938
# Epoch 2/11
# 16/16 [==============================] - 3s 164ms/step - loss: 2.0882 - accuracy: 0.0938
# Epoch 3/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0877 - accuracy: 0.0938
# Epoch 4/11
# 16/16 [==============================] - 3s 162ms/step - loss: 2.0870 - accuracy: 0.0938
# Epoch 5/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0862 - accuracy: 0.0938
# Epoch 6/11
# 16/16 [==============================] - 3s 170ms/step - loss: 2.0855 - accuracy: 0.0938
# Epoch 7/11
# 16/16 [==============================] - 3s 162ms/step - loss: 2.0850 - accuracy: 0.0938
# Epoch 8/11
# 16/16 [==============================] - 3s 163ms/step - loss: 2.0841 - accuracy: 0.0938
# Epoch 9/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0837 - accuracy: 0.0938
# Epoch 10/11
# 16/16 [==============================] - 3s 163ms/step - loss: 2.0829 - accuracy: 0.0938
# Epoch 11/11
# 16/16 [==============================] - 3s 165ms/step - loss: 2.0825 - accuracy: 0.0625
# 2.598303729837591
# trained image count:  11008
# Images Left:  12992
# Estimated completion time:  0:08:47.455657
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0879 - accuracy: 0.1250
# Epoch 2/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0877 - accuracy: 0.1250
# Epoch 3/11
# 16/16 [==============================] - 3s 163ms/step - loss: 2.0872 - accuracy: 0.1250
# Epoch 4/11
# 16/16 [==============================] - 3s 161ms/step - loss: 2.
# Epoch 11/11
# 16/16 [==============================] - 3s 167ms/step - loss: 2.0709 - accuracy: 0.1719
# 2.6733433333310215
# trained image count:  11200
# Images Left:  12800
# Estimated completion time:  0:08:54.668667
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 169ms/step - loss: 2.0911 - accuracy: 0.0938
# Epoch 2/11
# 16/16 [==============================] - 3s 167ms/step - loss: 2.0899 - accuracy: 0.0938
# Epoch 3/11
# 16/16 [==============================] - 3s 167ms/step - loss: 2.0886 - accuracy: 0.0938
# Epoch 4/11
# 16/16 [==============================] - 3s 165ms/step - loss: 2.0875 - accuracy: 0.0938
# Epoch 5/11
# 16/16 [==============================] - 3s 168ms/step - loss: 2.0861 - accuracy: 0.0938
# Epoch 6/11
#  2/16 [==>...........................] - ETA: 2s - loss: 2.0744 - accuracy: 0.0000e+00

# %% [markdown]
# ### Reference

# %%
# Default Train and Test function
def TrainAndTest(modelName):
  """Train and test a model. This function's input should be customized to accept different parameters, function body should be customized to these parameters to train models of variety of paramters.

  Args:
      modelName (str): name of model
  """
  pretrained_model = tf.keras.applications.MobileNetV3Large(input_shape=(224,224,3)) # Initializing model with mobile net V3 pretrained model

  # Initializing the input and output from the model, removing last layer
  base_input = pretrained_model.layers[0].input
  base_output = pretrained_model.layers[-2].output

  #-------------------------------------------------
  # Customizing layers
  #-------------------------------------------------
  # Adding 3 more layers to output side
  final_output = layers.Dense(128)(base_output) # Adding new layers, to the output side
  final_output = layers.Activation('relu')(final_output) # activating layer
  final_output = layers.Dense(8, activation = 'softmax')(final_output) # 8 cuz there are 8 image classifications

  model = keras.Model(inputs = base_input, outputs = final_output)
  model.compile(loss = "sparse_categorical_crossentropy", optimizer = "adam", metrics=["accuracy"])

  # ------------------ Training Model ------------------
  time_callback = TimeHistory()
  dataSet = mainTrainSet.copy()

  # Initializing model fit params
  batchSize = 4
  imgPerIter = batchSize*16

  count = 0
  while(len(dataSet) != 0):
    croppedList = []
    try:
      print("loading image") # Crop and load images in
      croppedList = CropData(dataSet, imgPerIter)
      label, data = LoadImages(TRAINIMAGEPATH, croppedList)
      
      # Training model
      model.fit(data, label, epochs = 11, batch_size = batchSize, callbacks = [time_callback])
      print(time_callback.AverageTime())
    except RuntimeError as e:
      print(e)
    
    # Saving weights
    model.save_weights('{}.h5'.format(modelName))
    
    # Print summary of current iteration
    count = count + len(croppedList)
    timeLeft = len(dataSet)/imgPerIter * time_callback.AverageTime()
    print("trained image count: ", count)
    print("Images Left: ", len(dataSet))
    print("Estimated completion time: ", str(timedelta(seconds=timeLeft)))
    
    reset_keras()
  print("---------------- {} Training Completed ------------------".format(modelName))

  # ---------------- Testing Model -----------------
  # initialise image names and label
  testSetData = mainTrainSet.copy()

  # test model
  loss, accuracy = TestModel(model, mainTrainSet.copy())
  
  # Saving test informations
  modelSummary = '''
  model name: {}
  average lost: {}
  average accuracy: {}
            '''.format(modelName, loss, accuracy)
      
  print("==========FINISH TESTING===========\n{}".format(modelSummary))
  
  file = open("training_summaries.txt", "a")
  file.write(modelSummary + "\n\n")
