# %% [markdown]
# ### Setup & Functions

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
tf.config.run_functions_eagerly(True)
tf.data.experimental.enable_debug_mode()
import cv2
import matplotlib.pyplot as plt
import random
from keras.backend import clear_session
from keras.backend import get_session
import time
from datetime import timedelta 
os.chdir("..\\asset") # change working directory

# %%
emotionList = ('Neutral', 'Happy', 'Sad', 'Surprise', 'Fear', 'Disgust', 'Anger', 'Contempt')
TRAINANNOTATIONPATH = "train_set\\annotations\\"
TRAINIMAGEPATH = "train_set\\images\\"
TESTANNOTATIONPATH = "val_set\\annotations\\"
TESTIMAGEPATH = "val_set\\images\\"

def LoadAllImageNames(filePath, limit = 0, catLimit = []):
  """Load the images names and label in tuple format (label, image name)

  Args:
      filePath (str): directory of image folder
      limit (int, optional): max number of image to load. Defaults to 0.
      catLimit (list<int>, optional): array of image count limit for each class. Defaults to []*8.

  Returns:
      list<str>: shuffled list of image names
  """
  limitCounter = [0,0,0,0,0,0,0,0]
  dataSet = []
  loadCounter = 0
  for file in os.scandir(filePath):
    if (limit > 0 and loadCounter > limit):
      break
  
    name = file.name[:-4] # file name w/o file extension
    data = np.load("{}{}_exp.npy".format(TRAINANNOTATIONPATH if filePath == TRAINIMAGEPATH else TESTANNOTATIONPATH, name)) # 
    label = int(data.item(0))

    if len(catLimit) > 0 and limitCounter[label] >= catLimit[label]:
        continue
    limitCounter[label] += 1
    loadCounter += 1

    dataSet.append((label, file.name))
    if (loadCounter%10000==0):
      print("Files loaded:{}".format(loadCounter))
  
  print("Total images loaded: ", loadCounter)
  print("Images Loaded: ", limitCounter)
  random.shuffle(dataSet)
  return dataSet

# Load the pixels of a picture to numpy.ndarray format. false for test set, true for training set
# Return image in RGB format
def LoadImage(imagePath, imageName, normalize = True):
  """Load image using numpy

  Args:
      imagePath (str): image path 
      imageName (str): image name
      normalize (bool, optional): To normalize image or not. Defaults to True.

  Returns:
      numpy array: x,y,3 array
  """
  # print("{}{}{}".format(os.getcwd(), "\\"+imagePath, imageName))
  image_array = cv2.imread("{}{}{}".format(os.getcwd(), "\\"+imagePath, imageName))
  image_array = cv2.cvtColor(image_array, cv2.COLOR_BGR2RGB)
  if normalize:
    image_array = image_array/255
    
  return image_array

# Extract the daata from 0 to amount from list and return it
def CropData(list, amount):
  if (len(list) < amount):
    amount = len(list)
  croppedList = list[:amount]
  del list[:amount]
  return croppedList

def LoadImages(imagePath, list):
  label = []
  data = []
  count = 0
  for entries in list:
    try:
      image = LoadImage(imagePath, entries[1])
      data.append(image) 
      label.append(entries[0]) 
    except: 
      print("Failed to load training image: ", entries[1])
  npLabel = np.array(label) 
  npData = np.array(data) 
  return npLabel, npData 

def InitializeModel():
  pretrained_model = tf.keras.applications.MobileNetV3Large(input_shape=(224,224,3)) # Initializing model with mobile net V3 pretrained model

  # Initializing the input and output from the model, removing last layer
  base_input = pretrained_model.layers[0].input
  base_output = pretrained_model.layers[-2].output

  # Adding 3 more layers to output side
  final_output = layers.Dense(128)(base_output) # Adding new layers, to the output side
  final_output = layers.Activation('relu')(final_output) # activating layer
  final_output = layers.Dense(64)(final_output)
  final_output = layers.Activation('relu')(final_output) # activating layer
  final_output = layers.Dense(8, activation = 'softmax')(final_output) # 8 cuz there are 8 image classifications

  new_model = keras.Model(inputs = base_input, outputs = final_output)
  # new_model.summary()
  return new_model

def ConvertToGray(image):
  image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
  image = cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)
  return image

def ScaleImage(image, width):
  ratio = image.shape[1]/width
  image = cv2.resize(image, (width, int(image.shape[0]/ratio)))
  return image

def DetectFace(image):
  face_roi = np.ndarray(1)
  faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
  grayImage = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
  faces = faceCascade.detectMultiScale(grayImage, 1.3, 5)
  for x,y,w,h in faces:
    roi_gray = grayImage[y:y+h, x:x+w]
    roi_color = image[y:y+h, x:x+w]
    cv2.rectangle(image, (x,y), (x+w, y+h), (255,0,0), 2)
    facess = faceCascade.detectMultiScale(roi_gray)
    if (len(facess) == 0):
      print("Face not detected")
    else:
      for (ex,ey,ew,eh) in facess:
        face_roi = roi_color[ey:ey+eh, ex:ex+ew]
  return face_roi

def ConvertToInput(image):
  input = ScaleImage(image, 224)
  input = np.expand_dims(input, axis = 0) ## to add fourth dimension to fit model input
  input = input/255
  return input

def GetResult(model, input):
  Predictions = model.predict(input)
  print(Predictions)
  result = np.argmax(Predictions)
  return emotionList[result]

def printDataSetLabels(dataSet):
    counterList = list(range(8))
    for label, name in dataSet:
        counterList[label] += 1
    print(counterList)
    
# Reset Keras Session
def reset_keras():
    sess = get_session()
    clear_session()
    sess.close()
    sess = get_session()

    # try:
    #     del classifier # this is from global space - change this as you need
    # except:
    #     pass

    # use the same config as you used to create the session
    tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.9, visible_device_list="0")
    
def TestModel(model, testSetData):
  # test model
  lostSum = 0
  accuracySum = 0
  count = 0
  while(len(testSetData) != 0):
    # training data
    try:
      croppedList = CropData(testSetData, 100)
      label, data = LoadImages(TESTIMAGEPATH, croppedList)
      result = model.evaluate(data, label, batch_size = 1)
      lostSum += result[0]
      accuracySum += result[1]
    except:
      print("Failed to train data")

    count += 1
    reset_keras()
  
  return lostSum/count, accuracySum/count

class TimeHistory(keras.callbacks.Callback):
  def on_train_begin(self, logs={}):
    self.times = []

  def on_epoch_begin(self, batch, logs={}):
    self.epoch_time_start = time.time()

  def on_epoch_end(self, batch, logs={}):
    self.times.append(time.time() - self.epoch_time_start)

  def AverageTime(self):
    sum = 0
    for time in self.times:
      sum += time
    return sum/len(self.times)

# %% [markdown]
# ### Data Processing

# %%
mainTrainSet = LoadAllImageNames(TRAINIMAGEPATH, catLimit=[1000]*8)
mainTestSet = LoadAllImageNames(TESTIMAGEPATH)
# Out:
# Total images loaded:  8000
# Images Loaded:  [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000]
# Total images loaded:  3999
# Images Loaded:  [500, 500, 500, 500, 500, 500, 500, 499]

# %% [markdown]
# ### Model prepping
# Change the pretrained model and layers here

# %%
def SingleLayerTrainAndTest(modelName, batchSize, firstLayerSize):
  """Train and test a model. This function's input should be customized to accept different parameters, function body should be customized to these parameters to train models of variety of paramters.

  Args:
      modelName (str): name of model
  """
  pretrained_model = tf.keras.applications.MobileNetV3Large(input_shape=(224,224,3)) # Initializing model with mobile net V3 pretrained model

  # Initializing the input and output from the model, removing last layer
  base_input = pretrained_model.layers[0].input
  base_output = pretrained_model.layers[-2].output

  #-------------------------------------------------
  # Customizing layers
  #-------------------------------------------------
  # Adding 3 more layers to output side
  final_output = layers.Dense(firstLayerSize)(base_output) # Adding new layers, to the output side
  final_output = layers.Activation('relu')(final_output) # activating layer
  final_output = layers.Dense(8, activation = 'softmax')(final_output) # 8 cuz there are 8 image classifications

  model = keras.Model(inputs = base_input, outputs = final_output)
  model.compile(loss = "sparse_categorical_crossentropy", optimizer = "adam", metrics=["accuracy"])

  # ------------------ Training Model ------------------
  time_callback = TimeHistory()
  dataSet = mainTestSet.copy()

  # Initializing model fit params
  # batchSize = 4
  imgPerIter = batchSize*16

  count = 0
  while(len(dataSet) != 0):
    croppedList = []
    try:
      print("loading image") # Crop and load images in
      croppedList = CropData(dataSet, imgPerIter)
      label, data = LoadImages(TRAINIMAGEPATH, croppedList)
      
      # Training model
      model.fit(data, label, epochs = 11, batch_size = batchSize, callbacks = [time_callback])
      print(time_callback.AverageTime())
    except RuntimeError as e:
      print(e)
    
    # Saving weights
    model.save_weights('{}.h5'.format(modelName))
    
    # Print summary of current iteration
    count = count + len(croppedList)
    timeLeft = len(dataSet)/imgPerIter * time_callback.AverageTime()
    print("trained image count: ", count)
    print("Images Left: ", len(dataSet))
    print("Estimated completion time: ", str(timedelta(seconds=timeLeft)))
    
    reset_keras()
  print("---------------- {} Training Completed ------------------".format(modelName))

  # ---------------- Testing Model -----------------
  # initialise image names and label
  testSetData = mainTrainSet.copy()

  # test model
  loss, accuracy = TestModel(model, mainTrainSet.copy())
  
  # Saving test informations
  modelSummary = '''
  model name: {}
  average lost: {}
  average accuracy: {}
            '''.format(modelName, loss, accuracy)
      
  print("==========FINISH TESTING===========\n{}".format(modelSummary))
  
  file = open("training_summaries.txt", "a")
  file.write(modelSummary + "\n\n")

# %%
batchSizes = [4, 8, 16, 32, 48]
firstLayerSizes = [128, 256, 384, 516, 772]

';i0p0'
for batchSize in batchSizes:
    for firstLayerSize in firstLayerSizes:
        modelName = "bs{}_fls{}.h".format(batchSize, firstLayerSize)
        SingleLayerTrainAndTest(modelName, batchSize, firstLayerSize)
# Out:
# loading image
# Epoch 1/11
# 16/16 [==============================] - 6s 152ms/step - loss: 2.9879 - accuracy: 0.1875
# Epoch 2/11
# 16/16 [==============================] - 3s 162ms/step - loss: 2.2598 - accuracy: 0.3906
# Epoch 3/11
# 16/16 [==============================] - 2s 155ms/step - loss: 1.3891 - accuracy: 0.5000
# Epoch 4/11
# 16/16 [==============================] - 2s 151ms/step - loss: 0.8989 - accuracy: 0.7188
# Epoch 5/11
# 16/16 [==============================] - 2s 151ms/step - loss: 1.0848 - accuracy: 0.6875
# Epoch 6/11
# 16/16 [==============================] - 3s 157ms/step - loss: 1.0790 - accuracy: 0.7031
# Epoch 7/11
# 16/16 [==============================] - 2s 155ms/step - loss: 1.5175 - accuracy: 0.6406
# Epoch 8/11
# 16/16 [==============================] - 2s 155ms/step - loss: 1.0060 - accuracy: 0.6406
# Epoch 9/11
# 16/16 [==============================] - 2s 155ms/step - loss: 0.5548 - accuracy: 0.8750
# Epoch 10/11
# 16/16 [==============================] - 3s 158ms/step - loss: 0.6128 - accuracy: 0.8438
# Epoch 11/11
# 16/16 [==============================] - 2s 153ms/step - loss: 0.6880 - accuracy: 0.8125
# 2.8110259012742476
# trained image count:  64
# Images Left:  7936
# Estimated completion time:  0:05:48.567212
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 168ms/step - loss: 2.9466 - accuracy: 0.1094
# Epoch 2/11
# 16/16 [==============================] - 3s 160ms/step - loss: 1.7558 - accuracy: 0.3281
# Epoch 3/11
# 16/16 [==============================] - 3s 159ms/step - loss: 1.5078 - accuracy: 0.4375
# Epoch 4/11
# 16/16 [==============================] - 2s 156ms/step - loss: 1.3369 - accuracy: 0.5000
# Epoch 5/11
# 16/16 [==============================] - 3s 157ms/step - loss: 1.1994 - accuracy: 0.5469
# Epoch 6/11
# 16/16 [==============================] - 3s 156ms/step - loss: 0.8413 - accuracy: 0.7031
# Epoch 7/11
# 16/16 [==============================] - 3s 161ms/step - loss: 1.0054 - accuracy: 0.6719
# Epoch 8/11
# 16/16 [==============================] - 2s 154ms/step - loss: 1.4368 - accuracy: 0.5156
# Epoch 9/11
# 16/16 [==============================] - 3s 158ms/step - loss: 1.0243 - accuracy: 0.7031
# Epoch 10/11
# 16/16 [==============================] - 2s 154ms/step - loss: 0.8485 - accuracy: 0.6719
# Epoch 11/11
# 16/16 [==============================] - 2s 152ms/step - loss: 1.2540 - accuracy: 0.5938
# 2.5259768962860107
# trained image count:  128
# Images Left:  7872
# Estimated completion time:  0:05:10.695158
# loading image
# Epoch 1/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.5807 - accuracy: 0.1094
# Epoch 2/11
# 16/16 [==============================] - 3s 156ms/step - loss: 2.1138 - accuracy: 0.1406
# Epoch 3/11
# 16/16 [==============================] - 3s 156ms/step - loss: 2.0493 - accuracy: 0.1875
# Epoch 4/11
# 16/16 [==============================] - 2s 151ms/step - loss: 2.0569 - accuracy: 0.2969
# Epoch 5/11
# 16/16 [==============================] - 3s 157ms/step - loss: 1.7995 - accuracy: 0.2656
# Epoch 6/11
# 16/16 [==============================] - 2s 155ms/step - loss: 1.9769 - accuracy: 0.2656
# Epoch 7/11
# 16/16 [==============================] - 2s 151ms/step - loss: 1.9445 - accuracy: 0.2031
# Epoch 8/11
# 16/16 [==============================] - 3s 166ms/step - loss: 1.9173 - accuracy: 0.2969
# Epoch 9/11
# 16/16 [==============================] - 2s 153ms/step - loss: 1.8282 - accuracy: 0.3281
# Epoch 10/11
# 16/16 [==============================] - 3s 158ms/step - loss: 1.5758 - accuracy: 0.3594
# Epoch 11/11
# 16/16 [==============================] - 2s 155ms/step - loss: 1.4458 - accuracy: 0.4844
# 2.494512427936901
# trained image count:  192
# Images Left:  7808
# Estimated completion time:  0:05:04.330516
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.4243 - accuracy: 0.1562
# Epoch 2/11
# 16/16 [==============================] - 2s 155ms/step - loss: 1.9130 - accuracy: 0.1719
# Epoch 3/11
# 16/16 [==============================] - 3s 160ms/step - loss: 1.9293 - accuracy: 0.2656
# Epoch 4/11
# 16/16 [==============================] - 2s 154ms/step - loss: 1.8272 - accuracy: 0.4219
# Epoch 5/11
# 16/16 [==============================] - 3s 159ms/step - loss: 1.6068 - accuracy: 0.4219
# Epoch 6/11
# 16/16 [==============================] - 2s 154ms/step - loss: 1.5993 - accuracy: 0.4219
# Epoch 7/11
# 16/16 [==============================] - 2s 152ms/step - loss: 1.8129 - accuracy: 0.4531
# Epoch 8/11
# 16/16 [==============================] - 3s 167ms/step - loss: 1.8262 - accuracy: 0.3906
# Epoch 9/11
# 16/16 [==============================] - 2s 154ms/step - loss: 1.9416 - accuracy: 0.3750
# Epoch 10/11
# 16/16 [==============================] - 3s 158ms/step - loss: 1.7696 - accuracy: 0.2812
# Epoch 11/11
# 16/16 [==============================] - 3s 157ms/step - loss: 1.6155 - accuracy: 0.3750
# 2.5114470178430732
# trained image count:  256
# Images Left:  7744
# Estimated completion time:  0:05:03.885089
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.3023 - accuracy: 0.0469
# Epoch 2/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0897 - accuracy: 0.0938
# Epoch 3/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.1436 - accuracy: 0.1562
# Epoch 4/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0844 - accuracy: 0.0781
# Epoch 5/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0850 - accuracy: 0.0781
# Epoch 6/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0815 - accuracy: 0.0781
# Epoch 7/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0800 - accuracy: 0.0938
# Epoch 8/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0787 - accuracy: 0.2031
# Epoch 9/11
# 16/16 [==============================] - 2s 150ms/step - loss: 2.0774 - accuracy: 0.2031
# Epoch 10/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0759 - accuracy: 0.2031
# Epoch 11/11
# 16/16 [==============================] - 2s 151ms/step - loss: 2.0748 - accuracy: 0.2031
# 2.4839634245092217
# trained image count:  320
# Images Left:  7680
# Estimated completion time:  0:04:58.075611
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0817 - accuracy: 0.1250
# Epoch 2/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0809 - accuracy: 0.1250
# Epoch 3/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0803 - accuracy: 0.1250
# Epoch 4/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0795 - accuracy: 0.1250
# Epoch 5/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0787 - accuracy: 0.1250
# Epoch 6/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0780 - accuracy: 0.1250
# Epoch 7/11
# 16/16 [==============================] - 3s 163ms/step - loss: 2.0773 - accuracy: 0.1250
# Epoch 8/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0767 - accuracy: 0.1250
# Epoch 9/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0759 - accuracy: 0.1250
# Epoch 10/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0753 - accuracy: 0.1250
# Epoch 11/11
# 16/16 [==============================] - 2s 151ms/step - loss: 2.0748 - accuracy: 0.1250
# 2.4906406619332055
# trained image count:  384
# Images Left:  7616
# Estimated completion time:  0:04:56.386239
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0899 - accuracy: 0.0938
# Epoch 2/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0881 - accuracy: 0.0938
# Epoch 3/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.0859 - accuracy: 0.0938
# Epoch 4/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0832 - accuracy: 0.0938
# Epoch 5/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0809 - accuracy: 0.0938
# Epoch 6/11
# 16/16 [==============================] - 3s 162ms/step - loss: 2.0783 - accuracy: 0.2500
# Epoch 7/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0764 - accuracy: 0.2344
# Epoch 8/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0738 - accuracy: 0.2344
# Epoch 9/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0717 - accuracy: 0.2344
# Epoch 10/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0695 - accuracy: 0.2344
# Epoch 11/11
# 16/16 [==============================] - 3s 156ms/step - loss: 2.0677 - accuracy: 0.2344
# 2.5117029276761142
# trained image count:  448
# Images Left:  7552
# Estimated completion time:  0:04:56.380945
# loading image
# Epoch 1/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0727 - accuracy: 0.1719
# Epoch 2/11
# 16/16 [==============================] - 2s 149ms/step - loss: 2.0708 - accuracy: 0.1719
# Epoch 3/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0685 - accuracy: 0.1719
# Epoch 4/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0664 - accuracy: 0.1719
# Epoch 5/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0646 - accuracy: 0.1719
# Epoch 6/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0626 - accuracy: 0.1719
# Epoch 7/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0604 - accuracy: 0.1719
# Epoch 8/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0589 - accuracy: 0.1719
# Epoch 9/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0570 - accuracy: 0.1719
# Epoch 10/11
# 16/16 [==============================] - 2s 151ms/step - loss: 2.0551 - accuracy: 0.1719
# Epoch 11/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0534 - accuracy: 0.1719
# 2.4570318568836558
# trained image count:  512
# Images Left:  7488
# Estimated completion time:  0:04:47.472727
# loading image
# Epoch 1/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0750 - accuracy: 0.2031
# Epoch 2/11
# 16/16 [==============================] - 3s 162ms/step - loss: 2.0733 - accuracy: 0.2031
# Epoch 3/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0715 - accuracy: 0.2031
# Epoch 4/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.0694 - accuracy: 0.2031
# Epoch 5/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0676 - accuracy: 0.2031
# Epoch 6/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0655 - accuracy: 0.2031
# Epoch 7/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0640 - accuracy: 0.2031
# Epoch 8/11
# 16/16 [==============================] - 2s 151ms/step - loss: 2.0619 - accuracy: 0.2031
# Epoch 9/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.0602 - accuracy: 0.2031
# Epoch 10/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0584 - accuracy: 0.2031
# Epoch 11/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0568 - accuracy: 0.2031
# 2.4914006103168833
# trained image count:  576
# Images Left:  7424
# Estimated completion time:  0:04:49.002471
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0835 - accuracy: 0.1250
# Epoch 2/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0831 - accuracy: 0.1250
# Epoch 3/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.0826 - accuracy: 0.1250
# Epoch 4/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0814 - accuracy: 0.1250
# Epoch 5/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0809 - accuracy: 0.1250
# Epoch 6/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.0802 - accuracy: 0.1250
# Epoch 7/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0795 - accuracy: 0.1250
# Epoch 8/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.0791 - accuracy: 0.1250
# Epoch 9/11
# 16/16 [==============================] - 3s 164ms/step - loss: 2.0781 - accuracy: 0.1250
# Epoch 10/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0775 - accuracy: 0.1250
# Epoch 11/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0771 - accuracy: 0.1250
# 2.5195684216239234
# trained image count:  640
# Images Left:  7360
# Estimated completion time:  0:04:49.750368
# loading image
# Epoch 1/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0660 - accuracy: 0.1875
# Epoch 2/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0655 - accuracy: 0.1875
# Epoch 3/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.0651 - accuracy: 0.1875
# Epoch 4/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0646 - accuracy: 0.1875
# Epoch 5/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0641 - accuracy: 0.1875
# Epoch 6/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0637 - accuracy: 0.1875
# Epoch 7/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0630 - accuracy: 0.1875
# Epoch 8/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0626 - accuracy: 0.1875
# Epoch 9/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0621 - accuracy: 0.1875
# Epoch 10/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0618 - accuracy: 0.1875
# Epoch 11/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0613 - accuracy: 0.1875
# 2.498136953874068
# trained image count:  704
# Images Left:  7296
# Estimated completion time:  0:04:44.787613
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.1097 - accuracy: 0.0312
# Epoch 2/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.1079 - accuracy: 0.0312
# Epoch 3/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.1056 - accuracy: 0.0312
# Epoch 4/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.1030 - accuracy: 0.0312
# Epoch 5/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.1008 - accuracy: 0.0312
# Epoch 6/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.0984 - accuracy: 0.0312
# Epoch 7/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0960 - accuracy: 0.0312
# Epoch 8/11
# 16/16 [==============================] - 3s 165ms/step - loss: 2.0941 - accuracy: 0.0312
# Epoch 9/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.0917 - accuracy: 0.0312
# Epoch 10/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0897 - accuracy: 0.0312
# Epoch 11/11
# 16/16 [==============================] - 3s 165ms/step - loss: 2.0876 - accuracy: 0.0312
# 2.534058094024658
# trained image count:  768
# Images Left:  7232
# Estimated completion time:  0:04:46.348565
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 170ms/step - loss: 2.0882 - accuracy: 0.0781
# Epoch 2/11
# 16/16 [==============================] - 3s 161ms/step - loss: 2.0873 - accuracy: 0.0938
# Epoch 3/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0859 - accuracy: 0.1094
# Epoch 4/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0851 - accuracy: 0.1094
# Epoch 5/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0836 - accuracy: 0.1094
# Epoch 6/11
# 16/16 [==============================] - 3s 166ms/step - loss: 2.0827 - accuracy: 0.1094
# Epoch 7/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0818 - accuracy: 0.1094
# Epoch 8/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0806 - accuracy: 0.1094
# Epoch 9/11
# 16/16 [==============================] - 3s 163ms/step - loss: 2.0797 - accuracy: 0.1094
# Epoch 10/11
# 16/16 [==============================] - 2s 150ms/step - loss: 2.0787 - accuracy: 0.1094
# Epoch 11/11
# 16/16 [==============================] - 2s 150ms/step - loss: 2.0781 - accuracy: 0.1094
# 2.5351043180985884
# trained image count:  832
# Images Left:  7168
# Estimated completion time:  0:04:43.931684
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 156ms/step - loss: 2.0800 - accuracy: 0.1094
# Epoch 2/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0792 - accuracy: 0.1094
# Epoch 3/11
# 16/16 [==============================] - 2s 150ms/step - loss: 2.0784 - accuracy: 0.2031
# Epoch 4/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0774 - accuracy: 0.2031
# Epoch 5/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0763 - accuracy: 0.2031
# Epoch 6/11
# 16/16 [==============================] - 2s 149ms/step - loss: 2.0754 - accuracy: 0.2031
# Epoch 7/11
# 16/16 [==============================] - 3s 163ms/step - loss: 2.0745 - accuracy: 0.2031
# Epoch 8/11
# 16/16 [==============================] - 2s 149ms/step - loss: 2.0736 - accuracy: 0.2031
# Epoch 9/11
# 16/16 [==============================] - 2s 150ms/step - loss: 2.0728 - accuracy: 0.2031
# Epoch 10/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0719 - accuracy: 0.2031
# Epoch 11/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0712 - accuracy: 0.2031
# 2.448783441023393
# trained image count:  896
# Images Left:  7104
# Estimated completion time:  0:04:31.814962
# loading image
# Epoch 1/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0956 - accuracy: 0.0781
# Epoch 2/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0944 - accuracy: 0.0781
# Epoch 3/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0929 - accuracy: 0.0781
# Epoch 4/11
# 16/16 [==============================] - 2s 149ms/step - loss: 2.0913 - accuracy: 0.0781
# Epoch 5/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.0898 - accuracy: 0.0781
# Epoch 6/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0884 - accuracy: 0.0781
# Epoch 7/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0867 - accuracy: 0.0781
# Epoch 8/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0853 - accuracy: 0.0781
# Epoch 9/11
# 16/16 [==============================] - 2s 149ms/step - loss: 2.0838 - accuracy: 0.0781
# Epoch 10/11
# 16/16 [==============================] - 2s 151ms/step - loss: 2.0825 - accuracy: 0.1406
# Epoch 11/11
# 16/16 [==============================] - 2s 151ms/step - loss: 2.0812 - accuracy: 0.1719
# 2.454379428516735
# trained image count:  960
# Images Left:  7040
# Estimated completion time:  0:04:29.981737
# loading image
# Epoch 1/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0745 - accuracy: 0.1250
# Epoch 2/11
# 16/16 [==============================] - 2s 148ms/step - loss: 2.0737 - accuracy: 0.1250
# Epoch 3/11
# 16/16 [==============================] - 2s 147ms/step - loss: 2.0725 - accuracy: 0.1250
# Epoch 4/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0714 - accuracy: 0.1250
# Epoch 5/11
# 16/16 [==============================] - 2s 149ms/step - loss: 2.0704 - accuracy: 0.1250
# Epoch 6/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0694 - accuracy: 0.0938
# Epoch 7/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0685 - accuracy: 0.1719
# Epoch 8/11
# 16/16 [==============================] - 2s 149ms/step - loss: 2.0673 - accuracy: 0.1719
# Epoch 9/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0666 - accuracy: 0.1719
# Epoch 10/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0656 - accuracy: 0.1719
# Epoch 11/11
# 16/16 [==============================] - 2s 151ms/step - loss: 2.0644 - accuracy: 0.1719
# 2.4299884059212427
# trained image count:  1024
# Images Left:  6976
# Estimated completion time:  0:04:24.868736
# loading image
# Epoch 1/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0771 - accuracy: 0.1406
# Epoch 2/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0767 - accuracy: 0.1406
# Epoch 3/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0762 - accuracy: 0.1406
# Epoch 4/11
# 16/16 [==============================] - 2s 149ms/step - loss: 2.0757 - accuracy: 0.1406
# Epoch 5/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0753 - accuracy: 0.1406
# Epoch 6/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0749 - accuracy: 0.1406
# Epoch 7/11
# 16/16 [==============================] - 2s 149ms/step - loss: 2.0743 - accuracy: 0.1406
# Epoch 8/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0738 - accuracy: 0.1406
# Epoch 9/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0735 - accuracy: 0.1406
# Epoch 10/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0729 - accuracy: 0.1406
# Epoch 11/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0726 - accuracy: 0.1406
# 2.4638728445226494
# trained image count:  1088
# Images Left:  6912
# Estimated completion time:  0:04:26.098267
# loading image
# Epoch 1/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0942 - accuracy: 0.1250
# Epoch 2/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.0923 - accuracy: 0.1250
# Epoch 3/11
# 16/16 [==============================] - 3s 156ms/step - loss: 2.0901 - accuracy: 0.1250
# Epoch 4/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0876 - accuracy: 0.1250
# Epoch 5/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0852 - accuracy: 0.1250
# Epoch 6/11
# 16/16 [==============================] - 2s 149ms/step - loss: 2.0830 - accuracy: 0.1250
# Epoch 7/11
# 16/16 [==============================] - 2s 151ms/step - loss: 2.0806 - accuracy: 0.1250
# Epoch 8/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0786 - accuracy: 0.1250
# Epoch 9/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0765 - accuracy: 0.1250
# Epoch 10/11
# 16/16 [==============================] - 2s 150ms/step - loss: 2.0743 - accuracy: 0.1250
# Epoch 11/11
# 16/16 [==============================] - 2s 150ms/step - loss: 2.0726 - accuracy: 0.1250
# 2.4524620663036
# trained image count:  1152
# Images Left:  6848
# Estimated completion time:  0:04:22.413441
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 155ms/step - loss: 2.0846 - accuracy: 0.1094
# Epoch 2/11
# 16/16 [==============================] - 2s 149ms/step - loss: 2.0835 - accuracy: 0.1094
# Epoch 3/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0823 - accuracy: 0.1094
# Epoch 4/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0813 - accuracy: 0.1094
# Epoch 5/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0800 - accuracy: 0.1250
# Epoch 6/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0790 - accuracy: 0.1562
# Epoch 7/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0779 - accuracy: 0.1562
# Epoch 8/11
# 16/16 [==============================] - 2s 150ms/step - loss: 2.0772 - accuracy: 0.1562
# Epoch 9/11
# 16/16 [==============================] - 3s 156ms/step - loss: 2.0758 - accuracy: 0.1562
# Epoch 10/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.0749 - accuracy: 0.1562
# Epoch 11/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0739 - accuracy: 0.1562
# 2.465212345123291
# trained image count:  1216
# Images Left:  6784
# Estimated completion time:  0:04:21.312509
# loading image
# Epoch 1/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0733 - accuracy: 0.1406
# Epoch 2/11
# 16/16 [==============================] - 2s 149ms/step - loss: 2.0731 - accuracy: 0.1406
# Epoch 3/11
# 16/16 [==============================] - 2s 150ms/step - loss: 2.0728 - accuracy: 0.1406
# Epoch 4/11
# 16/16 [==============================] - 3s 164ms/step - loss: 2.0723 - accuracy: 0.1406
# Epoch 5/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0718 - accuracy: 0.1406
# Epoch 6/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0712 - accuracy: 0.1406
# Epoch 7/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0708 - accuracy: 0.1406
# Epoch 8/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.0705 - accuracy: 0.1406
# Epoch 9/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0700 - accuracy: 0.1406
# Epoch 10/11
# 16/16 [==============================] - 2s 151ms/step - loss: 2.0697 - accuracy: 0.1406
# Epoch 11/11
# 16/16 [==============================] - 3s 156ms/step - loss: 2.0693 - accuracy: 0.1406
# 2.4734577265652744
# trained image count:  1280
# Images Left:  6720
# Estimated completion time:  0:04:19.713061
# loading image
# Epoch 1/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0750 - accuracy: 0.1875
# Epoch 2/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0747 - accuracy: 0.1875
# Epoch 3/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0741 - accuracy: 0.1875
# Epoch 4/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0736 - accuracy: 0.1875
# Epoch 5/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0733 - accuracy: 0.1875
# Epoch 6/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0726 - accuracy: 0.1875
# Epoch 7/11
# 16/16 [==============================] - 2s 150ms/step - loss: 2.0721 - accuracy: 0.1875
# Epoch 8/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0718 - accuracy: 0.1875
# Epoch 9/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0713 - accuracy: 0.1875
# Epoch 10/11
# 16/16 [==============================] - 2s 151ms/step - loss: 2.0708 - accuracy: 0.1875
# Epoch 11/11
# 16/16 [==============================] - 2s 150ms/step - loss: 2.0703 - accuracy: 0.1875
# 2.448151870207353
# trained image count:  1344
# Images Left:  6656
# Estimated completion time:  0:04:14.607795
# loading image
# Epoch 1/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0953 - accuracy: 0.1250
# Epoch 2/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0936 - accuracy: 0.1250
# Epoch 3/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0915 - accuracy: 0.1250
# Epoch 4/11
# 16/16 [==============================] - 2s 149ms/step - loss: 2.0895 - accuracy: 0.1250
# Epoch 5/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0871 - accuracy: 0.1250
# Epoch 6/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.0852 - accuracy: 0.1250
# Epoch 7/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0829 - accuracy: 0.1250
# Epoch 8/11
# 16/16 [==============================] - 2s 151ms/step - loss: 2.0814 - accuracy: 0.1250
# Epoch 9/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0794 - accuracy: 0.1250
# Epoch 10/11
# 16/16 [==============================] - 2s 151ms/step - loss: 2.0773 - accuracy: 0.1250
# Epoch 11/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0756 - accuracy: 0.1250
# 2.4563930251381616
# trained image count:  1408
# Images Left:  6592
# Estimated completion time:  0:04:13.008482
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 156ms/step - loss: 2.0929 - accuracy: 0.0781
# Epoch 2/11
# 16/16 [==============================] - 2s 157ms/step - loss: 2.0913 - accuracy: 0.0781
# Epoch 3/11
# 16/16 [==============================] - 3s 163ms/step - loss: 2.0893 - accuracy: 0.0781
# Epoch 4/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0877 - accuracy: 0.0781
# Epoch 5/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0858 - accuracy: 0.0781
# Epoch 6/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0842 - accuracy: 0.0781
# Epoch 7/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0828 - accuracy: 0.0781
# Epoch 8/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0810 - accuracy: 0.0781
# Epoch 9/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0795 - accuracy: 0.0781
# Epoch 10/11
# 16/16 [==============================] - 2s 149ms/step - loss: 2.0779 - accuracy: 0.0781
# Epoch 11/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0764 - accuracy: 0.0781
# 2.472215760837902
# trained image count:  1472
# Images Left:  6528
# Estimated completion time:  0:04:12.166008
# loading image
# Epoch 1/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0818 - accuracy: 0.0625
# Epoch 2/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0806 - accuracy: 0.0625
# Epoch 3/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0798 - accuracy: 0.0938
# Epoch 4/11
# 16/16 [==============================] - 2s 151ms/step - loss: 2.0787 - accuracy: 0.0938
# Epoch 5/11
# 16/16 [==============================] - 2s 149ms/step - loss: 2.0776 - accuracy: 0.2031
# Epoch 6/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0767 - accuracy: 0.2031
# Epoch 7/11
# 16/16 [==============================] - 2s 151ms/step - loss: 2.0758 - accuracy: 0.2031
# Epoch 8/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0749 - accuracy: 0.2031
# Epoch 9/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0742 - accuracy: 0.2031
# Epoch 10/11
# 16/16 [==============================] - 2s 150ms/step - loss: 2.0730 - accuracy: 0.2031
# Epoch 11/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0723 - accuracy: 0.2031
# 2.440735188397494
# trained image count:  1536
# Images Left:  6464
# Estimated completion time:  0:04:06.514254
# loading image
# Epoch 1/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0856 - accuracy: 0.1719
# Epoch 2/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0842 - accuracy: 0.1719
# Epoch 3/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0822 - accuracy: 0.1719
# Epoch 4/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.0806 - accuracy: 0.1719
# Epoch 5/11
# 16/16 [==============================] - 2s 149ms/step - loss: 2.0785 - accuracy: 0.1719
# Epoch 6/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0769 - accuracy: 0.1719
# Epoch 7/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0751 - accuracy: 0.1719
# Epoch 8/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0737 - accuracy: 0.1719
# Epoch 9/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.0718 - accuracy: 0.1719
# Epoch 10/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0705 - accuracy: 0.1719
# Epoch 11/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0688 - accuracy: 0.1719
# 2.4744215228340845
# trained image count:  1600
# Images Left:  6400
# Estimated completion time:  0:04:07.442152
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 162ms/step - loss: 2.0840 - accuracy: 0.1250
# Epoch 2/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0835 - accuracy: 0.1250
# Epoch 3/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0826 - accuracy: 0.1250
# Epoch 4/11
# 16/16 [==============================] - 2s 151ms/step - loss: 2.0822 - accuracy: 0.1250
# Epoch 5/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0812 - accuracy: 0.1250
# Epoch 6/11
# 16/16 [==============================] - 2s 150ms/step - loss: 2.0806 - accuracy: 0.1250
# Epoch 7/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0799 - accuracy: 0.1250
# Epoch 8/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0792 - accuracy: 0.1250
# Epoch 9/11
# 16/16 [==============================] - 2s 151ms/step - loss: 2.0785 - accuracy: 0.1250
# Epoch 10/11
# 16/16 [==============================] - 2s 149ms/step - loss: 2.0779 - accuracy: 0.1250
# Epoch 11/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0772 - accuracy: 0.1250
# 2.4538628188046543
# trained image count:  1664
# Images Left:  6336
# Estimated completion time:  0:04:02.932419
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 161ms/step - loss: 2.0787 - accuracy: 0.1406
# Epoch 2/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0782 - accuracy: 0.1406
# Epoch 3/11
# 16/16 [==============================] - 2s 150ms/step - loss: 2.0782 - accuracy: 0.1406
# Epoch 4/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0777 - accuracy: 0.1406
# Epoch 5/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0773 - accuracy: 0.1406
# Epoch 6/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0772 - accuracy: 0.1406
# Epoch 7/11
# 16/16 [==============================] - 2s 150ms/step - loss: 2.0767 - accuracy: 0.1406
# Epoch 8/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0763 - accuracy: 0.1406
# Epoch 9/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0761 - accuracy: 0.1406
# Epoch 10/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0759 - accuracy: 0.1406
# Epoch 11/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0756 - accuracy: 0.1406
# 2.458040410822088
# trained image count:  1728
# Images Left:  6272
# Estimated completion time:  0:04:00.887960
# loading image
# Epoch 1/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0929 - accuracy: 0.0625
# Epoch 2/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0918 - accuracy: 0.0625
# Epoch 3/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0904 - accuracy: 0.0625
# Epoch 4/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0884 - accuracy: 0.0625
# Epoch 5/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0871 - accuracy: 0.0625
# Epoch 6/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0853 - accuracy: 0.0625
# Epoch 7/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.0840 - accuracy: 0.0625
# Epoch 8/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.0822 - accuracy: 0.0625
# Epoch 9/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0810 - accuracy: 0.0625
# Epoch 10/11
# 16/16 [==============================] - 2s 151ms/step - loss: 2.0795 - accuracy: 0.0625
# Epoch 11/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0781 - accuracy: 0.1094
# 2.4780102643099697
# trained image count:  1792
# Images Left:  6208
# Estimated completion time:  0:04:00.366996
# loading image
# Epoch 1/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0941 - accuracy: 0.0781
# Epoch 2/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0922 - accuracy: 0.0781
# Epoch 3/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0891 - accuracy: 0.0781
# Epoch 4/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0862 - accuracy: 0.0781
# Epoch 5/11
# 16/16 [==============================] - 2s 151ms/step - loss: 2.0835 - accuracy: 0.0781
# Epoch 6/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0805 - accuracy: 0.1094
# Epoch 7/11
# 16/16 [==============================] - 3s 161ms/step - loss: 2.0782 - accuracy: 0.1406
# Epoch 8/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0750 - accuracy: 0.1406
# Epoch 9/11
# 16/16 [==============================] - 2s 149ms/step - loss: 2.0729 - accuracy: 0.1406
# Epoch 10/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0701 - accuracy: 0.1406
# Epoch 11/11
# 16/16 [==============================] - 2s 150ms/step - loss: 2.0677 - accuracy: 0.1406
# 2.449538144198331
# trained image count:  1856
# Images Left:  6144
# Estimated completion time:  0:03:55.155662
# loading image
# Epoch 1/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0896 - accuracy: 0.1094
# Epoch 2/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0887 - accuracy: 0.1094
# Epoch 3/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0876 - accuracy: 0.1094
# Epoch 4/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0860 - accuracy: 0.1094
# Epoch 5/11
# 16/16 [==============================] - 2s 149ms/step - loss: 2.0846 - accuracy: 0.1094
# Epoch 6/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0832 - accuracy: 0.0938
# Epoch 7/11
# 16/16 [==============================] - 2s 151ms/step - loss: 2.0820 - accuracy: 0.1875
# Epoch 8/11
# 16/16 [==============================] - 2s 147ms/step - loss: 2.0810 - accuracy: 0.1875
# Epoch 9/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0796 - accuracy: 0.1875
# Epoch 10/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.0782 - accuracy: 0.1875
# Epoch 11/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0772 - accuracy: 0.1875
# 2.4621711427515205
# trained image count:  1920
# Images Left:  6080
# Estimated completion time:  0:03:53.906259
# loading image
# Epoch 1/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0751 - accuracy: 0.0938
# Epoch 2/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.0733 - accuracy: 0.0938
# Epoch 3/11
# 16/16 [==============================] - 3s 163ms/step - loss: 2.0710 - accuracy: 0.0938
# Epoch 4/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0691 - accuracy: 0.1094
# Epoch 5/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0664 - accuracy: 0.2344
# Epoch 6/11
# 16/16 [==============================] - 2s 150ms/step - loss: 2.0641 - accuracy: 0.2344
# Epoch 7/11
# 16/16 [==============================] - 2s 148ms/step - loss: 2.0621 - accuracy: 0.2344
# Epoch 8/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0601 - accuracy: 0.2344
# Epoch 9/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0579 - accuracy: 0.2344
# Epoch 10/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0560 - accuracy: 0.2344
# Epoch 11/11
# 16/16 [==============================] - 2s 151ms/step - loss: 2.0539 - accuracy: 0.2344
# 2.45465070551092
# trained image count:  1984
# Images Left:  6016
# Estimated completion time:  0:03:50.737166
# loading image
# Epoch 1/11
# 16/16 [==============================] - 2s 149ms/step - loss: 2.0846 - accuracy: 0.0781
# Epoch 2/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0836 - accuracy: 0.0781
# Epoch 3/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0822 - accuracy: 0.0781
# Epoch 4/11
# 16/16 [==============================] - 2s 151ms/step - loss: 2.0809 - accuracy: 0.0781
# Epoch 5/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0793 - accuracy: 0.0781
# Epoch 6/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0782 - accuracy: 0.0781
# Epoch 7/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0767 - accuracy: 0.0781
# Epoch 8/11
# 16/16 [==============================] - 2s 149ms/step - loss: 2.0752 - accuracy: 0.0781
# Epoch 9/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0739 - accuracy: 0.1094
# Epoch 10/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0726 - accuracy: 0.2031
# Epoch 11/11
# 16/16 [==============================] - 2s 149ms/step - loss: 2.0714 - accuracy: 0.2031
# 2.4420519958842886
# trained image count:  2048
# Images Left:  5952
# Estimated completion time:  0:03:47.110836
# loading image
# Epoch 1/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0952 - accuracy: 0.0938
# Epoch 2/11
# 16/16 [==============================] - 3s 160ms/step - loss: 2.0946 - accuracy: 0.0938
# Epoch 3/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0943 - accuracy: 0.0938
# Epoch 4/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0929 - accuracy: 0.0938
# Epoch 5/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0924 - accuracy: 0.0938
# Epoch 6/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0914 - accuracy: 0.0938
# Epoch 7/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0908 - accuracy: 0.0938
# Epoch 8/11
# 16/16 [==============================] - 2s 151ms/step - loss: 2.0900 - accuracy: 0.0938
# Epoch 9/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0892 - accuracy: 0.0938
# Epoch 10/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0887 - accuracy: 0.0938
# Epoch 11/11
# 16/16 [==============================] - 2s 150ms/step - loss: 2.0879 - accuracy: 0.0938
# 2.459618330001831
# trained image count:  2112
# Images Left:  5888
# Estimated completion time:  0:03:46.284886
# loading image
# Epoch 1/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0919 - accuracy: 0.0625
# Epoch 2/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.0895 - accuracy: 0.0625
# Epoch 3/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0875 - accuracy: 0.0781
# Epoch 4/11
# 16/16 [==============================] - 2s 150ms/step - loss: 2.0852 - accuracy: 0.0938
# Epoch 5/11
# 16/16 [==============================] - 2s 149ms/step - loss: 2.0827 - accuracy: 0.0938
# Epoch 6/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0809 - accuracy: 0.0938
# Epoch 7/11
# 16/16 [==============================] - 2s 151ms/step - loss: 2.0789 - accuracy: 0.1719
# Epoch 8/11
# 16/16 [==============================] - 2s 151ms/step - loss: 2.0767 - accuracy: 0.2344
# Epoch 9/11
# 16/16 [==============================] - 2s 150ms/step - loss: 2.0749 - accuracy: 0.2344
# Epoch 10/11
# 16/16 [==============================] - 2s 150ms/step - loss: 2.0733 - accuracy: 0.2344
# Epoch 11/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0711 - accuracy: 0.2344
# 2.4377234198830346
# trained image count:  2176
# Images Left:  5824
# Estimated completion time:  0:03:41.832831
# loading image
# Epoch 1/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.0793 - accuracy: 0.1562
# Epoch 2/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0784 - accuracy: 0.1562
# Epoch 3/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0776 - accuracy: 0.1562
# Epoch 4/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0768 - accuracy: 0.1562
# Epoch 5/11
# 16/16 [==============================] - 2s 151ms/step - loss: 2.0758 - accuracy: 0.1562
# Epoch 6/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0750 - accuracy: 0.1562
# Epoch 7/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0742 - accuracy: 0.1562
# Epoch 8/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0736 - accuracy: 0.1562
# Epoch 9/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0726 - accuracy: 0.1562
# Epoch 10/11
# 16/16 [==============================] - 2s 150ms/step - loss: 2.0718 - accuracy: 0.1562
# Epoch 11/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0712 - accuracy: 0.1562
# 2.4734516577287153
# trained image count:  2240
# Images Left:  5760
# Estimated completion time:  0:03:42.610649
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 164ms/step - loss: 2.0800 - accuracy: 0.1250
# Epoch 2/11
# 16/16 [==============================] - 3s 156ms/step - loss: 2.0776 - accuracy: 0.1250
# Epoch 3/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0746 - accuracy: 0.1250
# Epoch 4/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0720 - accuracy: 0.1250
# Epoch 5/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0690 - accuracy: 0.1250
# Epoch 6/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0665 - accuracy: 0.1250
# Epoch 7/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0642 - accuracy: 0.1562
# Epoch 8/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0613 - accuracy: 0.2812
# Epoch 9/11
# 16/16 [==============================] - 2s 149ms/step - loss: 2.0591 - accuracy: 0.2812
# Epoch 10/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0566 - accuracy: 0.2812
# Epoch 11/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.0542 - accuracy: 0.2812
# 2.487455736507069
# trained image count:  2304
# Images Left:  5696
# Estimated completion time:  0:03:41.383561
# loading image
# Epoch 1/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0930 - accuracy: 0.1406
# Epoch 2/11
# 16/16 [==============================] - 2s 150ms/step - loss: 2.0913 - accuracy: 0.1406
# Epoch 3/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0893 - accuracy: 0.1406
# Epoch 4/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0874 - accuracy: 0.1406
# Epoch 5/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0856 - accuracy: 0.1406
# Epoch 6/11
# 16/16 [==============================] - 2s 151ms/step - loss: 2.0841 - accuracy: 0.1406
# Epoch 7/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0821 - accuracy: 0.1406
# Epoch 8/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.0804 - accuracy: 0.1406
# Epoch 9/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0788 - accuracy: 0.1406
# Epoch 10/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0769 - accuracy: 0.1406
# Epoch 11/11
# 16/16 [==============================] - 2s 150ms/step - loss: 2.0755 - accuracy: 0.1406
# 2.4518149115822534
# trained image count:  2368
# Images Left:  5632
# Estimated completion time:  0:03:35.759712
# loading image
# Epoch 1/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0970 - accuracy: 0.0625
# Epoch 2/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0959 - accuracy: 0.0625
# Epoch 3/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0932 - accuracy: 0.0625
# Epoch 4/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0915 - accuracy: 0.0625
# Epoch 5/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0895 - accuracy: 0.0625
# Epoch 6/11
# 16/16 [==============================] - 2s 151ms/step - loss: 2.0879 - accuracy: 0.0625
# Epoch 7/11
# 16/16 [==============================] - 3s 162ms/step - loss: 2.0860 - accuracy: 0.0625
# Epoch 8/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0842 - accuracy: 0.0625
# Epoch 9/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0824 - accuracy: 0.0625
# Epoch 10/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0810 - accuracy: 0.0625
# Epoch 11/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0792 - accuracy: 0.0625
# 2.4724643230438232
# trained image count:  2432
# Images Left:  5568
# Estimated completion time:  0:03:35.104396
# loading image
# Epoch 1/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0872 - accuracy: 0.1250
# Epoch 2/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0859 - accuracy: 0.1250
# Epoch 3/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0843 - accuracy: 0.1250
# Epoch 4/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0824 - accuracy: 0.1250
# Epoch 5/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0805 - accuracy: 0.1250
# Epoch 6/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0787 - accuracy: 0.1250
# Epoch 7/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0769 - accuracy: 0.1250
# Epoch 8/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0753 - accuracy: 0.1250
# Epoch 9/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0737 - accuracy: 0.1250
# Epoch 10/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0719 - accuracy: 0.1250
# Epoch 11/11
# 16/16 [==============================] - 2s 150ms/step - loss: 2.0704 - accuracy: 0.1250
# 2.456397858532992
# trained image count:  2496
# Images Left:  5504
# Estimated completion time:  0:03:31.250216
# loading image
# Epoch 1/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0693 - accuracy: 0.1719
# Epoch 2/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0682 - accuracy: 0.1719
# Epoch 3/11
# ...
# Images Left:  5376
# Estimated completion time:  0:03:30.076617
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0733 - accuracy: 0.1250
# Epoch 2/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0728 - accuracy: 0.1250
# Epoch 3/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0719 - accuracy: 0.1250
# Epoch 4/11
# 16/16 [==============================] - 3s 163ms/step - loss: 2.0708 - accuracy: 0.1250
# Epoch 5/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0702 - accuracy: 0.1250
# Epoch 6/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0692 - accuracy: 0.1250
# Epoch 7/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0682 - accuracy: 0.1250
# Epoch 8/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0673 - accuracy: 0.1250
# Epoch 9/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0667 - accuracy: 0.1250
# Epoch 10/11
# 16/16 [==============================] - 3s 156ms/step - loss: 2.0658 - accuracy: 0.1250
# Epoch 11/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0648 - accuracy: 0.1250
# 2.51167293028398
# trained image count:  2688
# Images Left:  5312
# Estimated completion time:  0:03:28.468853
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0790 - accuracy: 0.1719
# Epoch 2/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0784 - accuracy: 0.1719
# Epoch 3/11
# 16/16 [==============================] - 3s 165ms/step - loss: 2.0774 - accuracy: 0.1719
# Epoch 4/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0764 - accuracy: 0.1719
# Epoch 5/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0754 - accuracy: 0.1719
# Epoch 6/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0741 - accuracy: 0.1719
# Epoch 7/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0730 - accuracy: 0.1719
# Epoch 8/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0722 - accuracy: 0.1719
# Epoch 9/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0712 - accuracy: 0.1719
# Epoch 10/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0706 - accuracy: 0.1719
# Epoch 11/11
# 16/16 [==============================] - 2s 156ms/step - loss: 2.0693 - accuracy: 0.1719
# 2.5043694972991943
# trained image count:  2752
# Images Left:  5248
# Estimated completion time:  0:03:25.358299
# loading image
# Epoch 1/11
# 16/16 [==============================] - 2s 153ms/step - loss: 2.0915 - accuracy: 0.0938
# Epoch 2/11
# 16/16 [==============================] - 3s 163ms/step - loss: 2.0897 - accuracy: 0.0938
# Epoch 3/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0879 - accuracy: 0.0938
# Epoch 4/11
# 16/16 [==============================] - 3s 156ms/step - loss: 2.0854 - accuracy: 0.0938
# Epoch 5/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0838 - accuracy: 0.0938
# Epoch 6/11
# 16/16 [==============================] - 2s 152ms/step - loss: 2.0817 - accuracy: 0.0938
# Epoch 7/11
# 16/16 [==============================] - 3s 156ms/step - loss: 2.0798 - accuracy: 0.0938
# Epoch 8/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0777 - accuracy: 0.0938
# Epoch 9/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0762 - accuracy: 0.0938
# Epoch 10/11
# 16/16 [==============================] - 3s 156ms/step - loss: 2.0742 - accuracy: 0.0938
# Epoch 11/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0726 - accuracy: 0.0781
# 2.4925764474001797
# trained image count:  2816
# Images Left:  5184
# Estimated completion time:  0:03:21.898692
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 161ms/step - loss: 2.0679 - accuracy: 0.1875
# Epoch 2/11
# 16/16 [==============================] - 3s 165ms/step - loss: 2.0666 - accuracy: 0.1875
# Epoch 3/11
# 16/16 [==============================] - 2s 155ms/step - loss: 2.0652 - accuracy: 0.1719
# Epoch 4/11
# 16/16 [==============================] - 2s 154ms/step - loss: 2.0636 - accuracy: 0.2031
# Epoch 5/11
# 16/16 [==============================] - 3s 158ms/step - loss: 2.0618 - accuracy: 0.2031
# Epoch 6/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0603 - accuracy: 0.2031
# Epoch 7/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0589 - accuracy: 0.2031
# Epoch 8/11
# 16/16 [==============================] - 3s 187ms/step - loss: 2.0572 - accuracy: 0.2031
# Epoch 9/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0560 - accuracy: 0.2031
# Epoch 10/11
# 16/16 [==============================] - 3s 161ms/step - loss: 2.0544 - accuracy: 0.2031
# Epoch 11/11
# 16/16 [==============================] - 3s 159ms/step - loss: 2.0529 - accuracy: 0.2031
# 2.584690895947543
# trained image count:  2880
# Images Left:  5120
# Estimated completion time:  0:03:26.775272
# loading image
# Epoch 1/11
# 16/16 [==============================] - 3s 170ms/step - loss: 2.0601 - accuracy: 0.2188
# Epoch 2/11
# 16/16 [==============================] - 3s 157ms/step - loss: 2.0588 - accuracy: 0.2188
# Epoch 3/11
# 16/16 [==============================] - 2s 157ms/step - loss: 2.0579 - accuracy: 0.2188
# Epoch 4/11
# 10/16 [=================>............] - ETA: 0s - loss: 2.0720 - accuracy: 0.2000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3416\1590298336.py in ?()
#       4 batchSizes = [4, 8, 16, 32, 48]
#       5 firstLayerSizes = [128, 256, 384, 516, 772]
#       6
# ----> 7 for batchSize in batchSizes:
#       8     for firstLayerSize in firstLayerSizes:
#       9         modelName = "bs{}_fls{}.h".format(batchSize, firstLayerSize)
#      10         SingleLayerTrainAndTest(modelName, batchSize, firstLayerSize)
#
# ~\AppData\Local\Temp\ipykernel_3416\3468547524.py in ?(modelName, batchSize, firstLayerSize)
#      40       # Training model
#      41       model.fit(data, label, epochs = 11, batch_size = batchSize, callbacks = [time_callback])
#      42       print(time_callback.AverageTime())
#      43     except RuntimeError as e:
# ---> 44       print(e)
#      45
#      46     # Saving weights
#      47     model.save_weights('{}.h5'.format(modelName))
#
# ~\AppData\Local\miniconda3\envs\tflite-facial-expression\lib\site-packages\keras\utils\traceback_utils.py in ?(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#      67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
# ---> 69       del filtered_tb
#
# ~\AppData\Local\miniconda3\envs\tflite-facial-expression\lib\site-packages\keras\engine\training.py in ?(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1440       # If eval data_handler exists, delete it after all epochs are done.
#    1441       if getattr(self, '_eval_data_handler', None) is not None:
#    1442         del self._eval_data_handler
#    1443       callbacks.on_train_end(logs=training_logs)
# -> 1444       return self.history
#
# ~\AppData\Local\miniconda3\envs\tflite-facial-expression\lib\site-packages\keras\engine\training.py in ?(iterator)
#    1019       def train_function(iterator):
#    1020         """Runs a training execution with a single step."""
# -> 1021         return step_function(self, iterator)
#
# ~\AppData\Local\miniconda3\envs\tflite-facial-expression\lib\site-packages\keras\engine\training.py in ?(model, iterator)
#    1006       if self._jit_compile:
#    1007         run_step = tf.function(
#    1008             run_step, jit_compile=True, experimental_relax_shapes=True)
#    1009       data = next(iterator)
# -> 1010       outputs = model.distribute_strategy.run(run_step, args=(data,))
#    1011       outputs = reduce_per_replica(
#    1012           outputs, self.distribute_strategy, reduction='first')
#    1013       return outputs
#
# ~\AppData\Local\miniconda3\envs\tflite-facial-expression\lib\site-packages\tensorflow\python\distribute\distribute_lib.py in ?(***failed resolving arguments***)
#    1308       # tf.distribute supports Eager functions, so AutoGraph should not be
#    1309       # applied when the caller is also in Eager mode.
#    1310       fn = autograph.tf_convert(
#    1311           fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1312       return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#
# ~\AppData\Local\miniconda3\envs\tflite-facial-expression\lib\site-packages\tensorflow\python\distribute\distribute_lib.py in ?(self, fn, args, kwargs)
#    2884     _require_cross_replica_or_default_context_extended(self)
#    2885     if kwargs is None:
#    2886       kwargs = {}
#    2887     with self._container_strategy().scope():
# -> 2888       return self._call_for_each_replica(fn, args, kwargs)
#
# ~\AppData\Local\miniconda3\envs\tflite-facial-expression\lib\site-packages\tensorflow\python\distribute\distribute_lib.py in ?(self, fn, args, kwargs)
#    3687   def _call_for_each_replica(self, fn, args, kwargs):
#    3688     with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 3689       return fn(*args, **kwargs)
#
# ~\AppData\Local\miniconda3\envs\tflite-facial-expression\lib\site-packages\tensorflow\python\autograph\impl\api.py in ?(*args, **kwargs)
#     593   def wrapper(*args, **kwargs):
#     594     with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.UNSPECIFIED):
# --> 595       return func(*args, **kwargs)
#
# ~\AppData\Local\miniconda3\envs\tflite-facial-expression\lib\site-packages\keras\engine\training.py in ?(data)
#     999       def run_step(data):
# -> 1000         outputs = model.train_step(data)
#    1001         # Ensure counter is updated only if `train_step` succeeds.
#    1002         with tf.control_dependencies(_minimum_control_deps(outputs)):
#    1003           model._train_counter.assign_add(1)  # pylint: disable=protected-access
#
# ~\AppData\Local\miniconda3\envs\tflite-facial-expression\lib\site-packages\keras\engine\training.py in ?(self, data)
#     860       loss = self.compute_loss(x, y, y_pred, sample_weight)
#     861     self._validate_target_and_loss(y, loss)
#     862     # Run backwards pass.
#     863     self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
# --> 864     return self.compute_metrics(x, y, y_pred, sample_weight)
#
# ~\AppData\Local\miniconda3\envs\tflite-facial-expression\lib\site-packages\keras\engine\training.py in ?(***failed resolving arguments***)
#     953       values of the metrics listed in `self.metrics` are returned. Example:
#     954       `{'loss': 0.2, 'accuracy': 0.7}`.
#     955     """
#     956     del x  # The default implementation does not use `x`.
# --> 957     self.compiled_metrics.update_state(y, y_pred, sample_weight)
#     958     # Collect metrics to return
#     959     return_metrics = {}
#     960     for metric in self.metrics:
#
# ~\AppData\Local\miniconda3\envs\tflite-facial-expression\lib\site-packages\keras\engine\compile_utils.py in ?(self, y_true, y_pred, sample_weight)
#     455
#     456       for metric_obj in metric_objs:
#     457         if metric_obj is None:
#     458           continue
# --> 459         metric_obj.update_state(y_t, y_p, sample_weight=mask)
#     460
#     461       for weighted_metric_obj in weighted_metric_objs:
#     462         if weighted_metric_obj is None:
#
# ~\AppData\Local\miniconda3\envs\tflite-facial-expression\lib\site-packages\keras\utils\metrics_utils.py in ?(metric_obj, *args, **kwargs)
#      66             'the metric was not created in TPUStrategy scope. '
#      67             'Make sure the keras Metric is created in TPUstrategy scope. ')
#      68
#      69     with tf_utils.graph_context_for_symbolic_tensors(*args, **kwargs):
# ---> 70       update_op = update_state_fn(*args, **kwargs)
#      71     if update_op is not None:  # update_op will be None in eager execution.
#      72       metric_obj.add_update(update_op)
#      73     return update_op
#
# ~\AppData\Local\miniconda3\envs\tflite-facial-expression\lib\site-packages\keras\metrics.py in ?(*args, **kwargs)
#     175       def update_state_fn(*args, **kwargs):
#     176         control_status = tf.__internal__.autograph.control_status_ctx()
#     177         ag_update_state = tf.__internal__.autograph.tf_convert(obj_update_state, control_status)
# --> 178         return ag_update_state(*args, **kwargs)
#
# ~\AppData\Local\miniconda3\envs\tflite-facial-expression\lib\site-packages\tensorflow\python\autograph\impl\api.py in ?(*args, **kwargs)
#     690       except Exception as e:  # pylint:disable=broad-except
#     691         if hasattr(e, 'ag_error_metadata'):
#     692           raise e.ag_error_metadata.to_exception(e)
#     693         else:
# --> 694           raise
#
# ~\AppData\Local\miniconda3\envs\tflite-facial-expression\lib\site-packages\tensorflow\python\autograph\impl\api.py in ?(f, args, kwargs, caller_fn_scope, options)
#     327     options = caller_fn_scope.callopts
#     328
#     329   if conversion.is_in_allowlist_cache(f, options):
#     330     logging.log(2, 'Allowlisted %s: from cache', f)
# --> 331     return _call_unconverted(f, args, kwargs, options, False)
#     332
#     333   if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#     334     logging.log(2, 'Allowlisted: %s: AutoGraph is disabled in context', f)
#
# ~\AppData\Local\miniconda3\envs\tflite-facial-expression\lib\site-packages\tensorflow\python\autograph\impl\api.py in ?(f, args, kwargs, options, update_cache)
#     454   if inspect.ismethod(f) and isinstance(f.__self__, function.TfMethodTarget):
#     455     return f.__self__.call(args, kwargs)
#     456
#     457   if kwargs is not None:
# --> 458     return f(*args, **kwargs)
#     459   return f(*args)
#
# ~\AppData\Local\miniconda3\envs\tflite-facial-expression\lib\site-packages\keras\metrics.py in ?(self, y_true, y_pred, sample_weight)
#     716
#     717     Returns:
#     718       Update op.
#     719     """
# --> 720     y_true = tf.cast(y_true, self._dtype)
#     721     y_pred = tf.cast(y_pred, self._dtype)
#     722     [y_true, y_pred], sample_weight = (
#     723         metrics_utils.ragged_assert_compatible_and_get_flat_values(
#
# ~\AppData\Local\miniconda3\envs\tflite-facial-expression\lib\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~\AppData\Local\miniconda3\envs\tflite-facial-expression\lib\site-packages\tensorflow\python\util\dispatch.py in ?(*args, **kwargs)
#    1086         result = dispatch(op_dispatch_handler, args, kwargs)
#    1087         if result is not OpDispatcher.NOT_SUPPORTED:
#    1088           return result
#    1089         else:
# -> 1090           raise
#
# ~\AppData\Local\miniconda3\envs\tflite-facial-expression\lib\site-packages\tensorflow\python\ops\math_ops.py in ?(x, dtype, name)
#    1001       if x.dtype.base_dtype != base_type:
#    1002         x = gen_math_ops.cast(x, base_type, name=name)
#    1003     if x.dtype.is_complex and base_type.is_floating:
#    1004       logging.warn("Casting complex to real discards imaginary part.")
# -> 1005     return x
#
# ~\AppData\Local\miniconda3\envs\tflite-facial-expression\lib\site-packages\tensorflow\python\ops\gen_math_ops.py in ?(x, DstT, Truncate, name)
#    1998       return _result
#    1999     except _core._NotOkStatusException as e:
#    2000       _ops.raise_from_not_ok_status(e, name)
#    2001     except _core._FallbackException:
# -> 2002       pass
#    2003     try:
#    2004       return cast_eager_fallback(
#    2005           x, DstT=DstT, Truncate=Truncate, name=name, ctx=_ctx)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Reference

# %%
# Default Train and Test function
def TrainAndTest(modelName):
  """Train and test a model. This function's input should be customized to accept different parameters, function body should be customized to these parameters to train models of variety of paramters.

  Args:
      modelName (str): name of model
  """
  pretrained_model = tf.keras.applications.MobileNetV3Large(input_shape=(224,224,3)) # Initializing model with mobile net V3 pretrained model

  # Initializing the input and output from the model, removing last layer
  base_input = pretrained_model.layers[0].input
  base_output = pretrained_model.layers[-2].output

  #-------------------------------------------------
  # Customizing layers
  #-------------------------------------------------
  # Adding 3 more layers to output side
  final_output = layers.Dense(128)(base_output) # Adding new layers, to the output side
  final_output = layers.Activation('relu')(final_output) # activating layer
  final_output = layers.Dense(8, activation = 'softmax')(final_output) # 8 cuz there are 8 image classifications

  model = keras.Model(inputs = base_input, outputs = final_output)
  model.compile(loss = "sparse_categorical_crossentropy", optimizer = "adam", metrics=["accuracy"])

  # ------------------ Training Model ------------------
  time_callback = TimeHistory()
  dataSet = mainTrainSet.copy()

  # Initializing model fit params
  batchSize = 4
  imgPerIter = batchSize*16

  count = 0
  while(len(dataSet) != 0):
    croppedList = []
    try:
      print("loading image") # Crop and load images in
      croppedList = CropData(dataSet, imgPerIter)
      label, data = LoadImages(TRAINIMAGEPATH, croppedList)
      
      # Training model
      model.fit(data, label, epochs = 11, batch_size = batchSize, callbacks = [time_callback])
      print(time_callback.AverageTime())
    except RuntimeError as e:
      print(e)
    
    # Saving weights
    model.save_weights('{}.h5'.format(modelName))
    
    # Print summary of current iteration
    count = count + len(croppedList)
    timeLeft = len(dataSet)/imgPerIter * time_callback.AverageTime()
    print("trained image count: ", count)
    print("Images Left: ", len(dataSet))
    print("Estimated completion time: ", str(timedelta(seconds=timeLeft)))
    
    reset_keras()
  print("---------------- {} Training Completed ------------------".format(modelName))

  # ---------------- Testing Model -----------------
  # initialise image names and label
  testSetData = mainTrainSet.copy()

  # test model
  loss, accuracy = TestModel(model, mainTrainSet.copy())
  
  # Saving test informations
  modelSummary = '''
  model name: {}
  average lost: {}
  average accuracy: {}
            '''.format(modelName, loss, accuracy)
      
  print("==========FINISH TESTING===========\n{}".format(modelSummary))
  
  file = open("training_summaries.txt", "a")
  file.write(modelSummary + "\n\n")
