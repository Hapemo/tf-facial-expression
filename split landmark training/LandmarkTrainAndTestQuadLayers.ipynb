# %% [markdown]
# This is for second desktop

# %% [markdown]
# ## Import libraries and set up functions
# Starting directory is this "..\\asset" from this notebook code

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
tf.config.run_functions_eagerly(True)
tf.data.experimental.enable_debug_mode()
import cv2
import matplotlib.pyplot as plt
import random
from keras.backend import clear_session
from keras.backend import get_session
import time
import math
from datetime import timedelta
# import mediapipe as mp
import csv
import pandas as pd
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ReduceLROnPlateau

os.chdir("..\\..\\asset") # change working directory

# %%
emotionList = ('Neutral', 'Happy', 'Sad', 'Surprise', 'Fear', 'Disgust', 'Anger', 'Contempt')
TRAINANNOTATIONPATH = "train_set\\annotations\\"
TRAINIMAGEPATH = "train_set\\images\\"
TRAINLANDMARKPATH = "train_set\\landmarks\\"
TESTANNOTATIONPATH = "val_set\\annotations\\"
TESTIMAGEPATH = "val_set\\images\\"
TESTLANDMARKPATH = "val_set\\landmarks\\"

def LoadAllImageNames(filePath, limit = 0, catLimit = []):
  """Load the images names and label in tuple format (label, image name)

  Args:
      filePath (str): directory of image folder
      limit (int, optional): max number of image to load. Defaults to 0.
      catLimit (list<int>, optional): array of image count limit for each class. Defaults to []*8.

  Returns:
      list<str>: shuffled list of image names
  """
  limitCounter = [0,0,0,0,0,0,0,0]
  dataSet = []
  loadCounter = 0

  annotationPath = TRAINANNOTATIONPATH if ("train" in filePath) else TESTANNOTATIONPATH
  for file in os.scandir(filePath):
    if (limit > 0 and loadCounter > limit):
      break
  
    name = file.name[:-4] # file name w/o file extension
    if "_landmark" in name:
      name = name[:-9]
    data = np.load("{}{}_exp.npy".format(annotationPath, name)) # 
    label = int(data.item(0))

    if len(catLimit) > 0 and limitCounter[label] >= catLimit[label]:
        continue
    limitCounter[label] += 1
    loadCounter += 1

    dataSet.append((label, file.name))
    if (loadCounter%10000==0):
      print("Files loaded:{}".format(loadCounter))
  
  print("Total images loaded: ", loadCounter)
  print("Images Loaded: ", limitCounter)
  random.shuffle(dataSet)
  return dataSet

# Load the pixels of a picture to numpy.ndarray format. false for test set, true for training set
# Return image in RGB format
def LoadImage(imagePath, imageName, normalize = True):
  """Load image using numpy

  Args:
      imagePath (str): image path 
      imageName (str): image name
      normalize (bool, optional): To normalize image or not. Defaults to True.

  Returns:
      numpy array: x,y,3 array
  """
  # print("{}{}{}".format(os.getcwd(), "\\"+imagePath, imageName))
  image_array = cv2.imread("{}{}{}".format(os.getcwd(), "\\"+imagePath, imageName))
  image_array = cv2.cvtColor(image_array, cv2.COLOR_BGR2RGB)
  if normalize:
    image_array = image_array/255
    
  return image_array

# Extract the daata from 0 to amount from list and return it
def CropData(list, amount):
  if (len(list) < amount):
    amount = len(list)
  croppedList = list[:amount]
  del list[:amount]
  return croppedList

def LoadImages(imagePath, list):
  label = []
  data = []
  for entries in list:
    try:
      image = LoadImage(imagePath, entries[1])
      data.append(image) 
      label.append(entries[0]) 
    except: 
      print("Failed to load training image: ", entries[1])
  npLabel = np.array(label) 
  npData = np.array(data) 
  return npLabel, npData 

# Load a list of face mesh in landmark_pb2.NormalizedLandmarkList format
def LoadFaceMeshes(faceMesh, path, list, withFace = False):
  face = []
  label = []
  data = []
  for entry in list:
    # try:
    if withFace:
      face.append(LoadImage(path, entry[1], normalize = False)) # Load image
      data.append(faceMesh.process(face[-1])) # process it into face mesh and append into data
    else:
      data.append(faceMesh.process(LoadImage(path, entry[1], normalize = False))) # Load image, process it into face mesh, and append into data
    label.append(entry[0])
    # except:
      # print("Failed to load training image: ", entry[1])

  if withFace:
    return np.array(label), np.array(data), np.array(face)
  else:
    return np.array(label), np.array(data)

# Load face mesh data in numpy array of 
def LoadFaceMeshVertices(faceMesh, path, list):
  label = []
  data = []
  for entry in list:
    # load image, process it into normalizedlandmarklist format, obtain face data from the list, convert it into vertices
    image = LoadImage(path, entry[1], normalize = False)
    multiFaceLandmarks = faceMesh.process(image).multi_face_landmarks
    if (multiFaceLandmarks == None):
      print("{} multi-face landmarks is none".format(entry[1]))
      continue
    vertices = MultiLandmarkToVertices(multiFaceLandmarks[0])
    data.append(vertices)
    label.append(entry[0])
    # except:
      # print("Failed to load training image: ", entry[1])

def LoadVertices(path, list):
  label = []
  data = []
  for entry in list:
    vertices = np.load("{}{}{}.npy".format(os.getcwd(), "\\"+path, entry[1][:-4]))
    data.append(vertices)
    label.append(entry[0])
  
  return np.array(label), np.array(data)
  
def MultiLandmarkToVertices(multiLandmark):
  verticesList = []
  for idx, landmark in enumerate(multiLandmark.landmark):
    verticesList.append([landmark.x, landmark.y, landmark.z])

  return verticesList


def InitializeModel():
  pretrained_model = tf.keras.applications.MobileNetV3Large(input_shape=(224,224,3)) # Initializing model with mobile net V3 pretrained model

  # Initializing the input and output from the model, removing last layer
  base_input = pretrained_model.layers[0].input
  base_output = pretrained_model.layers[-2].output

  # Adding 3 more layers to output side
  final_output = layers.Dense(128)(base_output) # Adding new layers, to the output side
  final_output = layers.Activation('relu')(final_output) # activating layer
  final_output = layers.Dense(64)(final_output)
  final_output = layers.Activation('relu')(final_output) # activating layer
  final_output = layers.Dense(8, activation = 'softmax')(final_output) # 8 cuz there are 8 image classifications

  new_model = keras.Model(inputs = base_input, outputs = final_output)
  # new_model.summary()
  return new_model

def ConvertToGray(image):
  image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
  image = cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)
  return image

def ScaleImage(image, width):
  ratio = image.shape[1]/width
  image = cv2.resize(image, (width, int(image.shape[0]/ratio)))
  return image

def DetectFace(image):
  face_roi = np.ndarray(1)
  faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
  grayImage = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
  faces = faceCascade.detectMultiScale(grayImage, 1.3, 5)
  for x,y,w,h in faces:
    roi_gray = grayImage[y:y+h, x:x+w]
    roi_color = image[y:y+h, x:x+w]
    cv2.rectangle(image, (x,y), (x+w, y+h), (255,0,0), 2)
    facess = faceCascade.detectMultiScale(roi_gray)
    if (len(facess) == 0):
      print("Face not detected")
    else:
      for (ex,ey,ew,eh) in facess:
        face_roi = roi_color[ey:ey+eh, ex:ex+ew]
  return face_roi

def ConvertToInput(image):
  input = ScaleImage(image, 224)
  input = np.expand_dims(input, axis = 0) ## to add fourth dimension to fit model input
  input = input/255
  return input

def GetResult(model, input):
  Predictions = model.predict(input)
  print(Predictions)
  result = np.argmax(Predictions)
  return emotionList[result]

def printDataSetLabels(dataSet):
    counterList = list(range(8))
    for label, name in dataSet:
        counterList[label] += 1
    print(counterList)
    
# Reset Keras Session
def reset_keras():
    sess = get_session()
    clear_session()
    sess.close()
    sess = get_session()

    # try:
    #     del classifier # this is from global space - change this as you need
    # except:
    #     pass

    # use the same config as you used to create the session
    tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.9, visible_device_list="0")

class TimeHistory(keras.callbacks.Callback):
  def on_train_begin(self, logs={}):
    self.times = []

  def on_epoch_begin(self, batch, logs={}):
    self.epoch_time_start = time.time()

  def on_epoch_end(self, batch, logs={}):
    self.times.append(time.time() - self.epoch_time_start)

  def AverageTime(self):
    sum = 0
    for time in self.times:
      sum += time
    return sum/len(self.times)

def TestModel(model, testSetData):
  # test model
  lostSum = 0
  accuracySum = 0
  count = 0
  while(len(testSetData) != 0):
    # training data
    try:
      croppedList = CropData(testSetData, 100)
      label, data = LoadImages(TESTIMAGEPATH, croppedList)
      result = model.evaluate(data, label, batch_size = 1)
      lostSum += result[0]
      accuracySum += result[1]
    except:
      print("Failed to train data")

    count += 1
    reset_keras()
  
  return lostSum/count, accuracySum/count

def TestModelWithVertices(model, dataSet, tensorboard):
  # test model
  lostSum = 0
  accuracySum = 0
  count = 0
  while(len(dataSet) != 0):
    # training data
    try:
      croppedList = CropData(dataSet, 100)
      label, data = LoadVertices(TESTLANDMARKPATH, croppedList)
      result = model.evaluate(data, label, batch_size = 1, callbacks =[tensorboard])
      lostSum += result[0]
      accuracySum += result[1]
    except:
      print("Failed to train data")

    count += 1
    reset_keras()
  
  return lostSum/count, accuracySum/count

def DrawFaceLandmark(label, image, landmarks):
  mp_drawing = mp.solutions.drawing_utils
  mp_drawing_styles = mp.solutions.drawing_styles
  mp_face_mesh = mp.solutions.face_mesh
  print(f'Face landmarks of {label}:')
  if not landmarks.multi_face_landmarks:
    print("unagle to locate face landmark for {}".format(label))
  annotated_image = image.copy()
  for face_landmarks in landmarks.multi_face_landmarks:
    mp_drawing.draw_landmarks(
        image=annotated_image,
        landmark_list=face_landmarks,
        connections=mp_face_mesh.FACEMESH_TESSELATION,
        landmark_drawing_spec=None,
        connection_drawing_spec=mp_drawing_styles
        .get_default_face_mesh_tesselation_style())
    mp_drawing.draw_landmarks(
        image=annotated_image,
        landmark_list=face_landmarks,
        connections=mp_face_mesh.FACEMESH_CONTOURS,
        landmark_drawing_spec=None,
        connection_drawing_spec=mp_drawing_styles
        .get_default_face_mesh_contours_style())
    mp_drawing.draw_landmarks(
        image=annotated_image,
        landmark_list=face_landmarks,
        connections=mp_face_mesh.FACEMESH_IRISES,
        landmark_drawing_spec=None,
        connection_drawing_spec=mp_drawing_styles
        .get_default_face_mesh_iris_connections_style())
  plt.imshow(annotated_image)

# %% [markdown]
# ## Setup directory and import image file names

# %%
# Get currect directory (os.getcwd() -> C:\Users\jazzt\src)

#-----------------------Start of code---------------------------
# initialise image names and label
mainTrainSet = LoadAllImageNames(TRAINLANDMARKPATH, catLimit=[4000]*8)
mainTestSet = LoadAllImageNames(TESTLANDMARKPATH, catLimit=[500]*8)
# Out:
# Files loaded:10000
# Files loaded:20000
# Files loaded:30000
# Total images loaded:  31553
# Images Loaded:  [4000, 4000, 4000, 4000, 4000, 3803, 4000, 3750]
# Total images loaded:  3987
# Images Loaded:  [499, 500, 498, 498, 498, 500, 499, 495]

# %%
# reset learning rate callback to counter ReduceLROnPlateau
class ResetLR(tf.keras.callbacks.Callback):
    def __init__(self, learningRate):
        self.default_lr = learningRate
    def on_train_begin(self, logs={}):
        previous_lr = self.model.optimizer.lr.read_value()
        if previous_lr != self.default_lr:
            print("Resetting learning rate from {} to {}".format(previous_lr, self.default_lr))
            self.model.optimizer.lr.assign(self.default_lr)

# # making stopper to only start counting from 3 epochs onwards
# class CustomStopper(tf.keras.callbacks.EarlyStopping):
#     def __init__(self, monitor='val_loss',
#              min_delta=0, patience=3, verbose=0, mode='auto', start_epoch = 3): # add argument for starting epoch
#         super(CustomStopper, self).__init__()
#         self.start_epoch = start_epoch

#     def on_epoch_end(self, epoch, logs=None):
#         if epoch > self.start_epoch:
#             super().on_epoch_end(epoch, logs)

# %%
batchSizes = [128, 256, 320]
firstLayerSizes = [512, 764, 1024, 1536, 2048]
secondLayerSizes = [64, 128, 192, 256, 384, 512, 764, 1024]
thirdLayerSizes = [64, 128, 192, 256, 384, 512, 764, 1024]
fourthLayerSizes = [16, 32, 48, 64, 128, 192, 256]
epoch = 30
learningRate = 0.001

for batchSize in batchSizes:
  for firstLayerSize in firstLayerSizes:
    for secondLayerSize in secondLayerSizes:
      if secondLayerSize > firstLayerSize:
        continue
      for thirdLayerSize in thirdLayerSizes:
        if (thirdLayerSize > secondLayerSize):
          continue
        for fourthLayerSize in fourthLayerSizes:
          if (fourthLayerSize > thirdLayerSize):
            continue
          name = "freeze_{}epoch_{}lr_{}bs_{}_{}_{}_{}_landmark".format(epoch, learningRate, batchSize, firstLayerSize, secondLayerSize, thirdLayerSize, fourthLayerSize)
          FreezeLayerTrainAndTest(epoch, learningRate, name, batchSize, firstLayerSize, secondLayerSize, thirdLayerSize, fourthLayerSize)

# %%
SaveInformation = [] # Saving information as {name, bs, L1, L2, L3, L4, loss, accuracy}

batchSizes = [128, 256, 320]
layerSizes = [
  (512, 128, 128, 64), (512, 128, 128, 128), (512, 192, 128, 64), (764,256,256,256), (764,384,192,128), (764,512,256,192)
]
epoch = 30
learningRate = 0.001

for batchSize in batchSizes:
  for layerSize in layerSizes:
    firstLayerSize = layerSize[0]
    secondLayerSize = layerSize[1]
    thirdLayerSize = layerSize[2]
    fourthLayerSize = layerSize[3]
    name = "rerun_{}epoch_{}lr_{}bs_{}_{}_{}_{}_landmark".format(epoch, learningRate, batchSize, firstLayerSize, secondLayerSize, thirdLayerSize, fourthLayerSize)
    FreezeLayerTrainAndTest(epoch, learningRate, name, batchSize, firstLayerSize, secondLayerSize, thirdLayerSize, fourthLayerSize)
# Out:
# C:\Users\j.teoh\AppData\Local\miniconda3\envs\tflite-facial-expression\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# loading image
# Epoch 1/30
# 198/198 [==============================] - 12s 50ms/step - loss: 2.0426 - accuracy: 0.1738 - val_loss: 2.0106 - val_accuracy: 0.1848
# Epoch 2/30
# 198/198 [==============================] - 10s 51ms/step - loss: 1.9716 - accuracy: 0.2283 - val_loss: 1.9567 - val_accuracy: 0.2328
# Epoch 3/30
# 198/198 [==============================] - 11s 55ms/step - loss: 1.9379 - accuracy: 0.2522 - val_loss: 1.9152 - val_accuracy: 0.2706
# Epoch 4/30
# 198/198 [==============================] - 11s 57ms/step - loss: 1.9138 - accuracy: 0.2694 - val_loss: 1.9016 - val_accuracy: 0.2814
# Epoch 5/30
# 198/198 [==============================] - 11s 57ms/step - loss: 1.9019 - accuracy: 0.2743 - val_loss: 1.9125 - val_accuracy: 0.2752
# Epoch 6/30
# 198/198 [==============================] - 11s 57ms/step - loss: 1.8777 - accuracy: 0.2888 - val_loss: 1.8684 - val_accuracy: 0.2965
# Epoch 7/30
# 198/198 [==============================] - 11s 57ms/step - loss: 1.8553 - accuracy: 0.3016 - val_loss: 1.8507 - val_accuracy: 0.3004
# Epoch 8/30
# 198/198 [==============================] - 11s 55ms/step - loss: 1.8477 - accuracy: 0.3064 - val_loss: 1.8617 - val_accuracy: 0.3088
# Epoch 9/30
# 198/198 [==============================] - 11s 57ms/step - loss: 1.8321 - accuracy: 0.3142 - val_loss: 1.8260 - val_accuracy: 0.3120
# Epoch 10/30
# 198/198 [==============================] - 12s 58ms/step - loss: 1.8260 - accuracy: 0.3198 - val_loss: 1.8278 - val_accuracy: 0.3234
# Epoch 11/30
# 198/198 [==============================] - 12s 59ms/step - loss: 1.8196 - accuracy: 0.3262 - val_loss: 1.8218 - val_accuracy: 0.3194
# Epoch 12/30
# 198/198 [==============================] - 12s 58ms/step - loss: 1.8163 - accuracy: 0.3262 - val_loss: 1.8130 - val_accuracy: 0.3226
# Epoch 13/30
# 198/198 [==============================] - 12s 58ms/step - loss: 1.8097 - accuracy: 0.3252 - val_loss: 1.8112 - val_accuracy: 0.3218
# Epoch 14/30
# 198/198 [==============================] - 12s 59ms/step - loss: 1.8070 - accuracy: 0.3275 - val_loss: 1.8019 - val_accuracy: 0.3334
# Epoch 15/30
# 198/198 [==============================] - 12s 60ms/step - loss: 1.8017 - accuracy: 0.3292 - val_loss: 1.8196 - val_accuracy: 0.3275
# Epoch 16/30
# 198/198 [==============================] - 12s 58ms/step - loss: 1.8005 - accuracy: 0.3329 - val_loss: 1.8071 - val_accuracy: 0.3313
# Epoch 17/30
# 198/198 [==============================] - 11s 58ms/step - loss: 1.7945 - accuracy: 0.3371 - val_loss: 1.8047 - val_accuracy: 0.3385
# Epoch 18/30
# 198/198 [==============================] - 11s 58ms/step - loss: 1.7937 - accuracy: 0.3390 - val_loss: 1.8004 - val_accuracy: 0.3378
# Epoch 19/30
# 198/198 [==============================] - 11s 58ms/step - loss: 1.7877 - accuracy: 0.3396 - val_loss: 1.8059 - val_accuracy: 0.3210
# Epoch 20/30
# 198/198 [==============================] - 11s 57ms/step - loss: 1.7900 - accuracy: 0.3356 - val_loss: 1.7845 - val_accuracy: 0.3375
# Epoch 21/30
# 198/198 [==============================] - 12s 58ms/step - loss: 1.7855 - accuracy: 0.3405 - val_loss: 1.7887 - val_accuracy: 0.3359
# Epoch 22/30
# 198/198 [==============================] - 11s 58ms/step - loss: 1.7818 - accuracy: 0.3438 - val_loss: 1.8073 - val_accuracy: 0.3240
# Epoch 23/30
# 198/198 [==============================] - 11s 58ms/step - loss: 1.7758 - accuracy: 0.3445 - val_loss: 1.7995 - val_accuracy: 0.3329
# Epoch 24/30
# 198/198 [==============================] - 11s 57ms/step - loss: 1.7730 - accuracy: 0.3477 - val_loss: 1.8185 - val_accuracy: 0.3282
# 11.366207659244537
# trained image count:  31553
# Images Left:  0
# Estimated completion time:  0:00:00
# ---------------- rerun_30epoch_0.001lr_128bs_512_128_128_64_landmark Training Completed ------------------
# 100/100 [==============================] - 1s 10ms/step - loss: 1.7149 - accuracy: 0.3400
# 100/100 [==============================] - 1s 10ms/step - loss: 1.6758 - accuracy: 0.3400
# 100/100 [==============================] - 1s 12ms/step - loss: 1.9346 - accuracy: 0.3400
# 100/100 [==============================] - 2s 20ms/step - loss: 1.8599 - accuracy: 0.2900
# 100/100 [==============================] - 2s 22ms/step - loss: 1.9502 - accuracy: 0.2700
# 100/100 [==============================] - 2s 17ms/step - loss: 1.7796 - accuracy: 0.3300
# 100/100 [==============================] - 2s 23ms/step - loss: 1.9595 - accuracy: 0.3000
# 100/100 [==============================] - 2s 18ms/step - loss: 1.8226 - accuracy: 0.3200
# 100/100 [==============================] - 2s 21ms/step - loss: 1.9801 - accuracy: 0.2400
# 100/100 [==============================] - 2s 18ms/step - loss: 1.7565 - accuracy: 0.3300
# 100/100 [==============================] - 2s 18ms/step - loss: 1.8496 - accuracy: 0.3200
# 100/100 [==============================] - 2s 21ms/step - loss: 1.8090 - accuracy: 0.2500
# 100/100 [==============================] - 2s 17ms/step - loss: 1.9069 - accuracy: 0.3400
# 100/100 [==============================] - 2s 23ms/step - loss: 1.9093 - accuracy: 0.3400
# 100/100 [==============================] - 1s 13ms/step - loss: 1.8323 - accuracy: 0.3300
# 100/100 [==============================] - 2s 22ms/step - loss: 1.7735 - accuracy: 0.3200
# 100/100 [==============================] - 1s 13ms/step - loss: 1.6940 - accuracy: 0.4200
# 100/100 [==============================] - 2s 22ms/step - loss: 2.0263 - accuracy: 0.3000
# 100/100 [==============================] - 2s 18ms/step - loss: 1.8444 - accuracy: 0.3300
# 100/100 [==============================] - 2s 20ms/step - loss: 1.7537 - accuracy: 0.3300
# 100/100 [==============================] - 2s 17ms/step - loss: 1.7146 - accuracy: 0.4300
# 100/100 [==============================] - 2s 17ms/step - loss: 1.6937 - accuracy: 0.3400
# 100/100 [==============================] - 2s 21ms/step - loss: 1.8883 - accuracy: 0.2800
# 100/100 [==============================] - 1s 14ms/step - loss: 1.7935 - accuracy: 0.3300
# 100/100 [==============================] - 2s 23ms/step - loss: 1.7424 - accuracy: 0.3900
# 100/100 [==============================] - 1s 12ms/step - loss: 1.7449 - accuracy: 0.3600
# 100/100 [==============================] - 2s 24ms/step - loss: 1.7628 - accuracy: 0.4000
# 100/100 [==============================] - 1s 12ms/step - loss: 1.7290 - accuracy: 0.3800
# 100/100 [==============================] - 3s 29ms/step - loss: 1.8451 - accuracy: 0.2400
# 100/100 [==============================] - 1s 12ms/step - loss: 1.8111 - accuracy: 0.3200
# 100/100 [==============================] - 3s 35ms/step - loss: 1.8143 - accuracy: 0.3100
# 100/100 [==============================] - 1s 12ms/step - loss: 1.8218 - accuracy: 0.4000
# 100/100 [==============================] - 3s 30ms/step - loss: 1.7658 - accuracy: 0.2900
# 100/100 [==============================] - 1s 12ms/step - loss: 1.8691 - accuracy: 0.3500
# 100/100 [==============================] - 3s 28ms/step - loss: 1.7176 - accuracy: 0.3100
# 100/100 [==============================] - 2s 17ms/step - loss: 1.9654 - accuracy: 0.2400
# 100/100 [==============================] - 4s 39ms/step - loss: 1.7312 - accuracy: 0.3100
# 100/100 [==============================] - 2s 16ms/step - loss: 1.8568 - accuracy: 0.3400
# 100/100 [==============================] - 2s 16ms/step - loss: 1.9793 - accuracy: 0.2500
# 87/87 [==============================] - 2s 26ms/step - loss: 1.9197 - accuracy: 0.3103
# ==========FINISH TESTING===========
#
#   model name: rerun_30epoch_0.001lr_128bs_512_128_128_64_landmark
#   average lost: 1.8249806851148604
#   average accuracy: 0.32400862239301204
#
# loading image
# Epoch 1/30
# 198/198 [==============================] - 12s 57ms/step - loss: 2.0472 - accuracy: 0.1731 - val_loss: 2.0113 - val_accuracy: 0.2079
# Epoch 2/30
# 198/198 [==============================] - 12s 60ms/step - loss: 1.9813 - accuracy: 0.2233 - val_loss: 1.9716 - val_accuracy: 0.2291
# Epoch 3/30
# 198/198 [==============================] - 12s 59ms/step - loss: 1.9420 - accuracy: 0.2504 - val_loss: 1.9192 - val_accuracy: 0.2665
# Epoch 4/30
# 198/198 [==============================] - 11s 57ms/step - loss: 1.9218 - accuracy: 0.2629 - val_loss: 1.9187 - val_accuracy: 0.2662
# Epoch 5/30
# 198/198 [==============================] - 11s 56ms/step - loss: 1.9007 - accuracy: 0.2738 - val_loss: 1.8975 - val_accuracy: 0.2724
# Epoch 6/30
# 198/198 [==============================] - 11s 56ms/step - loss: 1.8803 - accuracy: 0.2874 - val_loss: 1.8632 - val_accuracy: 0.2911
# Epoch 7/30
# 198/198 [==============================] - 11s 57ms/step - loss: 1.8548 - accuracy: 0.3004 - val_loss: 1.8476 - val_accuracy: 0.3006
# Epoch 8/30
# 198/198 [==============================] - 11s 57ms/step - loss: 1.8434 - accuracy: 0.3036 - val_loss: 1.8246 - val_accuracy: 0.3131
# Epoch 9/30
# 198/198 [==============================] - 12s 58ms/step - loss: 1.8374 - accuracy: 0.3102 - val_loss: 1.8367 - val_accuracy: 0.3093
# Epoch 10/30
# 198/198 [==============================] - 12s 62ms/step - loss: 1.8281 - accuracy: 0.3175 - val_loss: 1.8181 - val_accuracy: 0.3156
# Epoch 11/30
# 198/198 [==============================] - 12s 61ms/step - loss: 1.8213 - accuracy: 0.3219 - val_loss: 1.8243 - val_accuracy: 0.3188
# Epoch 12/30
# 198/198 [==============================] - 12s 60ms/step - loss: 1.8167 - accuracy: 0.3253 - val_loss: 1.8044 - val_accuracy: 0.3286
# Epoch 13/30
# 198/198 [==============================] - 12s 60ms/step - loss: 1.8077 - accuracy: 0.3285 - val_loss: 1.8076 - val_accuracy: 0.3305
# Epoch 14/30
# 198/198 [==============================] - 12s 59ms/step - loss: 1.8083 - accuracy: 0.3266 - val_loss: 1.7964 - val_accuracy: 0.3302
# Epoch 15/30
# 198/198 [==============================] - 11s 57ms/step - loss: 1.8022 - accuracy: 0.3305 - val_loss: 1.8030 - val_accuracy: 0.3280
# Epoch 16/30
# 198/198 [==============================] - 11s 58ms/step - loss: 1.7965 - accuracy: 0.3348 - val_loss: 1.8189 - val_accuracy: 0.3175
# Epoch 17/30
# 198/198 [==============================] - 11s 57ms/step - loss: 1.7944 - accuracy: 0.3359 - val_loss: 1.7856 - val_accuracy: 0.3337
# Epoch 18/30
# 198/198 [==============================] - 11s 57ms/step - loss: 1.7907 - accuracy: 0.3386 - val_loss: 1.7989 - val_accuracy: 0.3305
# Epoch 19/30
# 198/198 [==============================] - 11s 57ms/step - loss: 1.7897 - accuracy: 0.3430 - val_loss: 1.8092 - val_accuracy: 0.3248
# Epoch 20/30
# 198/198 [==============================] - 11s 57ms/step - loss: 1.7795 - accuracy: 0.3422 - val_loss: 1.7782 - val_accuracy: 0.3443
# Epoch 21/30
# 198/198 [==============================] - 11s 57ms/step - loss: 1.7815 - accuracy: 0.3393 - val_loss: 1.8006 - val_accuracy: 0.3351
# Epoch 22/30
# 198/198 [==============================] - 11s 58ms/step - loss: 1.7815 - accuracy: 0.3422 - val_loss: 1.7893 - val_accuracy: 0.3316
# Epoch 23/30
# 198/198 [==============================] - 11s 58ms/step - loss: 1.7732 - accuracy: 0.3480 - val_loss: 1.7800 - val_accuracy: 0.3392
# Epoch 24/30
# 198/198 [==============================] - 11s 58ms/step - loss: 1.7710 - accuracy: 0.3497 - val_loss: 1.7807 - val_accuracy: 0.3418
# 11.505079140265783
# trained image count:  31553
# Images Left:  0
# Estimated completion time:  0:00:00
# ---------------- rerun_30epoch_0.001lr_128bs_512_128_128_128_landmark Training Completed ------------------
# 100/100 [==============================] - 1s 11ms/step - loss: 1.6767 - accuracy: 0.3800
# 100/100 [==============================] - 1s 10ms/step - loss: 1.6771 - accuracy: 0.3600
# 100/100 [==============================] - 1s 11ms/step - loss: 1.8815 - accuracy: 0.2900
# 100/100 [==============================] - 1s 13ms/step - loss: 1.8777 - accuracy: 0.2500
# 100/100 [==============================] - 3s 34ms/step - loss: 1.9308 - accuracy: 0.2400
# 100/100 [==============================] - 3s 34ms/step - loss: 1.7698 - accuracy: 0.3300
# 100/100 [==============================] - 2s 17ms/step - loss: 1.9474 - accuracy: 0.2700
# 100/100 [==============================] - 2s 19ms/step - loss: 1.8113 - accuracy: 0.3000
# 100/100 [==============================] - 1s 12ms/step - loss: 1.9663 - accuracy: 0.2500
# 100/100 [==============================] - 2s 20ms/step - loss: 1.7422 - accuracy: 0.3100
# 100/100 [==============================] - 2s 17ms/step - loss: 1.8475 - accuracy: 0.3200
# 100/100 [==============================] - 1s 14ms/step - loss: 1.8108 - accuracy: 0.3600
# 100/100 [==============================] - 2s 19ms/step - loss: 1.9035 - accuracy: 0.3100
# 100/100 [==============================] - 1s 12ms/step - loss: 1.9285 - accuracy: 0.3300
# 100/100 [==============================] - 2s 18ms/step - loss: 1.8234 - accuracy: 0.3400
# 100/100 [==============================] - 2s 19ms/step - loss: 1.7911 - accuracy: 0.3200
# 100/100 [==============================] - 1s 13ms/step - loss: 1.6993 - accuracy: 0.3900
# 100/100 [==============================] - 2s 18ms/step - loss: 2.0239 - accuracy: 0.2600
# 100/100 [==============================] - 2s 17ms/step - loss: 1.8448 - accuracy: 0.2700
# 100/100 [==============================] - 2s 16ms/step - loss: 1.7240 - accuracy: 0.3100
# 100/100 [==============================] - 2s 22ms/step - loss: 1.6911 - accuracy: 0.4500
# 100/100 [==============================] - 1s 13ms/step - loss: 1.6561 - accuracy: 0.3300
# 100/100 [==============================] - 2s 19ms/step - loss: 1.9305 - accuracy: 0.2700
# 100/100 [==============================] - 2s 16ms/step - loss: 1.8209 - accuracy: 0.3100
# 100/100 [==============================] - 2s 17ms/step - loss: 1.6882 - accuracy: 0.4100
# 100/100 [==============================] - 2s 22ms/step - loss: 1.7699 - accuracy: 0.3100
# 100/100 [==============================] - 1s 13ms/step - loss: 1.7684 - accuracy: 0.3800
# 100/100 [==============================] - 2s 22ms/step - loss: 1.7465 - accuracy: 0.3500
# 100/100 [==============================] - 1s 14ms/step - loss: 1.8508 - accuracy: 0.2900
# 100/100 [==============================] - 2s 17ms/step - loss: 1.7990 - accuracy: 0.3600
# 100/100 [==============================] - 2s 19ms/step - loss: 1.8071 - accuracy: 0.3300
# 100/100 [==============================] - 1s 13ms/step - loss: 1.7990 - accuracy: 0.3500
# 100/100 [==============================] - 2s 20ms/step - loss: 1.8115 - accuracy: 0.2800
# 100/100 [==============================] - 2s 21ms/step - loss: 1.8862 - accuracy: 0.2600
# 100/100 [==============================] - 1s 14ms/step - loss: 1.7101 - accuracy: 0.3200
# 100/100 [==============================] - 2s 18ms/step - loss: 1.9448 - accuracy: 0.3000
# 100/100 [==============================] - 1s 13ms/step - loss: 1.7013 - accuracy: 0.3800
# 100/100 [==============================] - 2s 22ms/step - loss: 1.8566 - accuracy: 0.3400
# 100/100 [==============================] - 2s 19ms/step - loss: 1.9843 - accuracy: 0.2200
# 87/87 [==============================] - 1s 13ms/step - loss: 1.9728 - accuracy: 0.2759
# ==========FINISH TESTING===========
#
#   model name: rerun_30epoch_0.001lr_128bs_512_128_128_128_landmark
#   average lost: 1.8218140393495559
#   average accuracy: 0.3176465529948473
#
# loading image
# Epoch 1/30
# 198/198 [==============================] - 12s 57ms/step - loss: 2.0490 - accuracy: 0.1670 - val_loss: 2.0287 - val_accuracy: 0.1884
# Epoch 2/30
# 198/198 [==============================] - 12s 58ms/step - loss: 1.9915 - accuracy: 0.2134 - val_loss: 1.9948 - val_accuracy: 0.2155
# Epoch 3/30
# 198/198 [==============================] - 12s 58ms/step - loss: 1.9587 - accuracy: 0.2423 - val_loss: 1.9407 - val_accuracy: 0.2534
# Epoch 4/30
# 198/198 [==============================] - 11s 58ms/step - loss: 1.9274 - accuracy: 0.2623 - val_loss: 1.9246 - val_accuracy: 0.2748
# Epoch 5/30
# 198/198 [==============================] - 11s 57ms/step - loss: 1.9170 - accuracy: 0.2668 - val_loss: 1.9211 - val_accuracy: 0.2711
# Epoch 6/30
# 198/198 [==============================] - 11s 56ms/step - loss: 1.9071 - accuracy: 0.2726 - val_loss: 1.9089 - val_accuracy: 0.2824
# Epoch 7/30
# 198/198 [==============================] - 11s 55ms/step - loss: 1.8976 - accuracy: 0.2820 - val_loss: 1.8943 - val_accuracy: 0.2868
# Epoch 8/30
# 198/198 [==============================] - 11s 55ms/step - loss: 1.8896 - accuracy: 0.2833 - val_loss: 1.8835 - val_accuracy: 0.2944
# Epoch 9/30
# 198/198 [==============================] - 11s 55ms/step - loss: 1.8817 - accuracy: 0.2851 - val_loss: 1.8889 - val_accuracy: 0.2846
# Epoch 10/30
# 198/198 [==============================] - 11s 54ms/step - loss: 1.8714 - accuracy: 0.2966 - val_loss: 1.8721 - val_accuracy: 0.2981
# Epoch 11/30
# 198/198 [==============================] - 11s 56ms/step - loss: 1.8593 - accuracy: 0.3024 - val_loss: 1.8668 - val_accuracy: 0.2836
# Epoch 12/30
# 198/198 [==============================] - 11s 55ms/step - loss: 1.8516 - accuracy: 0.3046 - val_loss: 1.8839 - val_accuracy: 0.2760
# Epoch 13/30
# 198/198 [==============================] - 11s 56ms/step - loss: 1.8482 - accuracy: 0.3073 - val_loss: 1.8693 - val_accuracy: 0.3028
# Epoch 14/30
# 198/198 [==============================] - 11s 56ms/step - loss: 1.8401 - accuracy: 0.3066 - val_loss: 1.8461 - val_accuracy: 0.3090
# Epoch 15/30
# 198/198 [==============================] - 11s 57ms/step - loss: 1.8354 - accuracy: 0.3113 - val_loss: 1.8395 - val_accuracy: 0.3060
# Epoch 16/30
# 198/198 [==============================] - 11s 57ms/step - loss: 1.8239 - accuracy: 0.3215 - val_loss: 1.8424 - val_accuracy: 0.3076
# Epoch 17/30
# 198/198 [==============================] - 11s 57ms/step - loss: 1.8225 - accuracy: 0.3205 - val_loss: 1.8573 - val_accuracy: 0.2923
# Epoch 18/30
# 198/198 [==============================] - 11s 57ms/step - loss: 1.8209 - accuracy: 0.3227 - val_loss: 1.8280 - val_accuracy: 0.3258
# Epoch 19/30
# 198/198 [==============================] - 11s 56ms/step - loss: 1.8176 - accuracy: 0.3235 - val_loss: 1.8273 - val_accuracy: 0.3148
# Epoch 20/30
# 198/198 [==============================] - 11s 56ms/step - loss: 1.8118 - accuracy: 0.3288 - val_loss: 1.8062 - val_accuracy: 0.3339
# Epoch 21/30
# 198/198 [==============================] - 11s 56ms/step - loss: 1.8051 - accuracy: 0.3298 - val_loss: 1.8409 - val_accuracy: 0.3118
# Epoch 22/30
# 198/198 [==============================] - 11s 56ms/step - loss: 1.7993 - accuracy: 0.3356 - val_loss: 1.8167 - val_accuracy: 0.3228
# Epoch 23/30
# 198/198 [==============================] - 11s 56ms/step - loss: 1.7997 - accuracy: 0.3295 - val_loss: 1.8194 - val_accuracy: 0.3193
# Epoch 24/30
# 198/198 [==============================] - 11s 56ms/step - loss: 1.7910 - accuracy: 0.3369 - val_loss: 1.8077 - val_accuracy: 0.3328
# 11.131660759449005
# trained image count:  31553
# Images Left:  0
# Estimated completion time:  0:00:00
# ---------------- rerun_30epoch_0.001lr_128bs_512_192_128_64_landmark Training Completed ------------------
# 100/100 [==============================] - 1s 11ms/step - loss: 1.7355 - accuracy: 0.3700
# 100/100 [==============================] - 1s 11ms/step - loss: 1.7492 - accuracy: 0.3300
# 100/100 [==============================] - 1s 11ms/step - loss: 1.9005 - accuracy: 0.3200
# 100/100 [==============================] - 2s 15ms/step - loss: 1.8626 - accuracy: 0.2800
# 100/100 [==============================] - 2s 21ms/step - loss: 1.9108 - accuracy: 0.3300
# 100/100 [==============================] - 2s 20ms/step - loss: 1.8080 - accuracy: 0.3300
# 100/100 [==============================] - 1s 12ms/step - loss: 1.9655 - accuracy: 0.2300
# 100/100 [==============================] - 2s 19ms/step - loss: 1.8343 - accuracy: 0.3000
# 100/100 [==============================] - 2s 19ms/step - loss: 1.9232 - accuracy: 0.2600
# 100/100 [==============================] - 1s 12ms/step - loss: 1.7828 - accuracy: 0.2900
# 100/100 [==============================] - 2s 21ms/step - loss: 1.8415 - accuracy: 0.3600
# 100/100 [==============================] - 1s 14ms/step - loss: 1.8427 - accuracy: 0.3200
# 100/100 [==============================] - 2s 16ms/step - loss: 1.8729 - accuracy: 0.2900
# 100/100 [==============================] - 2s 22ms/step - loss: 1.9338 - accuracy: 0.3200
# 100/100 [==============================] - 1s 12ms/step - loss: 1.8489 - accuracy: 0.2900
# 100/100 [==============================] - 2s 18ms/step - loss: 1.7728 - accuracy: 0.3400
# 100/100 [==============================] - 2s 16ms/step - loss: 1.7524 - accuracy: 0.3700
# 100/100 [==============================] - 2s 18ms/step - loss: 1.9782 - accuracy: 0.2600
# 100/100 [==============================] - 2s 21ms/step - loss: 1.8537 - accuracy: 0.2700
# 100/100 [==============================] - 1s 13ms/step - loss: 1.8040 - accuracy: 0.2900
# 100/100 [==============================] - 2s 19ms/step - loss: 1.7391 - accuracy: 0.3600
# 100/100 [==============================] - 2s 19ms/step - loss: 1.7376 - accuracy: 0.3200
# 100/100 [==============================] - 1s 12ms/step - loss: 1.9283 - accuracy: 0.2600
# 100/100 [==============================] - 2s 18ms/step - loss: 1.7980 - accuracy: 0.3100
# 100/100 [==============================] - 2s 15ms/step - loss: 1.7116 - accuracy: 0.4500
# 100/100 [==============================] - 2s 16ms/step - loss: 1.7916 - accuracy: 0.3600
# 100/100 [==============================] - 2s 22ms/step - loss: 1.8032 - accuracy: 0.3400
# 100/100 [==============================] - 1s 13ms/step - loss: 1.7687 - accuracy: 0.4000
# 100/100 [==============================] - 2s 18ms/step - loss: 1.8591 - accuracy: 0.2900
# 100/100 [==============================] - 2s 19ms/step - loss: 1.7922 - accuracy: 0.4000
# 100/100 [==============================] - 1s 14ms/step - loss: 1.7775 - accuracy: 0.3100
# 100/100 [==============================] - 2s 19ms/step - loss: 1.8384 - accuracy: 0.4000
# 100/100 [==============================] - 1s 12ms/step - loss: 1.7685 - accuracy: 0.3200
# 100/100 [==============================] - 2s 19ms/step - loss: 1.9062 - accuracy: 0.3100
# 100/100 [==============================] - 1s 15ms/step - loss: 1.7448 - accuracy: 0.3800
# 100/100 [==============================] - 1s 13ms/step - loss: 1.9498 - accuracy: 0.2600
# 100/100 [==============================] - 2s 19ms/step - loss: 1.7274 - accuracy: 0.3900
# 100/100 [==============================] - 1s 12ms/step - loss: 1.8704 - accuracy: 0.3000
# 100/100 [==============================] - 2s 15ms/step - loss: 1.9469 - accuracy: 0.2600
# 87/87 [==============================] - 2s 19ms/step - loss: 1.9339 - accuracy: 0.2644
# ==========FINISH TESTING===========
#
#   model name: rerun_30epoch_0.001lr_128bs_512_192_128_64_landmark
#   average lost: 1.834157434105873
#   average accuracy: 0.32085919566452503
#
# loading image
# Epoch 1/30
# 198/198 [==============================] - 12s 61ms/step - loss: 2.0467 - accuracy: 0.1733 - val_loss: 2.0136 - val_accuracy: 0.1997
# Epoch 2/30
# 198/198 [==============================] - 12s 60ms/step - loss: 1.9756 - accuracy: 0.2243 - val_loss: 1.9708 - val_accuracy: 0.2440
# Epoch 3/30
# 198/198 [==============================] - 12s 60ms/step - loss: 1.9428 - accuracy: 0.2534 - val_loss: 1.9268 - val_accuracy: 0.2676
# Epoch 4/30
# 198/198 [==============================] - 12s 61ms/step - loss: 1.9149 - accuracy: 0.2694 - val_loss: 1.9188 - val_accuracy: 0.2660
# Epoch 5/30
# 198/198 [==============================] - 12s 61ms/step - loss: 1.9036 - accuracy: 0.2751 - val_loss: 1.9166 - val_accuracy: 0.2697
# Epoch 6/30
# 198/198 [==============================] - 12s 61ms/step - loss: 1.8872 - accuracy: 0.2826 - val_loss: 1.8858 - val_accuracy: 0.2805
# Epoch 7/30
# 198/198 [==============================] - 12s 60ms/step - loss: 1.8664 - accuracy: 0.2948 - val_loss: 1.8737 - val_accuracy: 0.2855
# Epoch 8/30
# 198/198 [==============================] - 12s 61ms/step - loss: 1.8479 - accuracy: 0.3040 - val_loss: 1.8417 - val_accuracy: 0.3058
# Epoch 9/30
# 198/198 [==============================] - 12s 61ms/step - loss: 1.8395 - accuracy: 0.3140 - val_loss: 1.8364 - val_accuracy: 0.3126
# Epoch 10/30
# 198/198 [==============================] - 12s 60ms/step - loss: 1.8320 - accuracy: 0.3137 - val_loss: 1.8592 - val_accuracy: 0.2854
# Epoch 11/30
# 198/198 [==============================] - 12s 60ms/step - loss: 1.8200 - accuracy: 0.3222 - val_loss: 1.8004 - val_accuracy: 0.3293
# Epoch 12/30
# 198/198 [==============================] - 12s 60ms/step - loss: 1.8153 - accuracy: 0.3214 - val_loss: 1.8353 - val_accuracy: 0.3030
# Epoch 13/30
# 198/198 [==============================] - 12s 60ms/step - loss: 1.8084 - accuracy: 0.3291 - val_loss: 1.8650 - val_accuracy: 0.3042
# Epoch 14/30
# 198/198 [==============================] - 12s 61ms/step - loss: 1.8109 - accuracy: 0.3251 - val_loss: 1.8197 - val_accuracy: 0.3125
# Epoch 15/30
# 198/198 [==============================] - 12s 60ms/step - loss: 1.7969 - accuracy: 0.3375 - val_loss: 1.8134 - val_accuracy: 0.3229
# 11.97971092859904
# trained image count:  31553
# Images Left:  0
# Estimated completion time:  0:00:00
# ---------------- rerun_30epoch_0.001lr_128bs_764_256_256_256_landmark Training Completed ------------------
# 100/100 [==============================] - 1s 10ms/step - loss: 1.6902 - accuracy: 0.3500
# 100/100 [==============================] - 1s 10ms/step - loss: 1.7167 - accuracy: 0.3800
# 100/100 [==============================] - 1s 10ms/step - loss: 1.9174 - accuracy: 0.3200
# 100/100 [==============================] - 1s 10ms/step - loss: 1.8900 - accuracy: 0.2300
# 100/100 [==============================] - 1s 12ms/step - loss: 1.9154 - accuracy: 0.2700
# 100/100 [==============================] - 2s 23ms/step - loss: 1.7940 - accuracy: 0.3400
# 100/100 [==============================] - 3s 28ms/step - loss: 1.9493 - accuracy: 0.2900
# 100/100 [==============================] - 1s 12ms/step - loss: 1.8005 - accuracy: 0.3200
# 100/100 [==============================] - 3s 35ms/step - loss: 1.9801 - accuracy: 0.2200
# 100/100 [==============================] - 2s 21ms/step - loss: 1.7660 - accuracy: 0.3500
# 100/100 [==============================] - 2s 16ms/step - loss: 1.8832 - accuracy: 0.3200
# 100/100 [==============================] - 4s 35ms/step - loss: 1.8526 - accuracy: 0.2500
# 100/100 [==============================] - 1s 14ms/step - loss: 1.8787 - accuracy: 0.3300
# 100/100 [==============================] - 2s 18ms/step - loss: 1.9490 - accuracy: 0.3200
# 100/100 [==============================] - 1s 13ms/step - loss: 1.8162 - accuracy: 0.2700
# 100/100 [==============================] - 2s 21ms/step - loss: 1.7982 - accuracy: 0.2900
# 100/100 [==============================] - 2s 17ms/step - loss: 1.7150 - accuracy: 0.3800
# 100/100 [==============================] - 2s 16ms/step - loss: 2.0387 - accuracy: 0.2600
# 100/100 [==============================] - 2s 16ms/step - loss: 1.8687 - accuracy: 0.2800
# 100/100 [==============================] - 2s 19ms/step - loss: 1.8131 - accuracy: 0.2800
# 100/100 [==============================] - 2s 16ms/step - loss: 1.7562 - accuracy: 0.3800
# 100/100 [==============================] - 2s 17ms/step - loss: 1.7102 - accuracy: 0.3400
# 100/100 [==============================] - 2s 20ms/step - loss: 1.8749 - accuracy: 0.3000
# 100/100 [==============================] - 1s 13ms/step - loss: 1.8384 - accuracy: 0.2600
# 100/100 [==============================] - 2s 21ms/step - loss: 1.7201 - accuracy: 0.3900
# 100/100 [==============================] - 2s 20ms/step - loss: 1.7931 - accuracy: 0.3800
# 100/100 [==============================] - 1s 13ms/step - loss: 1.7408 - accuracy: 0.4000
# 100/100 [==============================] - 2s 17ms/step - loss: 1.7788 - accuracy: 0.3500
# 100/100 [==============================] - 2s 18ms/step - loss: 1.8528 - accuracy: 0.2400
# 100/100 [==============================] - 1s 14ms/step - loss: 1.8152 - accuracy: 0.3600
# 100/100 [==============================] - 2s 17ms/step - loss: 1.7778 - accuracy: 0.3300
# 100/100 [==============================] - 2s 18ms/step - loss: 1.8082 - accuracy: 0.3600
# 100/100 [==============================] - 1s 12ms/step - loss: 1.7650 - accuracy: 0.3700
# 100/100 [==============================] - 2s 18ms/step - loss: 1.9302 - accuracy: 0.2800
# 100/100 [==============================] - 2s 18ms/step - loss: 1.7391 - accuracy: 0.2800
# 100/100 [==============================] - 1s 12ms/step - loss: 1.9822 - accuracy: 0.2400
# 100/100 [==============================] - 2s 17ms/step - loss: 1.7294 - accuracy: 0.3200
# 100/100 [==============================] - 2s 16ms/step - loss: 1.8897 - accuracy: 0.3000
# 100/100 [==============================] - 1s 12ms/step - loss: 1.9530 - accuracy: 0.2400
# 87/87 [==============================] - 1s 15ms/step - loss: 1.9339 - accuracy: 0.2759
# ==========FINISH TESTING===========
#
#   model name: rerun_30epoch_0.001lr_128bs_764_256_256_256_landmark
#   average lost: 1.8355489522218704
#   average accuracy: 0.31114655137062075
#
# loading image
# Epoch 1/30
# 198/198 [==============================] - 13s 63ms/step - loss: 2.0428 - accuracy: 0.1741 - val_loss: 2.0028 - val_accuracy: 0.2063
# Epoch 2/30
# 198/198 [==============================] - 12s 63ms/step - loss: 1.9685 - accuracy: 0.2299 - val_loss: 1.9505 - val_accuracy: 0.2553
# Epoch 3/30
# 198/198 [==============================] - 13s 63ms/step - loss: 1.9349 - accuracy: 0.2551 - val_loss: 1.9315 - val_accuracy: 0.2557
# Epoch 4/30
# 198/198 [==============================] - 13s 63ms/step - loss: 1.9196 - accuracy: 0.2669 - val_loss: 1.9260 - val_accuracy: 0.2667
# Epoch 5/30
# 198/198 [==============================] - 12s 62ms/step - loss: 1.9058 - accuracy: 0.2757 - val_loss: 1.9157 - val_accuracy: 0.2778
# Epoch 6/30
# 198/198 [==============================] - 12s 63ms/step - loss: 1.9020 - accuracy: 0.2796 - val_loss: 1.8958 - val_accuracy: 0.2889
# Epoch 7/30
# 198/198 [==============================] - 12s 63ms/step - loss: 1.8802 - accuracy: 0.2899 - val_loss: 1.8790 - val_accuracy: 0.2909
# Epoch 8/30
# 198/198 [==============================] - 12s 63ms/step - loss: 1.8603 - accuracy: 0.2953 - val_loss: 1.8610 - val_accuracy: 0.2974
# Epoch 9/30
# 198/198 [==============================] - 13s 64ms/step - loss: 1.8372 - accuracy: 0.3117 - val_loss: 1.8639 - val_accuracy: 0.3014
# Epoch 10/30
# 198/198 [==============================] - 13s 64ms/step - loss: 1.8387 - accuracy: 0.3138 - val_loss: 1.8323 - val_accuracy: 0.3201
# Epoch 11/30
# 198/198 [==============================] - 13s 64ms/step - loss: 1.8271 - accuracy: 0.3162 - val_loss: 1.8152 - val_accuracy: 0.3263
# Epoch 12/30
# 198/198 [==============================] - 13s 63ms/step - loss: 1.8222 - accuracy: 0.3199 - val_loss: 1.8228 - val_accuracy: 0.3218
# Epoch 13/30
# 198/198 [==============================] - 12s 63ms/step - loss: 1.8140 - accuracy: 0.3247 - val_loss: 1.8322 - val_accuracy: 0.3115
# Epoch 14/30
# 198/198 [==============================] - 12s 63ms/step - loss: 1.8137 - accuracy: 0.3266 - val_loss: 1.8144 - val_accuracy: 0.3274
# Epoch 15/30
# 198/198 [==============================] - 13s 63ms/step - loss: 1.8068 - accuracy: 0.3290 - val_loss: 1.7970 - val_accuracy: 0.3343
# Epoch 16/30
# 198/198 [==============================] - 13s 64ms/step - loss: 1.8008 - accuracy: 0.3350 - val_loss: 1.8047 - val_accuracy: 0.3289
# Epoch 17/30
# 198/198 [==============================] - 13s 63ms/step - loss: 1.7955 - accuracy: 0.3342 - val_loss: 1.7876 - val_accuracy: 0.3419
# Epoch 18/30
# 198/198 [==============================] - 12s 63ms/step - loss: 1.7978 - accuracy: 0.3359 - val_loss: 1.8054 - val_accuracy: 0.3199
# Epoch 19/30
# 198/198 [==============================] - 13s 63ms/step - loss: 1.7890 - accuracy: 0.3395 - val_loss: 1.7957 - val_accuracy: 0.3328
# Epoch 20/30
# 198/198 [==============================] - 13s 63ms/step - loss: 1.7872 - accuracy: 0.3371 - val_loss: 1.7946 - val_accuracy: 0.3388
# Epoch 21/30
# 198/198 [==============================] - 12s 63ms/step - loss: 1.7871 - accuracy: 0.3398 - val_loss: 1.8337 - val_accuracy: 0.3193
# 12.53245032401312
# trained image count:  31553
# Images Left:  0
# Estimated completion time:  0:00:00
# ---------------- rerun_30epoch_0.001lr_128bs_764_384_192_128_landmark Training Completed ------------------
# 100/100 [==============================] - 1s 11ms/step - loss: 1.6581 - accuracy: 0.3900
# 100/100 [==============================] - 1s 11ms/step - loss: 1.7157 - accuracy: 0.3600
# 100/100 [==============================] - 1s 10ms/step - loss: 1.9309 - accuracy: 0.2500
# 100/100 [==============================] - 1s 12ms/step - loss: 1.8420 - accuracy: 0.3100
# 100/100 [==============================] - 1s 13ms/step - loss: 1.8973 - accuracy: 0.3000
# 100/100 [==============================] - 2s 21ms/step - loss: 1.7505 - accuracy: 0.3300
# 100/100 [==============================] - 2s 18ms/step - loss: 1.9406 - accuracy: 0.3400
# 100/100 [==============================] - 1s 13ms/step - loss: 1.7936 - accuracy: 0.3000
# 100/100 [==============================] - 2s 20ms/step - loss: 1.9598 - accuracy: 0.2500
# 100/100 [==============================] - 2s 18ms/step - loss: 1.7420 - accuracy: 0.3700
# 100/100 [==============================] - 2s 15ms/step - loss: 1.8531 - accuracy: 0.3600
# 100/100 [==============================] - 2s 22ms/step - loss: 1.8108 - accuracy: 0.3400
# 100/100 [==============================] - 1s 13ms/step - loss: 1.8932 - accuracy: 0.3100
# 100/100 [==============================] - 2s 20ms/step - loss: 1.9301 - accuracy: 0.3200
# 100/100 [==============================] - 2s 20ms/step - loss: 1.7938 - accuracy: 0.3600
# 100/100 [==============================] - 1s 14ms/step - loss: 1.7727 - accuracy: 0.3500
# 100/100 [==============================] - 2s 17ms/step - loss: 1.6780 - accuracy: 0.4200
# 100/100 [==============================] - 1s 14ms/step - loss: 1.9829 - accuracy: 0.2800
# 100/100 [==============================] - 2s 18ms/step - loss: 1.8581 - accuracy: 0.2900
# 100/100 [==============================] - 2s 20ms/step - loss: 1.7582 - accuracy: 0.3400
# 100/100 [==============================] - 1s 13ms/step - loss: 1.7324 - accuracy: 0.3900
# 100/100 [==============================] - 2s 19ms/step - loss: 1.6879 - accuracy: 0.3300
# 100/100 [==============================] - 2s 18ms/step - loss: 1.9185 - accuracy: 0.2500
# 100/100 [==============================] - 1s 13ms/step - loss: 1.8203 - accuracy: 0.3500
# 100/100 [==============================] - 2s 21ms/step - loss: 1.7249 - accuracy: 0.3800
# 100/100 [==============================] - 2s 18ms/step - loss: 1.7667 - accuracy: 0.3400
# 100/100 [==============================] - 1s 13ms/step - loss: 1.7554 - accuracy: 0.4000
# 100/100 [==============================] - 2s 18ms/step - loss: 1.7629 - accuracy: 0.3400
# 100/100 [==============================] - 2s 18ms/step - loss: 1.8455 - accuracy: 0.2600
# 100/100 [==============================] - 1s 12ms/step - loss: 1.7989 - accuracy: 0.3700
# 100/100 [==============================] - 2s 18ms/step - loss: 1.7873 - accuracy: 0.3300
# 100/100 [==============================] - 1s 15ms/step - loss: 1.8184 - accuracy: 0.3600
# 100/100 [==============================] - 2s 17ms/step - loss: 1.7770 - accuracy: 0.3300
# 100/100 [==============================] - 2s 18ms/step - loss: 1.8891 - accuracy: 0.2300
# 100/100 [==============================] - 1s 12ms/step - loss: 1.7198 - accuracy: 0.3000
# 100/100 [==============================] - 2s 18ms/step - loss: 1.9338 - accuracy: 0.2600
# 100/100 [==============================] - 2s 17ms/step - loss: 1.7177 - accuracy: 0.3600
# 100/100 [==============================] - 1s 12ms/step - loss: 1.8816 - accuracy: 0.3000
# 100/100 [==============================] - 2s 19ms/step - loss: 1.9649 - accuracy: 0.2500
# 87/87 [==============================] - 1s 12ms/step - loss: 1.9342 - accuracy: 0.3448
# ==========FINISH TESTING===========
#
#   model name: rerun_30epoch_0.001lr_128bs_764_384_192_128_landmark
#   average lost: 1.8199634939432143
#   average accuracy: 0.3261206928640604
#
# loading image
# Epoch 1/30
# 198/198 [==============================] - 14s 68ms/step - loss: 2.0572 - accuracy: 0.1582 - val_loss: 2.0215 - val_accuracy: 0.2027
# Epoch 2/30
# 198/198 [==============================] - 13s 68ms/step - loss: 1.9866 - accuracy: 0.2207 - val_loss: 1.9604 - val_accuracy: 0.2351
# Epoch 3/30
# 198/198 [==============================] - 13s 68ms/step - loss: 1.9366 - accuracy: 0.2551 - val_loss: 1.9175 - val_accuracy: 0.2779
# Epoch 4/30
# 198/198 [==============================] - 13s 68ms/step - loss: 1.9170 - accuracy: 0.2669 - val_loss: 1.9072 - val_accuracy: 0.2733
# Epoch 5/30
# 198/198 [==============================] - 14s 68ms/step - loss: 1.9006 - accuracy: 0.2751 - val_loss: 1.9091 - val_accuracy: 0.2824
# Epoch 6/30
# 198/198 [==============================] - 13s 68ms/step - loss: 1.8885 - accuracy: 0.2808 - val_loss: 1.8743 - val_accuracy: 0.2957
# Epoch 7/30
# 198/198 [==============================] - 14s 69ms/step - loss: 1.8657 - accuracy: 0.2955 - val_loss: 1.8462 - val_accuracy: 0.3163
# Epoch 8/30
# 198/198 [==============================] - 14s 69ms/step - loss: 1.8499 - accuracy: 0.3050 - val_loss: 1.8671 - val_accuracy: 0.3011
# Epoch 9/30
# 198/198 [==============================] - 14s 69ms/step - loss: 1.8395 - accuracy: 0.3086 - val_loss: 1.8406 - val_accuracy: 0.3003
# Epoch 10/30
# 198/198 [==============================] - 14s 69ms/step - loss: 1.8276 - accuracy: 0.3156 - val_loss: 1.8227 - val_accuracy: 0.3206
# Epoch 11/30
# 198/198 [==============================] - 14s 69ms/step - loss: 1.8206 - accuracy: 0.3218 - val_loss: 1.8137 - val_accuracy: 0.3232
# Epoch 12/30
# 198/198 [==============================] - 14s 69ms/step - loss: 1.8127 - accuracy: 0.3225 - val_loss: 1.8116 - val_accuracy: 0.3261
# Epoch 13/30
# 198/198 [==============================] - 14s 69ms/step - loss: 1.8098 - accuracy: 0.3238 - val_loss: 1.8070 - val_accuracy: 0.3343
# Epoch 14/30
# 198/198 [==============================] - 14s 68ms/step - loss: 1.8042 - accuracy: 0.3323 - val_loss: 1.8064 - val_accuracy: 0.3299
# Epoch 15/30
# 198/198 [==============================] - 14s 68ms/step - loss: 1.7963 - accuracy: 0.3334 - val_loss: 1.8024 - val_accuracy: 0.3242
# Epoch 16/30
# 198/198 [==============================] - 14s 68ms/step - loss: 1.7924 - accuracy: 0.3349 - val_loss: 1.8095 - val_accuracy: 0.3282
# Epoch 17/30
# 198/198 [==============================] - 14s 69ms/step - loss: 1.7874 - accuracy: 0.3395 - val_loss: 1.7913 - val_accuracy: 0.3286
# Epoch 18/30
# 198/198 [==============================] - 14s 69ms/step - loss: 1.7801 - accuracy: 0.3465 - val_loss: 1.7914 - val_accuracy: 0.3332
# Epoch 19/30
# 198/198 [==============================] - 14s 69ms/step - loss: 1.7798 - accuracy: 0.3458 - val_loss: 1.7850 - val_accuracy: 0.3394
# Epoch 20/30
# 198/198 [==============================] - 13s 68ms/step - loss: 1.7749 - accuracy: 0.3465 - val_loss: 1.7896 - val_accuracy: 0.3383
# Epoch 21/30
# 198/198 [==============================] - 14s 68ms/step - loss: 1.7737 - accuracy: 0.3487 - val_loss: 1.7840 - val_accuracy: 0.3350
# Epoch 22/30
# 198/198 [==============================] - 14s 69ms/step - loss: 1.7609 - accuracy: 0.3526 - val_loss: 1.7929 - val_accuracy: 0.3293
# Epoch 23/30
# 198/198 [==============================] - 14s 69ms/step - loss: 1.7634 - accuracy: 0.3514 - val_loss: 1.7845 - val_accuracy: 0.3388
# Epoch 24/30
# 198/198 [==============================] - 14s 69ms/step - loss: 1.7602 - accuracy: 0.3519 - val_loss: 1.7844 - val_accuracy: 0.3410
# Epoch 25/30
# 198/198 [==============================] - 14s 69ms/step - loss: 1.7585 - accuracy: 0.3529 - val_loss: 1.7834 - val_accuracy: 0.3438
# Epoch 26/30
# 198/198 [==============================] - 14s 69ms/step - loss: 1.7519 - accuracy: 0.3579 - val_loss: 1.7832 - val_accuracy: 0.3435
# Epoch 27/30
# 198/198 [==============================] - 14s 69ms/step - loss: 1.7542 - accuracy: 0.3583 - val_loss: 1.7753 - val_accuracy: 0.3562
# Epoch 28/30
# 198/198 [==============================] - 14s 68ms/step - loss: 1.7426 - accuracy: 0.3634 - val_loss: 1.7996 - val_accuracy: 0.3361
# Epoch 29/30
# 198/198 [==============================] - 14s 69ms/step - loss: 1.7497 - accuracy: 0.3583 - val_loss: 1.7800 - val_accuracy: 0.3459
# Epoch 30/30
# 198/198 [==============================] - 14s 68ms/step - loss: 1.7387 - accuracy: 0.3623 - val_loss: 1.7886 - val_accuracy: 0.3377
# 13.60031038125356
# trained image count:  31553
# Images Left:  0
# Estimated completion time:  0:00:00
# ---------------- rerun_30epoch_0.001lr_128bs_764_512_256_192_landmark Training Completed ------------------
# 100/100 [==============================] - 1s 10ms/step - loss: 1.7459 - accuracy: 0.3800
# 100/100 [==============================] - 1s 10ms/step - loss: 1.6413 - accuracy: 0.3800
# 100/100 [==============================] - 1s 11ms/step - loss: 1.9336 - accuracy: 0.3200
# 100/100 [==============================] - 1s 10ms/step - loss: 1.9034 - accuracy: 0.2700
# 100/100 [==============================] - 1s 12ms/step - loss: 1.9523 - accuracy: 0.3200
# 100/100 [==============================] - 3s 25ms/step - loss: 1.7631 - accuracy: 0.3400
# 100/100 [==============================] - 2s 23ms/step - loss: 1.9585 - accuracy: 0.3100
# 100/100 [==============================] - 2s 16ms/step - loss: 1.8173 - accuracy: 0.3400
# 100/100 [==============================] - 2s 17ms/step - loss: 1.9570 - accuracy: 0.2600
# 100/100 [==============================] - 2s 22ms/step - loss: 1.7606 - accuracy: 0.3500
# 100/100 [==============================] - 2s 15ms/step - loss: 1.9084 - accuracy: 0.2900
# 100/100 [==============================] - 2s 23ms/step - loss: 1.8026 - accuracy: 0.3500
# 100/100 [==============================] - 1s 12ms/step - loss: 1.9078 - accuracy: 0.3200
# 100/100 [==============================] - 2s 25ms/step - loss: 1.9146 - accuracy: 0.3400
# 100/100 [==============================] - 1s 13ms/step - loss: 1.8360 - accuracy: 0.4000
# 100/100 [==============================] - 2s 25ms/step - loss: 1.8028 - accuracy: 0.3300
# 100/100 [==============================] - 1s 13ms/step - loss: 1.7143 - accuracy: 0.4100
# 100/100 [==============================] - 2s 19ms/step - loss: 2.0165 - accuracy: 0.3700
# 100/100 [==============================] - 2s 19ms/step - loss: 1.8369 - accuracy: 0.3600
# 100/100 [==============================] - 2s 21ms/step - loss: 1.7769 - accuracy: 0.3500
# 100/100 [==============================] - 2s 18ms/step - loss: 1.6923 - accuracy: 0.4100
# 100/100 [==============================] - 2s 15ms/step - loss: 1.6864 - accuracy: 0.3600
# 100/100 [==============================] - 2s 24ms/step - loss: 1.8576 - accuracy: 0.3600
# 100/100 [==============================] - 2s 19ms/step - loss: 1.7864 - accuracy: 0.3300
# 100/100 [==============================] - 2s 20ms/step - loss: 1.7612 - accuracy: 0.3700
# 100/100 [==============================] - 2s 16ms/step - loss: 1.7893 - accuracy: 0.3000
# 100/100 [==============================] - 2s 23ms/step - loss: 1.7633 - accuracy: 0.4400
# 100/100 [==============================] - 2s 20ms/step - loss: 1.6948 - accuracy: 0.3900
# 100/100 [==============================] - 2s 20ms/step - loss: 1.8513 - accuracy: 0.3100
# 100/100 [==============================] - 2s 19ms/step - loss: 1.8153 - accuracy: 0.3600
# 100/100 [==============================] - 2s 22ms/step - loss: 1.8635 - accuracy: 0.2700
# 100/100 [==============================] - 2s 16ms/step - loss: 1.8423 - accuracy: 0.3800
# 100/100 [==============================] - 2s 25ms/step - loss: 1.7683 - accuracy: 0.3300
# 100/100 [==============================] - 1s 14ms/step - loss: 1.8606 - accuracy: 0.3100
# 100/100 [==============================] - 3s 28ms/step - loss: 1.6930 - accuracy: 0.3900
# 100/100 [==============================] - 2s 18ms/step - loss: 1.9650 - accuracy: 0.2600
# 100/100 [==============================] - 2s 20ms/step - loss: 1.7140 - accuracy: 0.3400
# 100/100 [==============================] - 2s 17ms/step - loss: 1.8595 - accuracy: 0.3800
# 100/100 [==============================] - 2s 21ms/step - loss: 2.0077 - accuracy: 0.2800
# 87/87 [==============================] - 1s 13ms/step - loss: 1.9136 - accuracy: 0.2644
# ==========FINISH TESTING===========
#
#   model name: rerun_30epoch_0.001lr_128bs_764_512_256_192_landmark
#   average lost: 1.828382757306099
#   average accuracy: 0.34060919657349586
#
# loading image
# Epoch 1/30
# 99/99 [==============================] - 6s 60ms/step - loss: 2.0563 - accuracy: 0.1559 - val_loss: 2.0350 - val_accuracy: 0.1932
# Epoch 2/30
# 99/99 [==============================] - 6s 59ms/step - loss: 1.9984 - accuracy: 0.2109 - val_loss: 1.9611 - val_accuracy: 0.2497
# Epoch 3/30
# 99/99 [==============================] - 6s 59ms/step - loss: 1.9425 - accuracy: 0.2520 - val_loss: 1.9231 - val_accuracy: 0.2781
# Epoch 4/30
# 99/99 [==============================] - 6s 60ms/step - loss: 1.9226 - accuracy: 0.2650 - val_loss: 1.9281 - val_accuracy: 0.2564
# Epoch 5/30
# 99/99 [==============================] - 6s 61ms/step - loss: 1.8925 - accuracy: 0.2810 - val_loss: 1.8948 - val_accuracy: 0.2859
# Epoch 6/30
# 99/99 [==============================] - 6s 61ms/step - loss: 1.8671 - accuracy: 0.2955 - val_loss: 1.8739 - val_accuracy: 0.2938
# Epoch 7/30
# 99/99 [==============================] - 6s 60ms/step - loss: 1.8446 - accuracy: 0.3098 - val_loss: 1.8669 - val_accuracy: 0.2904
# Epoch 8/30
# 99/99 [==============================] - 6s 60ms/step - loss: 1.8404 - accuracy: 0.3100 - val_loss: 1.8241 - val_accuracy: 0.3204
# Epoch 9/30
# 99/99 [==============================] - 6s 58ms/step - loss: 1.8240 - accuracy: 0.3186 - val_loss: 1.8267 - val_accuracy: 0.3206
# Epoch 10/30
# 99/99 [==============================] - 6s 58ms/step - loss: 1.8255 - accuracy: 0.3155 - val_loss: 1.8298 - val_accuracy: 0.3207
# Epoch 11/30
# 99/99 [==============================] - 6s 59ms/step - loss: 1.8246 - accuracy: 0.3215 - val_loss: 1.8173 - val_accuracy: 0.3228
# Epoch 12/30
# 99/99 [==============================] - 6s 58ms/step - loss: 1.8103 - accuracy: 0.3274 - val_loss: 1.8070 - val_accuracy: 0.3343
# Epoch 13/30
# 99/99 [==============================] - 6s 59ms/step - loss: 1.8070 - accuracy: 0.3262 - val_loss: 1.8050 - val_accuracy: 0.3266
# Epoch 14/30
# 99/99 [==============================] - 6s 59ms/step - loss: 1.7998 - accuracy: 0.3288 - val_loss: 1.8038 - val_accuracy: 0.3356
# Epoch 15/30
# 99/99 [==============================] - 6s 59ms/step - loss: 1.7884 - accuracy: 0.3373 - val_loss: 1.7904 - val_accuracy: 0.3421
# Epoch 16/30
# 99/99 [==============================] - 6s 59ms/step - loss: 1.7936 - accuracy: 0.3355 - val_loss: 1.8172 - val_accuracy: 0.3231
# Epoch 17/30
# 99/99 [==============================] - 6s 59ms/step - loss: 1.7927 - accuracy: 0.3378 - val_loss: 1.7994 - val_accuracy: 0.3309
# Epoch 18/30
# 99/99 [==============================] - 6s 59ms/step - loss: 1.7804 - accuracy: 0.3445 - val_loss: 1.7925 - val_accuracy: 0.3404
# Epoch 19/30
# 99/99 [==============================] - 6s 59ms/step - loss: 1.7785 - accuracy: 0.3429 - val_loss: 1.7798 - val_accuracy: 0.3495
# Epoch 20/30
# 99/99 [==============================] - 6s 59ms/step - loss: 1.7744 - accuracy: 0.3484 - val_loss: 1.7721 - val_accuracy: 0.3450
# Epoch 21/30
# 99/99 [==============================] - 6s 60ms/step - loss: 1.7709 - accuracy: 0.3490 - val_loss: 1.7909 - val_accuracy: 0.3378
# Epoch 22/30
# 99/99 [==============================] - 6s 60ms/step - loss: 1.7705 - accuracy: 0.3496 - val_loss: 1.7699 - val_accuracy: 0.3494
# Epoch 23/30
# 99/99 [==============================] - 6s 58ms/step - loss: 1.7639 - accuracy: 0.3514 - val_loss: 1.7676 - val_accuracy: 0.3548
# Epoch 24/30
# 99/99 [==============================] - 6s 58ms/step - loss: 1.7639 - accuracy: 0.3500 - val_loss: 1.7824 - val_accuracy: 0.3442
# Epoch 25/30
# 99/99 [==============================] - 6s 59ms/step - loss: 1.7563 - accuracy: 0.3533 - val_loss: 1.7794 - val_accuracy: 0.3453
# Epoch 26/30
# 99/99 [==============================] - 6s 60ms/step - loss: 1.7520 - accuracy: 0.3610 - val_loss: 1.7775 - val_accuracy: 0.3516
# Epoch 27/30
# ...
# 100/100 [==============================] - 4s 35ms/step - loss: 1.9623 - accuracy: 0.2800
# 87/87 [==============================] - 3s 35ms/step - loss: 1.9195 - accuracy: 0.3218
# ==========FINISH TESTING===========
#
#   model name: rerun_30epoch_0.001lr_320bs_764_256_256_256_landmark
#   average lost: 1.825921094417572
#   average accuracy: 0.31929597780108454
#
# loading image
# Epoch 1/30
# 79/79 [==============================] - 8s 93ms/step - loss: 2.0557 - accuracy: 0.1599 - val_loss: 2.0273 - val_accuracy: 0.2050
# Epoch 2/30
# 79/79 [==============================] - 7s 92ms/step - loss: 1.9924 - accuracy: 0.2148 - val_loss: 1.9553 - val_accuracy: 0.2348
# Epoch 3/30
# 79/79 [==============================] - 7s 92ms/step - loss: 1.9552 - accuracy: 0.2435 - val_loss: 1.9556 - val_accuracy: 0.2326
# Epoch 4/30
# 79/79 [==============================] - 7s 92ms/step - loss: 1.9281 - accuracy: 0.2593 - val_loss: 1.9174 - val_accuracy: 0.2736
# Epoch 5/30
# 79/79 [==============================] - 7s 92ms/step - loss: 1.9137 - accuracy: 0.2702 - val_loss: 1.9123 - val_accuracy: 0.2746
# Epoch 6/30
# 79/79 [==============================] - 7s 93ms/step - loss: 1.8923 - accuracy: 0.2842 - val_loss: 1.8904 - val_accuracy: 0.2889
# Epoch 7/30
# 79/79 [==============================] - 7s 93ms/step - loss: 1.8791 - accuracy: 0.2866 - val_loss: 1.8645 - val_accuracy: 0.2958
# Epoch 8/30
# 79/79 [==============================] - 7s 93ms/step - loss: 1.8483 - accuracy: 0.3042 - val_loss: 1.8424 - val_accuracy: 0.3150
# Epoch 9/30
# 79/79 [==============================] - 7s 93ms/step - loss: 1.8375 - accuracy: 0.3112 - val_loss: 1.8527 - val_accuracy: 0.2995
# Epoch 10/30
# 79/79 [==============================] - 7s 93ms/step - loss: 1.8346 - accuracy: 0.3131 - val_loss: 1.8488 - val_accuracy: 0.2990
# Epoch 11/30
# 79/79 [==============================] - 7s 93ms/step - loss: 1.8271 - accuracy: 0.3158 - val_loss: 1.8300 - val_accuracy: 0.3137
# Epoch 12/30
# 79/79 [==============================] - 7s 93ms/step - loss: 1.8225 - accuracy: 0.3200 - val_loss: 1.8130 - val_accuracy: 0.3237
# Epoch 13/30
# 79/79 [==============================] - 7s 93ms/step - loss: 1.8128 - accuracy: 0.3289 - val_loss: 1.8291 - val_accuracy: 0.3179
# Epoch 14/30
# 79/79 [==============================] - 7s 92ms/step - loss: 1.8011 - accuracy: 0.3327 - val_loss: 1.8030 - val_accuracy: 0.3299
# Epoch 15/30
# 79/79 [==============================] - 7s 92ms/step - loss: 1.7998 - accuracy: 0.3333 - val_loss: 1.7937 - val_accuracy: 0.3354
# Epoch 16/30
# 79/79 [==============================] - 7s 92ms/step - loss: 1.8025 - accuracy: 0.3301 - val_loss: 1.7898 - val_accuracy: 0.3397
# Epoch 17/30
# 79/79 [==============================] - 7s 92ms/step - loss: 1.7926 - accuracy: 0.3354 - val_loss: 1.8202 - val_accuracy: 0.3251
# Epoch 18/30
# 79/79 [==============================] - 7s 92ms/step - loss: 1.7932 - accuracy: 0.3339 - val_loss: 1.7952 - val_accuracy: 0.3385
# Epoch 19/30
# 79/79 [==============================] - 7s 92ms/step - loss: 1.7785 - accuracy: 0.3447 - val_loss: 1.7791 - val_accuracy: 0.3465
# Epoch 20/30
# 79/79 [==============================] - 7s 91ms/step - loss: 1.7781 - accuracy: 0.3468 - val_loss: 1.7922 - val_accuracy: 0.3415
# Epoch 21/30
# 79/79 [==============================] - 7s 91ms/step - loss: 1.7750 - accuracy: 0.3455 - val_loss: 1.8108 - val_accuracy: 0.3324
# Epoch 22/30
# 79/79 [==============================] - 7s 92ms/step - loss: 1.7773 - accuracy: 0.3437 - val_loss: 1.7828 - val_accuracy: 0.3429
# Epoch 23/30
# 79/79 [==============================] - 7s 92ms/step - loss: 1.7697 - accuracy: 0.3514 - val_loss: 1.8119 - val_accuracy: 0.3191
# 7.3006486892700195
# trained image count:  31553
# Images Left:  0
# Estimated completion time:  0:00:00
# ---------------- rerun_30epoch_0.001lr_320bs_764_384_192_128_landmark Training Completed ------------------
# 100/100 [==============================] - 1s 11ms/step - loss: 1.7065 - accuracy: 0.3800
# 100/100 [==============================] - 1s 10ms/step - loss: 1.7242 - accuracy: 0.3500
# 100/100 [==============================] - 1s 10ms/step - loss: 1.9016 - accuracy: 0.3300
# 100/100 [==============================] - 1s 11ms/step - loss: 1.8596 - accuracy: 0.2900
# 100/100 [==============================] - 1s 12ms/step - loss: 1.9173 - accuracy: 0.2500
# 100/100 [==============================] - 2s 18ms/step - loss: 1.7578 - accuracy: 0.3800
# 100/100 [==============================] - 4s 37ms/step - loss: 1.9697 - accuracy: 0.2800
# 100/100 [==============================] - 4s 36ms/step - loss: 1.7971 - accuracy: 0.3300
# 100/100 [==============================] - 4s 36ms/step - loss: 1.9618 - accuracy: 0.2300
# 100/100 [==============================] - 4s 36ms/step - loss: 1.7247 - accuracy: 0.3200
# 100/100 [==============================] - 4s 36ms/step - loss: 1.8526 - accuracy: 0.3700
# 100/100 [==============================] - 2s 18ms/step - loss: 1.8098 - accuracy: 0.2900
# 100/100 [==============================] - 2s 21ms/step - loss: 1.8992 - accuracy: 0.3700
# 100/100 [==============================] - 4s 37ms/step - loss: 1.9006 - accuracy: 0.3600
# 100/100 [==============================] - 4s 37ms/step - loss: 1.7973 - accuracy: 0.3200
# 100/100 [==============================] - 3s 35ms/step - loss: 1.7803 - accuracy: 0.3600
# 100/100 [==============================] - 1s 12ms/step - loss: 1.7257 - accuracy: 0.3500
# 100/100 [==============================] - 3s 32ms/step - loss: 2.0142 - accuracy: 0.2600
# 100/100 [==============================] - 4s 36ms/step - loss: 1.8568 - accuracy: 0.3100
# 100/100 [==============================] - 4s 37ms/step - loss: 1.7557 - accuracy: 0.3200
# 100/100 [==============================] - 4s 36ms/step - loss: 1.7014 - accuracy: 0.4000
# 100/100 [==============================] - 4s 36ms/step - loss: 1.6965 - accuracy: 0.3700
# 100/100 [==============================] - 4s 35ms/step - loss: 1.8948 - accuracy: 0.3100
# 100/100 [==============================] - 4s 36ms/step - loss: 1.8155 - accuracy: 0.2800
# 100/100 [==============================] - 4s 35ms/step - loss: 1.7080 - accuracy: 0.4200
# 100/100 [==============================] - 4s 36ms/step - loss: 1.7623 - accuracy: 0.3600
# 100/100 [==============================] - 4s 36ms/step - loss: 1.7939 - accuracy: 0.3500
# 100/100 [==============================] - 4s 36ms/step - loss: 1.7280 - accuracy: 0.3800
# 100/100 [==============================] - 4s 36ms/step - loss: 1.8299 - accuracy: 0.2700
# 100/100 [==============================] - 2s 15ms/step - loss: 1.7668 - accuracy: 0.3700
# 100/100 [==============================] - 3s 26ms/step - loss: 1.8168 - accuracy: 0.3400
# 100/100 [==============================] - 4s 36ms/step - loss: 1.7955 - accuracy: 0.4100
# 100/100 [==============================] - 4s 36ms/step - loss: 1.7839 - accuracy: 0.3100
# 100/100 [==============================] - 2s 24ms/step - loss: 1.8752 - accuracy: 0.3300
# 100/100 [==============================] - 1s 13ms/step - loss: 1.7211 - accuracy: 0.3100
# 100/100 [==============================] - 4s 35ms/step - loss: 1.9285 - accuracy: 0.2900
# 100/100 [==============================] - 1s 14ms/step - loss: 1.7158 - accuracy: 0.3600
# 100/100 [==============================] - 3s 27ms/step - loss: 1.8341 - accuracy: 0.3700
# 100/100 [==============================] - 4s 37ms/step - loss: 1.9487 - accuracy: 0.2800
# 87/87 [==============================] - 3s 36ms/step - loss: 1.9211 - accuracy: 0.2874
# ==========FINISH TESTING===========
#
#   model name: rerun_30epoch_0.001lr_320bs_764_384_192_128_landmark
#   average lost: 1.818755891919136
#   average accuracy: 0.33118390925228597
#
# loading image
# Epoch 1/30
# 79/79 [==============================] - 9s 104ms/step - loss: 2.0635 - accuracy: 0.1513 - val_loss: 2.0394 - val_accuracy: 0.1811
# Epoch 2/30
# 79/79 [==============================] - 8s 102ms/step - loss: 2.0016 - accuracy: 0.2127 - val_loss: 1.9704 - val_accuracy: 0.2516
# Epoch 3/30
# 79/79 [==============================] - 8s 101ms/step - loss: 1.9515 - accuracy: 0.2444 - val_loss: 1.9382 - val_accuracy: 0.2475
# Epoch 4/30
# 79/79 [==============================] - 8s 103ms/step - loss: 1.9278 - accuracy: 0.2583 - val_loss: 1.9147 - val_accuracy: 0.2633
# Epoch 5/30
# 79/79 [==============================] - 8s 102ms/step - loss: 1.9101 - accuracy: 0.2721 - val_loss: 1.9111 - val_accuracy: 0.2778
# Epoch 6/30
# 79/79 [==============================] - 8s 103ms/step - loss: 1.9004 - accuracy: 0.2747 - val_loss: 1.9109 - val_accuracy: 0.2694
# Epoch 7/30
# 79/79 [==============================] - 8s 103ms/step - loss: 1.8890 - accuracy: 0.2836 - val_loss: 1.8782 - val_accuracy: 0.2930
# Epoch 8/30
# 79/79 [==============================] - 8s 103ms/step - loss: 1.8675 - accuracy: 0.2931 - val_loss: 1.8666 - val_accuracy: 0.2960
# Epoch 9/30
# 79/79 [==============================] - 8s 104ms/step - loss: 1.8529 - accuracy: 0.3022 - val_loss: 1.8458 - val_accuracy: 0.3101
# Epoch 10/30
# 79/79 [==============================] - 8s 104ms/step - loss: 1.8397 - accuracy: 0.3091 - val_loss: 1.8284 - val_accuracy: 0.3099
# Epoch 11/30
# 79/79 [==============================] - 8s 104ms/step - loss: 1.8348 - accuracy: 0.3144 - val_loss: 1.8374 - val_accuracy: 0.3082
# Epoch 12/30
# 79/79 [==============================] - 8s 105ms/step - loss: 1.8209 - accuracy: 0.3205 - val_loss: 1.8321 - val_accuracy: 0.3175
# Epoch 13/30
# 79/79 [==============================] - 8s 105ms/step - loss: 1.8178 - accuracy: 0.3245 - val_loss: 1.8323 - val_accuracy: 0.3133
# Epoch 14/30
# 79/79 [==============================] - 8s 103ms/step - loss: 1.8168 - accuracy: 0.3210 - val_loss: 1.8181 - val_accuracy: 0.3255
# Epoch 15/30
# 79/79 [==============================] - 8s 104ms/step - loss: 1.8061 - accuracy: 0.3307 - val_loss: 1.8585 - val_accuracy: 0.2990
# Epoch 16/30
# 79/79 [==============================] - 8s 104ms/step - loss: 1.8044 - accuracy: 0.3302 - val_loss: 1.8071 - val_accuracy: 0.3324
# Epoch 17/30
# 79/79 [==============================] - 8s 104ms/step - loss: 1.8024 - accuracy: 0.3302 - val_loss: 1.8054 - val_accuracy: 0.3358
# Epoch 18/30
# 79/79 [==============================] - 8s 104ms/step - loss: 1.7929 - accuracy: 0.3388 - val_loss: 1.8013 - val_accuracy: 0.3343
# Epoch 19/30
# 79/79 [==============================] - 8s 104ms/step - loss: 1.7972 - accuracy: 0.3352 - val_loss: 1.7965 - val_accuracy: 0.3343
# Epoch 20/30
# 79/79 [==============================] - 8s 104ms/step - loss: 1.7869 - accuracy: 0.3422 - val_loss: 1.7879 - val_accuracy: 0.3397
# Epoch 21/30
# 79/79 [==============================] - 8s 104ms/step - loss: 1.7823 - accuracy: 0.3426 - val_loss: 1.7844 - val_accuracy: 0.3419
# Epoch 22/30
# 79/79 [==============================] - 8s 104ms/step - loss: 1.7779 - accuracy: 0.3470 - val_loss: 1.7935 - val_accuracy: 0.3309
# Epoch 23/30
# 79/79 [==============================] - 8s 104ms/step - loss: 1.7785 - accuracy: 0.3420 - val_loss: 1.7972 - val_accuracy: 0.3443
# Epoch 24/30
# 79/79 [==============================] - 8s 104ms/step - loss: 1.7767 - accuracy: 0.3450 - val_loss: 1.7900 - val_accuracy: 0.3331
# Epoch 25/30
# 79/79 [==============================] - 8s 104ms/step - loss: 1.7716 - accuracy: 0.3471 - val_loss: 1.7836 - val_accuracy: 0.3427
# Epoch 26/30
# 79/79 [==============================] - 8s 104ms/step - loss: 1.7599 - accuracy: 0.3560 - val_loss: 1.7808 - val_accuracy: 0.3465
# Epoch 27/30
# 79/79 [==============================] - 8s 104ms/step - loss: 1.7610 - accuracy: 0.3547 - val_loss: 1.7860 - val_accuracy: 0.3335
# Epoch 28/30
# 79/79 [==============================] - 8s 104ms/step - loss: 1.7607 - accuracy: 0.3513 - val_loss: 1.7648 - val_accuracy: 0.3584
# Epoch 29/30
# 79/79 [==============================] - 8s 104ms/step - loss: 1.7511 - accuracy: 0.3564 - val_loss: 1.7824 - val_accuracy: 0.3450
# Epoch 30/30
# 79/79 [==============================] - 8s 104ms/step - loss: 1.7529 - accuracy: 0.3581 - val_loss: 1.7908 - val_accuracy: 0.3337
# 8.185479021072387
# trained image count:  31553
# Images Left:  0
# Estimated completion time:  0:00:00
# ---------------- rerun_30epoch_0.001lr_320bs_764_512_256_192_landmark Training Completed ------------------
# 100/100 [==============================] - 1s 11ms/step - loss: 1.7123 - accuracy: 0.3900
# 100/100 [==============================] - 1s 11ms/step - loss: 1.7259 - accuracy: 0.3300
# 100/100 [==============================] - 1s 11ms/step - loss: 1.9229 - accuracy: 0.2900
# 100/100 [==============================] - 1s 12ms/step - loss: 1.8799 - accuracy: 0.2800
# 100/100 [==============================] - 1s 12ms/step - loss: 1.8952 - accuracy: 0.3000
# 100/100 [==============================] - 2s 18ms/step - loss: 1.7991 - accuracy: 0.3000
# 100/100 [==============================] - 4s 37ms/step - loss: 1.9407 - accuracy: 0.3000
# 100/100 [==============================] - 2s 22ms/step - loss: 1.8400 - accuracy: 0.3000
# 100/100 [==============================] - 2s 18ms/step - loss: 1.9804 - accuracy: 0.2200
# 100/100 [==============================] - 3s 28ms/step - loss: 1.7352 - accuracy: 0.3200
# 100/100 [==============================] - 1s 12ms/step - loss: 1.8194 - accuracy: 0.3200
# 100/100 [==============================] - 3s 33ms/step - loss: 1.8050 - accuracy: 0.3800
# 100/100 [==============================] - 1s 13ms/step - loss: 1.8904 - accuracy: 0.2900
# 100/100 [==============================] - 3s 25ms/step - loss: 1.8929 - accuracy: 0.3800
# 100/100 [==============================] - 2s 15ms/step - loss: 1.8333 - accuracy: 0.3100
# 100/100 [==============================] - 4s 37ms/step - loss: 1.7700 - accuracy: 0.3300
# 100/100 [==============================] - 3s 32ms/step - loss: 1.7254 - accuracy: 0.3300
# 100/100 [==============================] - 1s 13ms/step - loss: 2.0199 - accuracy: 0.3100
# 100/100 [==============================] - 4s 36ms/step - loss: 1.8568 - accuracy: 0.3300
# 100/100 [==============================] - 2s 22ms/step - loss: 1.8152 - accuracy: 0.2700
# 100/100 [==============================] - 2s 18ms/step - loss: 1.6855 - accuracy: 0.3800
# 100/100 [==============================] - 2s 23ms/step - loss: 1.7431 - accuracy: 0.3000
# 100/100 [==============================] - 2s 18ms/step - loss: 1.8557 - accuracy: 0.2700
# 100/100 [==============================] - 4s 36ms/step - loss: 1.8079 - accuracy: 0.2900
# 100/100 [==============================] - 1s 12ms/step - loss: 1.6609 - accuracy: 0.4000
# 100/100 [==============================] - 3s 29ms/step - loss: 1.7950 - accuracy: 0.3800
# 100/100 [==============================] - 2s 21ms/step - loss: 1.7292 - accuracy: 0.3900
# 100/100 [==============================] - 2s 19ms/step - loss: 1.7172 - accuracy: 0.4300
# 100/100 [==============================] - 4s 37ms/step - loss: 1.7883 - accuracy: 0.3300
# 100/100 [==============================] - 1s 13ms/step - loss: 1.7911 - accuracy: 0.3600
# 100/100 [==============================] - 3s 30ms/step - loss: 1.7720 - accuracy: 0.3100
# 100/100 [==============================] - 2s 19ms/step - loss: 1.8249 - accuracy: 0.3700
# 100/100 [==============================] - 2s 23ms/step - loss: 1.8404 - accuracy: 0.2800
# 100/100 [==============================] - 2s 18ms/step - loss: 1.9202 - accuracy: 0.3100
# 100/100 [==============================] - 2s 23ms/step - loss: 1.6996 - accuracy: 0.3400
# 100/100 [==============================] - 2s 21ms/step - loss: 1.9122 - accuracy: 0.3000
# 100/100 [==============================] - 2s 20ms/step - loss: 1.6592 - accuracy: 0.3600
# 100/100 [==============================] - 4s 37ms/step - loss: 1.8031 - accuracy: 0.3600
# 100/100 [==============================] - 4s 37ms/step - loss: 1.9750 - accuracy: 0.2700
# 87/87 [==============================] - 3s 37ms/step - loss: 1.9338 - accuracy: 0.3218
# ==========FINISH TESTING===========
#
#   model name: rerun_30epoch_0.001lr_320bs_764_512_256_192_landmark
#   average lost: 1.8193543553352356
#   average accuracy: 0.3257959812879562

# %% [markdown]
# def FreezeLayerTrainAndTest(epoch, learningRate, modelName, batchSize, firstLayerSize, secondLayerSize, thirdLayerSize, fourthLayerSize):
#   """Train and test a model. This function's input should be customized to accept different parameters, function body should be customized to these parameters to train models of variety of paramters.
#
#   Args:
#       modelName (str): name of model
#   """
#   #-------------------------------------------------
#   # Building model
#   #-------------------------------------------------
#   # Adding 3 more layers to output side
#   inputs = tf.keras.Input(shape=(478,3))
#   base = tf.keras.layers.Dense(firstLayerSize, activation='relu')(inputs)
#   base = tf.keras.layers.Dense(secondLayerSize, activation='relu')(base)
#   base = tf.keras.layers.Dense(thirdLayerSize, activation='relu')(base)
#   base = tf.keras.layers.Dense(fourthLayerSize, activation='relu')(base)
#   base = tf.keras.layers.Flatten()(base)
#   outputs = tf.keras.layers.Dense(8, activation='softmax')(base)
#
#   model = tf.keras.Model(inputs=inputs, outputs=outputs)
#   model.compile(loss = "sparse_categorical_crossentropy", optimizer = keras.optimizers.Adam(lr = learningRate), metrics=["accuracy"])
#
#   # ------------------ Callbacks ------------------
#   earlyStop = EarlyStopping(monitor='val_loss', patience = 4, restore_best_weights = True)
#   # earlyStopAcc = EarlyStopping(monitor='val_accuracy', patience = 1, restore_best_weights = True)
#   # reduce_lr = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.5, patience = 2, min_lr = 0.0002)
#   # reset_lr = ResetLR(learningRate)
#
#   # ------------------ Training Model ------------------
#   time_callback = TimeHistory()
#   trainDataSet = mainTrainSet.copy()
#
#   # Initializing model fit params
#   # batchSize = 4
#   imgPerIter = batchSize*256
#
#   count = 0
#   iter = 0
#   while(len(trainDataSet) != 0):
#     iter += 1
#     tensorboard = TensorBoard(log_dir = "logs/{}_it{}".format(modelName, iter))
#     croppedList = []
#     try:
#       print("loading image") # Crop and load images in
#       croppedList = CropData(trainDataSet, imgPerIter)
#       label, data = LoadVertices(TRAINLANDMARKPATH, croppedList)
#       # Training model
#       model.fit(data, label, epochs = epoch, validation_split = 0.2, batch_size = batchSize, callbacks = [time_callback, tensorboard, earlyStop]) # earlyStop, earlyStopAcc, reduce_lr, reset_lr
#       print(time_callback.AverageTime())
#     except RuntimeError as e:
#       print(e)
#
#     # Saving weights
#     model.save_weights('{}.h5'.format(modelName))
#
#     # Print summary of current iteration
#     count = count + len(croppedList)
#     timeLeft = len(trainDataSet)/imgPerIter * time_callback.AverageTime()
#     print("trained image count: ", count)
#     print("Images Left: ", len(trainDataSet))
#     print("Estimated completion time: ", str(timedelta(seconds=timeLeft)))
#
#     reset_keras()
#   print("---------------- {} Training Completed ------------------".format(modelName))
#
#   # ---------------- Testing Model -----------------
#   # initialise image names and label
#   testSetData = mainTestSet.copy()
#
#   # test model
#   loss, accuracy = TestModelWithVertices(model, testSetData, tensorboard)
#
#   # Saving test information on notebook
#   SaveInformation.append({"name": modelName,
#                           "batch": batchSize,
#                           "L1": firstLayerSize,
#                           "L2": secondLayerSize,
#                           "L3": thirdLayerSize,
#                           "L4": fourthLayerSize,
#                           "loss": loss,
#                           "accuracy": accuracy })
#
#   # Saving test informations
#   modelSummary = '''
#   model name: {}
#   average lost: {}
#   average accuracy: {}
#             '''.format(modelName, loss, accuracy)
#
#   print("==========FINISH TESTING===========\n{}".format(modelSummary))
#
#   file = open("training_summaries.txt", "a")
#   file.write(modelSummary + "\n\n")

# %%
model.summary()
