# %% [markdown]
# This is for second desktop

# %% [markdown]
# ## Import libraries and set up functions
# Starting directory is this "..\\asset" from this notebook code

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
tf.config.run_functions_eagerly(True)
tf.data.experimental.enable_debug_mode()
import cv2
import matplotlib.pyplot as plt
import random
from keras.backend import clear_session
from keras.backend import get_session
import time
import math
from datetime import timedelta
# import mediapipe as mp
import csv
import pandas as pd
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ReduceLROnPlateau

os.chdir("..\\..\\asset") # change working directory

# %%
emotionList = ('Neutral', 'Happy', 'Sad', 'Surprise', 'Fear', 'Disgust', 'Anger', 'Contempt')
TRAINANNOTATIONPATH = "train_set\\annotations\\"
TRAINIMAGEPATH = "train_set\\images\\"
TRAINLANDMARKPATH = "train_set\\landmarks\\"
TESTANNOTATIONPATH = "val_set\\annotations\\"
TESTIMAGEPATH = "val_set\\images\\"
TESTLANDMARKPATH = "val_set\\landmarks\\"

def LoadAllImageNames(filePath, limit = 0, catLimit = []):
  """Load the images names and label in tuple format (label, image name)

  Args:
      filePath (str): directory of image folder
      limit (int, optional): max number of image to load. Defaults to 0.
      catLimit (list<int>, optional): array of image count limit for each class. Defaults to []*8.

  Returns:
      list<str>: shuffled list of image names
  """
  limitCounter = [0,0,0,0,0,0,0,0]
  dataSet = []
  loadCounter = 0

  annotationPath = TRAINANNOTATIONPATH if ("train" in filePath) else TESTANNOTATIONPATH
  for file in os.scandir(filePath):
    if (limit > 0 and loadCounter > limit):
      break
  
    name = file.name[:-4] # file name w/o file extension
    if "_landmark" in name:
      name = name[:-9]
    data = np.load("{}{}_exp.npy".format(annotationPath, name)) # 
    label = int(data.item(0))

    if len(catLimit) > 0 and limitCounter[label] >= catLimit[label]:
        continue
    limitCounter[label] += 1
    loadCounter += 1

    dataSet.append((label, file.name))
    if (loadCounter%10000==0):
      print("Files loaded:{}".format(loadCounter))
  
  print("Total images loaded: ", loadCounter)
  print("Images Loaded: ", limitCounter)
  random.shuffle(dataSet)
  return dataSet

# Load the pixels of a picture to numpy.ndarray format. false for test set, true for training set
# Return image in RGB format
def LoadImage(imagePath, imageName, normalize = True):
  """Load image using numpy

  Args:
      imagePath (str): image path 
      imageName (str): image name
      normalize (bool, optional): To normalize image or not. Defaults to True.

  Returns:
      numpy array: x,y,3 array
  """
  # print("{}{}{}".format(os.getcwd(), "\\"+imagePath, imageName))
  image_array = cv2.imread("{}{}{}".format(os.getcwd(), "\\"+imagePath, imageName))
  image_array = cv2.cvtColor(image_array, cv2.COLOR_BGR2RGB)
  if normalize:
    image_array = image_array/255
    
  return image_array

# Extract the daata from 0 to amount from list and return it
def CropData(list, amount):
  if (len(list) < amount):
    amount = len(list)
  croppedList = list[:amount]
  del list[:amount]
  return croppedList

def LoadImages(imagePath, list):
  label = []
  data = []
  for entries in list:
    try:
      image = LoadImage(imagePath, entries[1])
      data.append(image) 
      label.append(entries[0]) 
    except: 
      print("Failed to load training image: ", entries[1])
  npLabel = np.array(label) 
  npData = np.array(data) 
  return npLabel, npData 

# Load a list of face mesh in landmark_pb2.NormalizedLandmarkList format
def LoadFaceMeshes(faceMesh, path, list, withFace = False):
  face = []
  label = []
  data = []
  for entry in list:
    # try:
    if withFace:
      face.append(LoadImage(path, entry[1], normalize = False)) # Load image
      data.append(faceMesh.process(face[-1])) # process it into face mesh and append into data
    else:
      data.append(faceMesh.process(LoadImage(path, entry[1], normalize = False))) # Load image, process it into face mesh, and append into data
    label.append(entry[0])
    # except:
      # print("Failed to load training image: ", entry[1])

  if withFace:
    return np.array(label), np.array(data), np.array(face)
  else:
    return np.array(label), np.array(data)

# Load face mesh data in numpy array of 
def LoadFaceMeshVertices(faceMesh, path, list):
  label = []
  data = []
  for entry in list:
    # load image, process it into normalizedlandmarklist format, obtain face data from the list, convert it into vertices
    image = LoadImage(path, entry[1], normalize = False)
    multiFaceLandmarks = faceMesh.process(image).multi_face_landmarks
    if (multiFaceLandmarks == None):
      print("{} multi-face landmarks is none".format(entry[1]))
      continue
    vertices = MultiLandmarkToVertices(multiFaceLandmarks[0])
    data.append(vertices)
    label.append(entry[0])
    # except:
      # print("Failed to load training image: ", entry[1])

def LoadVertices(path, list):
  label = []
  data = []
  for entry in list:
    vertices = np.load("{}{}{}.npy".format(os.getcwd(), "\\"+path, entry[1][:-4]))
    data.append(vertices)
    label.append(entry[0])
  
  return np.array(label), np.array(data)
  
def MultiLandmarkToVertices(multiLandmark):
  verticesList = []
  for idx, landmark in enumerate(multiLandmark.landmark):
    verticesList.append([landmark.x, landmark.y, landmark.z])

  return verticesList


def InitializeModel():
  pretrained_model = tf.keras.applications.MobileNetV3Large(input_shape=(224,224,3)) # Initializing model with mobile net V3 pretrained model

  # Initializing the input and output from the model, removing last layer
  base_input = pretrained_model.layers[0].input
  base_output = pretrained_model.layers[-2].output

  # Adding 3 more layers to output side
  final_output = layers.Dense(128)(base_output) # Adding new layers, to the output side
  final_output = layers.Activation('relu')(final_output) # activating layer
  final_output = layers.Dense(64)(final_output)
  final_output = layers.Activation('relu')(final_output) # activating layer
  final_output = layers.Dense(8, activation = 'softmax')(final_output) # 8 cuz there are 8 image classifications

  new_model = keras.Model(inputs = base_input, outputs = final_output)
  # new_model.summary()
  return new_model

def ConvertToGray(image):
  image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
  image = cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)
  return image

def ScaleImage(image, width):
  ratio = image.shape[1]/width
  image = cv2.resize(image, (width, int(image.shape[0]/ratio)))
  return image

def DetectFace(image):
  face_roi = np.ndarray(1)
  faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
  grayImage = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
  faces = faceCascade.detectMultiScale(grayImage, 1.3, 5)
  for x,y,w,h in faces:
    roi_gray = grayImage[y:y+h, x:x+w]
    roi_color = image[y:y+h, x:x+w]
    cv2.rectangle(image, (x,y), (x+w, y+h), (255,0,0), 2)
    facess = faceCascade.detectMultiScale(roi_gray)
    if (len(facess) == 0):
      print("Face not detected")
    else:
      for (ex,ey,ew,eh) in facess:
        face_roi = roi_color[ey:ey+eh, ex:ex+ew]
  return face_roi

def ConvertToInput(image):
  input = ScaleImage(image, 224)
  input = np.expand_dims(input, axis = 0) ## to add fourth dimension to fit model input
  input = input/255
  return input

def GetResult(model, input):
  Predictions = model.predict(input)
  print(Predictions)
  result = np.argmax(Predictions)
  return emotionList[result]

def printDataSetLabels(dataSet):
    counterList = list(range(8))
    for label, name in dataSet:
        counterList[label] += 1
    print(counterList)
    
# Reset Keras Session
def reset_keras():
    sess = get_session()
    clear_session()
    sess.close()
    sess = get_session()

    # try:
    #     del classifier # this is from global space - change this as you need
    # except:
    #     pass

    # use the same config as you used to create the session
    tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.9, visible_device_list="0")

class TimeHistory(keras.callbacks.Callback):
  def on_train_begin(self, logs={}):
    self.times = []

  def on_epoch_begin(self, batch, logs={}):
    self.epoch_time_start = time.time()

  def on_epoch_end(self, batch, logs={}):
    self.times.append(time.time() - self.epoch_time_start)

  def AverageTime(self):
    sum = 0
    for time in self.times:
      sum += time
    return sum/len(self.times)

def TestModel(model, testSetData):
  # test model
  lostSum = 0
  accuracySum = 0
  count = 0
  while(len(testSetData) != 0):
    # training data
    try:
      croppedList = CropData(testSetData, 100)
      label, data = LoadImages(TESTIMAGEPATH, croppedList)
      result = model.evaluate(data, label, batch_size = 1)
      lostSum += result[0]
      accuracySum += result[1]
    except:
      print("Failed to train data")

    count += 1
    reset_keras()
  
  return lostSum/count, accuracySum/count

def TestModelWithVertices(model, dataSet, tensorboard):
  # test model
  lostSum = 0
  accuracySum = 0
  count = 0
  while(len(dataSet) != 0):
    # training data
    try:
      croppedList = CropData(dataSet, 100)
      label, data = LoadVertices(TESTLANDMARKPATH, croppedList)
      result = model.evaluate(data, label, batch_size = 1, callbacks =[tensorboard])
      lostSum += result[0]
      accuracySum += result[1]
    except:
      print("Failed to train data")

    count += 1
    reset_keras()
  
  return lostSum/count, accuracySum/count

def DrawFaceLandmark(label, image, landmarks):
  mp_drawing = mp.solutions.drawing_utils
  mp_drawing_styles = mp.solutions.drawing_styles
  mp_face_mesh = mp.solutions.face_mesh
  print(f'Face landmarks of {label}:')
  if not landmarks.multi_face_landmarks:
    print("unagle to locate face landmark for {}".format(label))
  annotated_image = image.copy()
  for face_landmarks in landmarks.multi_face_landmarks:
    mp_drawing.draw_landmarks(
        image=annotated_image,
        landmark_list=face_landmarks,
        connections=mp_face_mesh.FACEMESH_TESSELATION,
        landmark_drawing_spec=None,
        connection_drawing_spec=mp_drawing_styles
        .get_default_face_mesh_tesselation_style())
    mp_drawing.draw_landmarks(
        image=annotated_image,
        landmark_list=face_landmarks,
        connections=mp_face_mesh.FACEMESH_CONTOURS,
        landmark_drawing_spec=None,
        connection_drawing_spec=mp_drawing_styles
        .get_default_face_mesh_contours_style())
    mp_drawing.draw_landmarks(
        image=annotated_image,
        landmark_list=face_landmarks,
        connections=mp_face_mesh.FACEMESH_IRISES,
        landmark_drawing_spec=None,
        connection_drawing_spec=mp_drawing_styles
        .get_default_face_mesh_iris_connections_style())
  plt.imshow(annotated_image)

# %% [markdown]
# ## Setup directory and import image file names

# %%
# Get currect directory (os.getcwd() -> C:\Users\jazzt\src)

#-----------------------Start of code---------------------------
# initialise image names and label
mainTrainSet = LoadAllImageNames(TRAINLANDMARKPATH, catLimit=[4000]*8)
mainTestSet = LoadAllImageNames(TESTLANDMARKPATH, catLimit=[500]*8)
# Out:
# Files loaded:10000
# Files loaded:20000
# Files loaded:30000
# Total images loaded:  31553
# Images Loaded:  [4000, 4000, 4000, 4000, 4000, 3803, 4000, 3750]
# Total images loaded:  3987
# Images Loaded:  [499, 500, 498, 498, 498, 500, 499, 495]

# %%
# reset learning rate callback to counter ReduceLROnPlateau
class ResetLR(tf.keras.callbacks.Callback):
    def __init__(self, learningRate):
        self.default_lr = learningRate
    def on_train_begin(self, logs={}):
        previous_lr = self.model.optimizer.lr.read_value()
        if previous_lr != self.default_lr:
            print("Resetting learning rate from {} to {}".format(previous_lr, self.default_lr))
            self.model.optimizer.lr.assign(self.default_lr)

# # making stopper to only start counting from 3 epochs onwards
# class CustomStopper(tf.keras.callbacks.EarlyStopping):
#     def __init__(self, monitor='val_loss',
#              min_delta=0, patience=3, verbose=0, mode='auto', start_epoch = 3): # add argument for starting epoch
#         super(CustomStopper, self).__init__()
#         self.start_epoch = start_epoch

#     def on_epoch_end(self, epoch, logs=None):
#         if epoch > self.start_epoch:
#             super().on_epoch_end(epoch, logs)

# %%
batchSizes = [512+128, 512+256]
firstLayerSizes = [764, 1024, 1536, 2048]
secondLayerSizes = [64, 128, 192, 256, 384]
epoch = 30
learningRate = 0.001

for batchSize in batchSizes:
  for firstLayerSize in firstLayerSizes:
    for secondLayerSize in secondLayerSizes:
      name = "freeze_{}epoch_{}lr_{}bs_{}fls_{}sls_landmark".format(epoch, learningRate, batchSize, firstLayerSize, secondLayerSize)
      FreezeLayerTrainAndTest(epoch, learningRate, name, batchSize, firstLayerSize, secondLayerSize)
# Out:
# loading image
# Epoch 1/30
# 40/40 [==============================] - 4s 88ms/step - loss: 2.0595 - accuracy: 0.1579 - val_loss: 2.0452 - val_accuracy: 0.1722
# Epoch 2/30
# 40/40 [==============================] - 3s 86ms/step - loss: 2.0314 - accuracy: 0.1830 - val_loss: 2.0184 - val_accuracy: 0.2016
# Epoch 3/30
# 40/40 [==============================] - 3s 86ms/step - loss: 2.0030 - accuracy: 0.2095 - val_loss: 1.9851 - val_accuracy: 0.2203
# Epoch 4/30
# 40/40 [==============================] - 3s 87ms/step - loss: 1.9641 - accuracy: 0.2358 - val_loss: 1.9559 - val_accuracy: 0.2456
# Epoch 5/30
# 40/40 [==============================] - 3s 87ms/step - loss: 1.9377 - accuracy: 0.2524 - val_loss: 1.9255 - val_accuracy: 0.2626
# Epoch 6/30
# 40/40 [==============================] - 3s 86ms/step - loss: 1.9086 - accuracy: 0.2701 - val_loss: 1.9036 - val_accuracy: 0.2890
# Epoch 7/30
# 40/40 [==============================] - 3s 87ms/step - loss: 1.8878 - accuracy: 0.2823 - val_loss: 1.9032 - val_accuracy: 0.2754
# Epoch 8/30
# 40/40 [==============================] - 3s 86ms/step - loss: 1.8761 - accuracy: 0.2882 - val_loss: 1.8836 - val_accuracy: 0.3001
# Epoch 9/30
# 40/40 [==============================] - 3s 86ms/step - loss: 1.8620 - accuracy: 0.2987 - val_loss: 1.8817 - val_accuracy: 0.2928
# Epoch 10/30
# 40/40 [==============================] - 3s 87ms/step - loss: 1.8538 - accuracy: 0.3018 - val_loss: 1.8491 - val_accuracy: 0.3150
# Epoch 11/30
# 40/40 [==============================] - 3s 86ms/step - loss: 1.8538 - accuracy: 0.3047 - val_loss: 1.8567 - val_accuracy: 0.3022
# Epoch 12/30
# 40/40 [==============================] - 3s 86ms/step - loss: 1.8379 - accuracy: 0.3098 - val_loss: 1.8376 - val_accuracy: 0.3152
# Epoch 13/30
# 40/40 [==============================] - 3s 86ms/step - loss: 1.8347 - accuracy: 0.3134 - val_loss: 1.8577 - val_accuracy: 0.2985
# Epoch 14/30
# 40/40 [==============================] - 3s 86ms/step - loss: 1.8293 - accuracy: 0.3140 - val_loss: 1.8326 - val_accuracy: 0.3225
# Epoch 15/30
# 40/40 [==============================] - 3s 86ms/step - loss: 1.8217 - accuracy: 0.3205 - val_loss: 1.8363 - val_accuracy: 0.3234
# Epoch 16/30
# 40/40 [==============================] - 3s 86ms/step - loss: 1.8154 - accuracy: 0.3240 - val_loss: 1.8139 - val_accuracy: 0.3354
# Epoch 17/30
# 40/40 [==============================] - 3s 86ms/step - loss: 1.8128 - accuracy: 0.3244 - val_loss: 1.8191 - val_accuracy: 0.3248
# Epoch 18/30
# 40/40 [==============================] - 3s 86ms/step - loss: 1.8116 - accuracy: 0.3262 - val_loss: 1.8560 - val_accuracy: 0.3090
# Epoch 19/30
# 40/40 [==============================] - 3s 86ms/step - loss: 1.8080 - accuracy: 0.3266 - val_loss: 1.8227 - val_accuracy: 0.3255
# 3.466280221939087
# trained image count:  31553
# Images Left:  0
# Estimated completion time:  0:00:00
# ---------------- freeze_30epoch_0.001lr_640bs_764fls_64sls_landmark Training Completed ------------------
# 100/100 [==============================] - 1s 9ms/step - loss: 1.7659 - accuracy: 0.3100
# 100/100 [==============================] - 1s 9ms/step - loss: 1.7033 - accuracy: 0.3400
# 100/100 [==============================] - 1s 9ms/step - loss: 1.9120 - accuracy: 0.2800
# 100/100 [==============================] - 1s 10ms/step - loss: 1.8772 - accuracy: 0.2200
# 100/100 [==============================] - 1s 9ms/step - loss: 1.6620 - accuracy: 0.3600
# 100/100 [==============================] - 1s 10ms/step - loss: 1.9181 - accuracy: 0.3500
# 100/100 [==============================] - 1s 13ms/step - loss: 1.8779 - accuracy: 0.3100
# 100/100 [==============================] - 4s 37ms/step - loss: 1.7696 - accuracy: 0.3600
# 100/100 [==============================] - 4s 35ms/step - loss: 1.8826 - accuracy: 0.2900
# 100/100 [==============================] - 4s 36ms/step - loss: 1.7830 - accuracy: 0.3100
# 100/100 [==============================] - 4s 36ms/step - loss: 1.7666 - accuracy: 0.3600
# 100/100 [==============================] - 4s 36ms/step - loss: 1.8603 - accuracy: 0.2900
# 100/100 [==============================] - 1s 8ms/step - loss: 1.9420 - accuracy: 0.2600
# 100/100 [==============================] - 1s 8ms/step - loss: 1.7228 - accuracy: 0.4300
# 100/100 [==============================] - 1s 8ms/step - loss: 1.8089 - accuracy: 0.3200
# 100/100 [==============================] - 1s 10ms/step - loss: 1.7862 - accuracy: 0.3600
# 100/100 [==============================] - 2s 16ms/step - loss: 1.7886 - accuracy: 0.3500
# 100/100 [==============================] - 1s 13ms/step - loss: 1.7668 - accuracy: 0.4200
# 100/100 [==============================] - 4s 37ms/step - loss: 1.7620 - accuracy: 0.3500
# 100/100 [==============================] - 4s 36ms/step - loss: 1.9133 - accuracy: 0.2400
# 100/100 [==============================] - 4s 35ms/step - loss: 1.7776 - accuracy: 0.3700
# 100/100 [==============================] - 4s 36ms/step - loss: 1.9312 - accuracy: 0.2800
# 100/100 [==============================] - 4s 37ms/step - loss: 1.7943 - accuracy: 0.3600
# 100/100 [==============================] - 4s 37ms/step - loss: 1.8882 - accuracy: 0.3400
# 100/100 [==============================] - 4s 36ms/step - loss: 1.9020 - accuracy: 0.3300
# 100/100 [==============================] - 4s 36ms/step - loss: 1.8487 - accuracy: 0.3000
# 100/100 [==============================] - 4s 35ms/step - loss: 1.9251 - accuracy: 0.2600
# 100/100 [==============================] - 4s 36ms/step - loss: 1.9895 - accuracy: 0.2800
# 100/100 [==============================] - 4s 36ms/step - loss: 1.8343 - accuracy: 0.2800
# 100/100 [==============================] - 4s 36ms/step - loss: 1.8916 - accuracy: 0.3200
# 100/100 [==============================] - 4s 36ms/step - loss: 1.7674 - accuracy: 0.4100
# 100/100 [==============================] - 4s 37ms/step - loss: 2.0297 - accuracy: 0.2300
# 100/100 [==============================] - 4s 36ms/step - loss: 1.8186 - accuracy: 0.3000
# 100/100 [==============================] - 4s 36ms/step - loss: 1.7962 - accuracy: 0.3000
# 100/100 [==============================] - 4s 37ms/step - loss: 1.8069 - accuracy: 0.2500
# 100/100 [==============================] - 4s 36ms/step - loss: 1.8900 - accuracy: 0.2400
# 100/100 [==============================] - 4s 36ms/step - loss: 1.8315 - accuracy: 0.2800
# 100/100 [==============================] - 4s 36ms/step - loss: 1.6805 - accuracy: 0.4300
# 100/100 [==============================] - 4s 36ms/step - loss: 1.8380 - accuracy: 0.3400
# 87/87 [==============================] - 3s 32ms/step - loss: 1.7963 - accuracy: 0.3448
# ==========FINISH TESTING===========
#
#   model name: freeze_30epoch_0.001lr_640bs_764fls_64sls_landmark
#   average lost: 1.8326750606298448
#   average accuracy: 0.31887069158256054
#
# loading image
# Epoch 1/30
# 40/40 [==============================] - 4s 95ms/step - loss: 2.0704 - accuracy: 0.1595 - val_loss: 2.0504 - val_accuracy: 0.1664
# Epoch 2/30
# 40/40 [==============================] - 4s 93ms/step - loss: 2.0364 - accuracy: 0.1859 - val_loss: 2.0291 - val_accuracy: 0.1913
# Epoch 3/30
# 40/40 [==============================] - 4s 93ms/step - loss: 2.0019 - accuracy: 0.2135 - val_loss: 2.0240 - val_accuracy: 0.1901
# Epoch 4/30
# 40/40 [==============================] - 4s 93ms/step - loss: 1.9674 - accuracy: 0.2323 - val_loss: 1.9558 - val_accuracy: 0.2515
# Epoch 5/30
# 40/40 [==============================] - 4s 93ms/step - loss: 1.9295 - accuracy: 0.2638 - val_loss: 1.9146 - val_accuracy: 0.2803
# Epoch 6/30
# 40/40 [==============================] - 4s 93ms/step - loss: 1.9017 - accuracy: 0.2778 - val_loss: 1.9138 - val_accuracy: 0.2844
# Epoch 7/30
# 40/40 [==============================] - 4s 94ms/step - loss: 1.8932 - accuracy: 0.2783 - val_loss: 1.8871 - val_accuracy: 0.3026
# Epoch 8/30
# 40/40 [==============================] - 4s 93ms/step - loss: 1.8693 - accuracy: 0.2909 - val_loss: 1.8695 - val_accuracy: 0.2879
# Epoch 9/30
# 40/40 [==============================] - 4s 94ms/step - loss: 1.8550 - accuracy: 0.2995 - val_loss: 1.8565 - val_accuracy: 0.3091
# Epoch 10/30
# 40/40 [==============================] - 4s 93ms/step - loss: 1.8480 - accuracy: 0.3063 - val_loss: 1.8482 - val_accuracy: 0.3153
# Epoch 11/30
# 40/40 [==============================] - 4s 94ms/step - loss: 1.8397 - accuracy: 0.3073 - val_loss: 1.8382 - val_accuracy: 0.3199
# Epoch 12/30
# 40/40 [==============================] - 4s 94ms/step - loss: 1.8333 - accuracy: 0.3168 - val_loss: 1.8340 - val_accuracy: 0.3110
# Epoch 13/30
# 40/40 [==============================] - 4s 93ms/step - loss: 1.8262 - accuracy: 0.3171 - val_loss: 1.8352 - val_accuracy: 0.3194
# Epoch 14/30
# 40/40 [==============================] - 4s 93ms/step - loss: 1.8226 - accuracy: 0.3202 - val_loss: 1.8280 - val_accuracy: 0.3305
# Epoch 15/30
# 40/40 [==============================] - 4s 94ms/step - loss: 1.8172 - accuracy: 0.3245 - val_loss: 1.8296 - val_accuracy: 0.3144
# Epoch 16/30
# 40/40 [==============================] - 4s 93ms/step - loss: 1.8077 - accuracy: 0.3282 - val_loss: 1.8149 - val_accuracy: 0.3236
# Epoch 17/30
# 40/40 [==============================] - 4s 92ms/step - loss: 1.8057 - accuracy: 0.3308 - val_loss: 1.8189 - val_accuracy: 0.3291
# Epoch 18/30
# 40/40 [==============================] - 4s 92ms/step - loss: 1.8038 - accuracy: 0.3318 - val_loss: 1.8254 - val_accuracy: 0.3191
# Epoch 19/30
# 40/40 [==============================] - 4s 93ms/step - loss: 1.7998 - accuracy: 0.3323 - val_loss: 1.8148 - val_accuracy: 0.3383
# Epoch 20/30
# 40/40 [==============================] - 4s 93ms/step - loss: 1.7982 - accuracy: 0.3300 - val_loss: 1.8023 - val_accuracy: 0.3302
# Epoch 21/30
# 40/40 [==============================] - 4s 93ms/step - loss: 1.7911 - accuracy: 0.3391 - val_loss: 1.8018 - val_accuracy: 0.3377
# Epoch 22/30
# 40/40 [==============================] - 4s 92ms/step - loss: 1.7846 - accuracy: 0.3421 - val_loss: 1.8043 - val_accuracy: 0.3354
# Epoch 23/30
# 40/40 [==============================] - 4s 93ms/step - loss: 1.7926 - accuracy: 0.3380 - val_loss: 1.8010 - val_accuracy: 0.3364
# Epoch 24/30
# 40/40 [==============================] - 4s 92ms/step - loss: 1.7816 - accuracy: 0.3445 - val_loss: 1.7876 - val_accuracy: 0.3462
# Epoch 25/30
# 40/40 [==============================] - 4s 92ms/step - loss: 1.7813 - accuracy: 0.3394 - val_loss: 1.8121 - val_accuracy: 0.3285
# Epoch 26/30
# 40/40 [==============================] - 4s 92ms/step - loss: 1.7779 - accuracy: 0.3433 - val_loss: 1.7846 - val_accuracy: 0.3473
# Epoch 27/30
# 40/40 [==============================] - 4s 92ms/step - loss: 1.7753 - accuracy: 0.3454 - val_loss: 1.7952 - val_accuracy: 0.3450
# Epoch 28/30
# 40/40 [==============================] - 4s 93ms/step - loss: 1.7706 - accuracy: 0.3510 - val_loss: 1.7879 - val_accuracy: 0.3399
# Epoch 29/30
# 40/40 [==============================] - 4s 93ms/step - loss: 1.7723 - accuracy: 0.3502 - val_loss: 1.7817 - val_accuracy: 0.3435
# Epoch 30/30
# 40/40 [==============================] - 4s 92ms/step - loss: 1.7704 - accuracy: 0.3478 - val_loss: 1.7809 - val_accuracy: 0.3454
# 3.7221279462178547
# trained image count:  31553
# Images Left:  0
# Estimated completion time:  0:00:00
# ---------------- freeze_30epoch_0.001lr_640bs_764fls_128sls_landmark Training Completed ------------------
# 100/100 [==============================] - 1s 9ms/step - loss: 1.7350 - accuracy: 0.3800
# 100/100 [==============================] - 1s 9ms/step - loss: 1.6547 - accuracy: 0.4000
# 100/100 [==============================] - 1s 8ms/step - loss: 1.8951 - accuracy: 0.2800
# 100/100 [==============================] - 1s 8ms/step - loss: 1.8500 - accuracy: 0.2600
# 100/100 [==============================] - 1s 9ms/step - loss: 1.6183 - accuracy: 0.3600
# 100/100 [==============================] - 1s 9ms/step - loss: 1.9040 - accuracy: 0.3200
# 100/100 [==============================] - 1s 11ms/step - loss: 1.8840 - accuracy: 0.3000
# 100/100 [==============================] - 2s 24ms/step - loss: 1.7450 - accuracy: 0.3800
# 100/100 [==============================] - 1s 9ms/step - loss: 1.8845 - accuracy: 0.2800
# 100/100 [==============================] - 1s 9ms/step - loss: 1.7964 - accuracy: 0.3200
# 100/100 [==============================] - 1s 9ms/step - loss: 1.7557 - accuracy: 0.3400
# 100/100 [==============================] - 1s 10ms/step - loss: 1.8448 - accuracy: 0.2900
# 100/100 [==============================] - 3s 29ms/step - loss: 1.9507 - accuracy: 0.2600
# 100/100 [==============================] - 4s 35ms/step - loss: 1.6714 - accuracy: 0.4800
# 100/100 [==============================] - 4s 35ms/step - loss: 1.8024 - accuracy: 0.2900
# 100/100 [==============================] - 4s 36ms/step - loss: 1.8064 - accuracy: 0.3400
# 100/100 [==============================] - 2s 23ms/step - loss: 1.7449 - accuracy: 0.4100
# 100/100 [==============================] - 1s 11ms/step - loss: 1.7239 - accuracy: 0.4000
# 100/100 [==============================] - 3s 34ms/step - loss: 1.7662 - accuracy: 0.3600
# 100/100 [==============================] - 3s 27ms/step - loss: 1.8730 - accuracy: 0.2900
# 100/100 [==============================] - 1s 11ms/step - loss: 1.7131 - accuracy: 0.3900
# 100/100 [==============================] - 3s 32ms/step - loss: 1.8630 - accuracy: 0.2800
# 100/100 [==============================] - 4s 35ms/step - loss: 1.7652 - accuracy: 0.3500
# 100/100 [==============================] - 1s 9ms/step - loss: 1.8376 - accuracy: 0.3600
# 100/100 [==============================] - 1s 9ms/step - loss: 1.9202 - accuracy: 0.3200
# 100/100 [==============================] - 1s 10ms/step - loss: 1.8028 - accuracy: 0.3300
# 100/100 [==============================] - 1s 10ms/step - loss: 1.8813 - accuracy: 0.3100
# 100/100 [==============================] - 3s 29ms/step - loss: 1.9426 - accuracy: 0.2700
# 100/100 [==============================] - 4s 37ms/step - loss: 1.8256 - accuracy: 0.2900
# 100/100 [==============================] - 4s 36ms/step - loss: 1.8926 - accuracy: 0.3200
# 100/100 [==============================] - 4s 36ms/step - loss: 1.7647 - accuracy: 0.3400
# 100/100 [==============================] - 4s 37ms/step - loss: 2.0008 - accuracy: 0.2500
# 100/100 [==============================] - 4s 37ms/step - loss: 1.7567 - accuracy: 0.3800
# 100/100 [==============================] - 4s 36ms/step - loss: 1.7757 - accuracy: 0.3400
# 100/100 [==============================] - 4s 37ms/step - loss: 1.7842 - accuracy: 0.3200
# 100/100 [==============================] - 4s 37ms/step - loss: 1.8239 - accuracy: 0.2500
# 100/100 [==============================] - 4s 37ms/step - loss: 1.7660 - accuracy: 0.3200
# 100/100 [==============================] - 4s 36ms/step - loss: 1.6547 - accuracy: 0.3900
# 100/100 [==============================] - 4s 38ms/step - loss: 1.8672 - accuracy: 0.3500
# 87/87 [==============================] - 3s 38ms/step - loss: 1.7929 - accuracy: 0.2759
# ==========FINISH TESTING===========
#
#   model name: freeze_30epoch_0.001lr_640bs_764fls_128sls_landmark
#   average lost: 1.8084320187568665
#   average accuracy: 0.3293965503573418
#
# loading image
# Epoch 1/30
# 40/40 [==============================] - 5s 105ms/step - loss: 2.0929 - accuracy: 0.1463 - val_loss: 2.0498 - val_accuracy: 0.1640
# Epoch 2/30
# 40/40 [==============================] - 4s 102ms/step - loss: 2.0357 - accuracy: 0.1837 - val_loss: 2.0308 - val_accuracy: 0.2025
# Epoch 3/30
# 40/40 [==============================] - 4s 102ms/step - loss: 2.0019 - accuracy: 0.2146 - val_loss: 1.9985 - val_accuracy: 0.2188
# Epoch 4/30
# 40/40 [==============================] - 4s 102ms/step - loss: 1.9674 - accuracy: 0.2378 - val_loss: 1.9617 - val_accuracy: 0.2543
# Epoch 5/30
# 40/40 [==============================] - 4s 102ms/step - loss: 1.9390 - accuracy: 0.2551 - val_loss: 1.9327 - val_accuracy: 0.2592
# Epoch 6/30
# 40/40 [==============================] - 4s 102ms/step - loss: 1.9208 - accuracy: 0.2626 - val_loss: 1.9212 - val_accuracy: 0.2732
# Epoch 7/30
# 40/40 [==============================] - 4s 102ms/step - loss: 1.9125 - accuracy: 0.2713 - val_loss: 1.8935 - val_accuracy: 0.2884
# Epoch 8/30
# 40/40 [==============================] - 4s 102ms/step - loss: 1.8873 - accuracy: 0.2859 - val_loss: 1.9119 - val_accuracy: 0.2445
# Epoch 9/30
# 40/40 [==============================] - 4s 102ms/step - loss: 1.8831 - accuracy: 0.2848 - val_loss: 1.8815 - val_accuracy: 0.2930
# Epoch 10/30
# 40/40 [==============================] - 4s 103ms/step - loss: 1.8757 - accuracy: 0.2887 - val_loss: 1.8750 - val_accuracy: 0.2866
# Epoch 11/30
# 40/40 [==============================] - 4s 103ms/step - loss: 1.8581 - accuracy: 0.2988 - val_loss: 1.8647 - val_accuracy: 0.3022
# Epoch 12/30
# 40/40 [==============================] - 4s 102ms/step - loss: 1.8564 - accuracy: 0.3001 - val_loss: 1.8499 - val_accuracy: 0.3144
# Epoch 13/30
# 40/40 [==============================] - 4s 101ms/step - loss: 1.8485 - accuracy: 0.3052 - val_loss: 1.8499 - val_accuracy: 0.3098
# Epoch 14/30
# 40/40 [==============================] - 4s 102ms/step - loss: 1.8410 - accuracy: 0.3096 - val_loss: 1.8463 - val_accuracy: 0.3096
# Epoch 15/30
# 40/40 [==============================] - 4s 101ms/step - loss: 1.8342 - accuracy: 0.3136 - val_loss: 1.8586 - val_accuracy: 0.3055
# Epoch 16/30
# 40/40 [==============================] - 4s 101ms/step - loss: 1.8357 - accuracy: 0.3101 - val_loss: 1.8445 - val_accuracy: 0.3112
# Epoch 17/30
# 40/40 [==============================] - 4s 102ms/step - loss: 1.8276 - accuracy: 0.3192 - val_loss: 1.8453 - val_accuracy: 0.3148
# Epoch 18/30
# 40/40 [==============================] - 4s 101ms/step - loss: 1.8267 - accuracy: 0.3182 - val_loss: 1.8239 - val_accuracy: 0.3221
# Epoch 19/30
# 40/40 [==============================] - 4s 101ms/step - loss: 1.8172 - accuracy: 0.3216 - val_loss: 1.8381 - val_accuracy: 0.3210
# Epoch 20/30
# 40/40 [==============================] - 4s 102ms/step - loss: 1.8217 - accuracy: 0.3196 - val_loss: 1.8203 - val_accuracy: 0.3328
# Epoch 21/30
# 40/40 [==============================] - 4s 102ms/step - loss: 1.8145 - accuracy: 0.3283 - val_loss: 1.8268 - val_accuracy: 0.3220
# Epoch 22/30
# 40/40 [==============================] - 4s 101ms/step - loss: 1.8047 - accuracy: 0.3330 - val_loss: 1.8363 - val_accuracy: 0.3134
# Epoch 23/30
# 40/40 [==============================] - 4s 103ms/step - loss: 1.8035 - accuracy: 0.3297 - val_loss: 1.8180 - val_accuracy: 0.3309
# Epoch 24/30
# 40/40 [==============================] - 4s 102ms/step - loss: 1.8042 - accuracy: 0.3289 - val_loss: 1.8255 - val_accuracy: 0.3301
# Epoch 25/30
# 40/40 [==============================] - 4s 103ms/step - loss: 1.7988 - accuracy: 0.3341 - val_loss: 1.8012 - val_accuracy: 0.3432
# Epoch 26/30
# 40/40 [==============================] - 4s 103ms/step - loss: 1.7963 - accuracy: 0.3357 - val_loss: 1.8164 - val_accuracy: 0.3320
# Epoch 27/30
# 40/40 [==============================] - 4s 103ms/step - loss: 1.7955 - accuracy: 0.3337 - val_loss: 1.8117 - val_accuracy: 0.3340
# Epoch 28/30
# 40/40 [==============================] - 4s 103ms/step - loss: 1.7880 - accuracy: 0.3399 - val_loss: 1.8058 - val_accuracy: 0.3315
# 4.083804249763489
# trained image count:  31553
# Images Left:  0
# Estimated completion time:  0:00:00
# ---------------- freeze_30epoch_0.001lr_640bs_764fls_192sls_landmark Training Completed ------------------
# 100/100 [==============================] - 1s 9ms/step - loss: 1.7470 - accuracy: 0.3400
# 100/100 [==============================] - 1s 9ms/step - loss: 1.6853 - accuracy: 0.3600
# 100/100 [==============================] - 1s 9ms/step - loss: 1.9231 - accuracy: 0.2800
# 100/100 [==============================] - 1s 10ms/step - loss: 1.8477 - accuracy: 0.2800
# 100/100 [==============================] - 1s 10ms/step - loss: 1.6361 - accuracy: 0.3300
# 100/100 [==============================] - 1s 10ms/step - loss: 1.9139 - accuracy: 0.3600
# 100/100 [==============================] - 1s 11ms/step - loss: 1.8813 - accuracy: 0.3100
# 100/100 [==============================] - 4s 37ms/step - loss: 1.7663 - accuracy: 0.4100
# 100/100 [==============================] - 4s 37ms/step - loss: 1.9071 - accuracy: 0.3200
# 100/100 [==============================] - 4s 37ms/step - loss: 1.7860 - accuracy: 0.3100
# 100/100 [==============================] - 4s 37ms/step - loss: 1.7698 - accuracy: 0.3500
# 100/100 [==============================] - 4s 37ms/step - loss: 1.8681 - accuracy: 0.2800
# 100/100 [==============================] - 4s 37ms/step - loss: 1.9523 - accuracy: 0.2100
# 100/100 [==============================] - 2s 17ms/step - loss: 1.7149 - accuracy: 0.4600
# 100/100 [==============================] - 2s 17ms/step - loss: 1.7926 - accuracy: 0.3200
# 100/100 [==============================] - 4s 37ms/step - loss: 1.7807 - accuracy: 0.3400
# 100/100 [==============================] - 4s 36ms/step - loss: 1.7766 - accuracy: 0.3700
# 100/100 [==============================] - 2s 22ms/step - loss: 1.7589 - accuracy: 0.4300
# 100/100 [==============================] - 1s 9ms/step - loss: 1.7469 - accuracy: 0.3700
# 100/100 [==============================] - 1s 9ms/step - loss: 1.8997 - accuracy: 0.2700
# 100/100 [==============================] - 1s 9ms/step - loss: 1.7571 - accuracy: 0.3600
# 100/100 [==============================] - 2s 24ms/step - loss: 1.9140 - accuracy: 0.2700
# 100/100 [==============================] - 4s 37ms/step - loss: 1.7462 - accuracy: 0.3700
# 100/100 [==============================] - 1s 9ms/step - loss: 1.8832 - accuracy: 0.3500
# 100/100 [==============================] - 1s 9ms/step - loss: 1.9234 - accuracy: 0.3400
# 100/100 [==============================] - 1s 9ms/step - loss: 1.8006 - accuracy: 0.3500
# 100/100 [==============================] - 1s 10ms/step - loss: 1.9207 - accuracy: 0.3200
# 100/100 [==============================] - 4s 37ms/step - loss: 1.9761 - accuracy: 0.3200
# 100/100 [==============================] - 4s 38ms/step - loss: 1.8457 - accuracy: 0.3300
# 100/100 [==============================] - 4s 37ms/step - loss: 1.9180 - accuracy: 0.2800
# 100/100 [==============================] - 4s 37ms/step - loss: 1.7731 - accuracy: 0.3400
# 100/100 [==============================] - 4s 37ms/step - loss: 2.0325 - accuracy: 0.1900
# 100/100 [==============================] - 4s 37ms/step - loss: 1.7954 - accuracy: 0.3500
# 100/100 [==============================] - 4s 37ms/step - loss: 1.7962 - accuracy: 0.3200
# 100/100 [==============================] - 4s 37ms/step - loss: 1.7733 - accuracy: 0.2800
# 100/100 [==============================] - 4s 37ms/step - loss: 1.8622 - accuracy: 0.2600
# 100/100 [==============================] - 4s 37ms/step - loss: 1.7884 - accuracy: 0.3100
# 100/100 [==============================] - 2s 16ms/step - loss: 1.6340 - accuracy: 0.4100
# 100/100 [==============================] - 2s 17ms/step - loss: 1.8493 - accuracy: 0.3400
# 87/87 [==============================] - 3s 37ms/step - loss: 1.8195 - accuracy: 0.3103
# ==========FINISH TESTING===========
#
#   model name: freeze_30epoch_0.001lr_640bs_764fls_192sls_landmark
#   average lost: 1.8240795612335206
#   average accuracy: 0.32750862203538417
#
# loading image
# Epoch 1/30
# 40/40 [==============================] - 5s 111ms/step - loss: 2.0982 - accuracy: 0.1498 - val_loss: 2.0483 - val_accuracy: 0.1688
# Epoch 2/30
# 40/40 [==============================] - 4s 110ms/step - loss: 2.0313 - accuracy: 0.1877 - val_loss: 2.0262 - val_accuracy: 0.1897
# Epoch 3/30
# 40/40 [==============================] - 4s 110ms/step - loss: 1.9979 - accuracy: 0.2128 - val_loss: 1.9931 - val_accuracy: 0.2050
# Epoch 4/30
# 40/40 [==============================] - 4s 110ms/step - loss: 1.9649 - accuracy: 0.2363 - val_loss: 1.9521 - val_accuracy: 0.2578
# Epoch 5/30
# 40/40 [==============================] - 4s 110ms/step - loss: 1.9331 - accuracy: 0.2577 - val_loss: 1.9182 - val_accuracy: 0.2890
# Epoch 6/30
# 40/40 [==============================] - 4s 109ms/step - loss: 1.9106 - accuracy: 0.2716 - val_loss: 1.9100 - val_accuracy: 0.2762
# Epoch 7/30
# 40/40 [==============================] - 4s 110ms/step - loss: 1.9023 - accuracy: 0.2764 - val_loss: 1.8957 - val_accuracy: 0.2792
# Epoch 8/30
# 40/40 [==============================] - 4s 110ms/step - loss: 1.8853 - accuracy: 0.2846 - val_loss: 1.8888 - val_accuracy: 0.2879
# Epoch 9/30
# 40/40 [==============================] - 4s 110ms/step - loss: 1.8742 - accuracy: 0.2928 - val_loss: 1.8745 - val_accuracy: 0.3004
# Epoch 10/30
# 40/40 [==============================] - 4s 110ms/step - loss: 1.8767 - accuracy: 0.2882 - val_loss: 1.8594 - val_accuracy: 0.3160
# Epoch 11/30
# 40/40 [==============================] - 4s 110ms/step - loss: 1.8565 - accuracy: 0.3036 - val_loss: 1.8715 - val_accuracy: 0.3017
# Epoch 12/30
# 40/40 [==============================] - 4s 111ms/step - loss: 1.8491 - accuracy: 0.3059 - val_loss: 1.8596 - val_accuracy: 0.2965
# Epoch 13/30
# 40/40 [==============================] - 4s 110ms/step - loss: 1.8439 - accuracy: 0.3081 - val_loss: 1.8665 - val_accuracy: 0.2952
# 4.410072876856877
# trained image count:  31553
# Images Left:  0
# Estimated completion time:  0:00:00
# ---------------- freeze_30epoch_0.001lr_640bs_764fls_256sls_landmark Training Completed ------------------
# 100/100 [==============================] - 1s 9ms/step - loss: 1.7922 - accuracy: 0.3000
# 100/100 [==============================] - 1s 9ms/step - loss: 1.7479 - accuracy: 0.3300
# 100/100 [==============================] - 1s 9ms/step - loss: 1.9042 - accuracy: 0.3000
# 100/100 [==============================] - 1s 9ms/step - loss: 1.9035 - accuracy: 0.2900
# 100/100 [==============================] - 1s 9ms/step - loss: 1.7519 - accuracy: 0.2700
# 100/100 [==============================] - 1s 10ms/step - loss: 1.9368 - accuracy: 0.2900
# 100/100 [==============================] - 1s 12ms/step - loss: 1.9043 - accuracy: 0.3000
# 100/100 [==============================] - 4s 36ms/step - loss: 1.7800 - accuracy: 0.3500
# 100/100 [==============================] - 4s 37ms/step - loss: 1.9240 - accuracy: 0.2900
# 100/100 [==============================] - 4s 37ms/step - loss: 1.8184 - accuracy: 0.3500
# 100/100 [==============================] - 4s 36ms/step - loss: 1.8600 - accuracy: 0.3400
# 100/100 [==============================] - 4s 36ms/step - loss: 1.9309 - accuracy: 0.2600
# 100/100 [==============================] - 4s 35ms/step - loss: 1.9889 - accuracy: 0.2700
# 100/100 [==============================] - 4s 36ms/step - loss: 1.7842 - accuracy: 0.4200
# 100/100 [==============================] - 4s 36ms/step - loss: 1.8375 - accuracy: 0.3000
# 100/100 [==============================] - 4s 36ms/step - loss: 1.8212 - accuracy: 0.3100
# 100/100 [==============================] - 4s 36ms/step - loss: 1.8007 - accuracy: 0.3600
# 100/100 [==============================] - 3s 25ms/step - loss: 1.8190 - accuracy: 0.3700
# 100/100 [==============================] - 1s 11ms/step - loss: 1.7567 - accuracy: 0.4300
# 100/100 [==============================] - 4s 36ms/step - loss: 1.9488 - accuracy: 0.2200
# 100/100 [==============================] - 4s 36ms/step - loss: 1.8231 - accuracy: 0.3800
# 100/100 [==============================] - 3s 25ms/step - loss: 1.9669 - accuracy: 0.2400
# 100/100 [==============================] - 1s 11ms/step - loss: 1.8296 - accuracy: 0.2900
# 100/100 [==============================] - 4s 37ms/step - loss: 1.9122 - accuracy: 0.3200
# 100/100 [==============================] - 4s 37ms/step - loss: 1.9089 - accuracy: 0.3100
# 100/100 [==============================] - 4s 36ms/step - loss: 1.8617 - accuracy: 0.3700
# 100/100 [==============================] - 4s 36ms/step - loss: 1.9648 - accuracy: 0.2800
# 100/100 [==============================] - 4s 37ms/step - loss: 1.9697 - accuracy: 0.2700
# 100/100 [==============================] - 4s 37ms/step - loss: 1.8789 - accuracy: 0.2900
# 100/100 [==============================] - 4s 37ms/step - loss: 1.9377 - accuracy: 0.2800
# 100/100 [==============================] - 4s 37ms/step - loss: 1.8413 - accuracy: 0.3200
# 100/100 [==============================] - 4s 36ms/step - loss: 2.0645 - accuracy: 0.1600
# 100/100 [==============================] - 4s 37ms/step - loss: 1.8244 - accuracy: 0.3400
# 100/100 [==============================] - 4s 37ms/step - loss: 1.8488 - accuracy: 0.3200
# 100/100 [==============================] - 4s 37ms/step - loss: 1.8164 - accuracy: 0.3000
# 100/100 [==============================] - 4s 37ms/step - loss: 1.8920 - accuracy: 0.2700
# 100/100 [==============================] - 4s 37ms/step - loss: 1.8367 - accuracy: 0.3100
# 100/100 [==============================] - 4s 36ms/step - loss: 1.7477 - accuracy: 0.3600
# 100/100 [==============================] - 4s 37ms/step - loss: 1.8924 - accuracy: 0.3400
# 87/87 [==============================] - 3s 37ms/step - loss: 1.8562 - accuracy: 0.2989
# ==========FINISH TESTING===========
#
#   model name: freeze_30epoch_0.001lr_640bs_764fls_256sls_landmark
#   average lost: 1.8671251684427261
#   average accuracy: 0.30997126586735246
#
# loading image
# Epoch 1/30
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[14], line 11
#       9 for secondLayerSize in secondLayerSizes:
#      10   name = "freeze_{}epoch_{}lr_{}bs_{}fls_{}sls_landmark".format(epoch, learningRate, batchSize, firstLayerSize, secondLayerSize)
# ---> 11   FreezeLayerTrainAndTest(epoch, learningRate, name, batchSize, firstLayerSize, secondLayerSize)
#
# Cell In[12], line 43, in FreezeLayerTrainAndTest(epoch, learningRate, modelName, batchSize, firstLayerSize, secondLayerSize)
#      41   label, data = LoadVertices(TRAINLANDMARKPATH, croppedList)
#      42   # Training model
# ---> 43   model.fit(data, label, epochs = epoch, validation_split = 0.2, batch_size = batchSize, callbacks = [time_callback, tensorboard, earlyStop]) # earlyStop, earlyStopAcc, reduce_lr, reset_lr
#      44   print(time_callback.AverageTime())
#      45 except RuntimeError as e:
#
# File ~\AppData\Local\miniconda3\envs\tflite-facial-expression\lib\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File ~\AppData\Local\miniconda3\envs\tflite-facial-expression\lib\site-packages\tensorflow\python\framework\ops.py:7186, in raise_from_not_ok_status(e, name)
#    7184 def raise_from_not_ok_status(e, name):
#    7185   e.message += (" name: " + name if name is not None else "")
# -> 7186   raise core._status_to_exception(e) from None
#
# ResourceExhaustedError: OOM when allocating tensor with shape[640,478,384] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc [Op:ReluGrad]

# %%
def FreezeLayerTrainAndTest(epoch, learningRate, modelName, batchSize, firstLayerSize, secondLayerSize):
  """Train and test a model. This function's input should be customized to accept different parameters, function body should be customized to these parameters to train models of variety of paramters.

  Args:
      modelName (str): name of model
  """
  #-------------------------------------------------
  # Building model
  #-------------------------------------------------
  # Adding 3 more layers to output side
  inputs = tf.keras.Input(shape=(478,3))
  base = tf.keras.layers.Dense(firstLayerSize, activation='relu')(inputs)
  base = tf.keras.layers.Dense(secondLayerSize, activation='relu')(base)
  base = tf.keras.layers.Flatten()(base)
  outputs = tf.keras.layers.Dense(8, activation='softmax')(base)
  
  model = tf.keras.Model(inputs=inputs, outputs=outputs)
  model.compile(loss = "sparse_categorical_crossentropy", optimizer = keras.optimizers.Adam(lr = learningRate), metrics=["accuracy"])

  # ------------------ Callbacks ------------------
  tensorboard = TensorBoard(log_dir = "logs/{}".format(modelName))
  earlyStop = EarlyStopping(monitor='val_loss', patience = 3, restore_best_weights=True)
  # earlyStopAcc = EarlyStopping(monitor='val_accuracy', patience = 1, restore_best_weights = True)
  # reduce_lr = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.5, patience = 2, min_lr = 0.0002)
  # reset_lr = ResetLR(learningRate)

  # ------------------ Training Model ------------------
  time_callback = TimeHistory()
  trainDataSet = mainTrainSet.copy()

  # Initializing model fit params
  # batchSize = 4
  imgPerIter = batchSize*256

  count = 0
  while(len(trainDataSet) != 0):
    croppedList = []
    try:
      print("loading image") # Crop and load images in
      croppedList = CropData(trainDataSet, imgPerIter)
      label, data = LoadVertices(TRAINLANDMARKPATH, croppedList)
      # Training model
      model.fit(data, label, epochs = epoch, validation_split = 0.2, batch_size = batchSize, callbacks = [time_callback, tensorboard, earlyStop]) # earlyStop, earlyStopAcc, reduce_lr, reset_lr
      print(time_callback.AverageTime())
    except RuntimeError as e:
      print(e)
    
    # Saving weights
    model.save_weights('{}.h5'.format(modelName))
    
    # Print summary of current iteration
    count = count + len(croppedList)
    timeLeft = len(trainDataSet)/imgPerIter * time_callback.AverageTime()
    print("trained image count: ", count)
    print("Images Left: ", len(trainDataSet))
    print("Estimated completion time: ", str(timedelta(seconds=timeLeft)))
    
    reset_keras()
  print("---------------- {} Training Completed ------------------".format(modelName))

  # ---------------- Testing Model -----------------
  # initialise image names and label
  testSetData = mainTestSet.copy()

  # test model
  loss, accuracy = TestModelWithVertices(model, testSetData, tensorboard)

  # Saving test informations
  modelSummary = '''
  model name: {}
  average lost: {}
  average accuracy: {}
            '''.format(modelName, loss, accuracy)
      
  print("==========FINISH TESTING===========\n{}".format(modelSummary))
  
  file = open("training_summaries.txt", "a")
  file.write(modelSummary + "\n\n")

# %%
model.summary()
